# %%
"""
We use the limit cycle to predict the motion of the slider given velocity of the pusher.
This is implementing a recent paper by Alberto

Object models to be considered:
1) cylinders
2) blocks
"""
import numpy as np
class Geometry:
    def __init__(self, shape, mins, maxs, resols):
        self.shape = shape
        self.grid_size = (maxs-mins)/resols
        self.grid_size = np.ceil(self.grid_size).astype(int)
        self.mins = mins
        self.maxs = maxs
        self.resols = resols
        self.grid = np.zeros(self.grid_size).astype(int)  # an occupancy grid
        self.grid_x, self.grid_y = np.indices(self.grid_size)
        self.grid_x = self.resols[0] * (self.grid_x+0.5) + self.mins[0]
        self.grid_y = self.resols[1] * (self.grid_y+0.5) + self.mins[1]

    def update_grid(self):
        # obtain the occupancy grid based on the shape
        pass
    def local_inside(self, pt):
        pass

class CylinderShape(Geometry):
    def __init__(self, shape, mins, maxs, resols):
        super().__init__(shape, mins, maxs, resols)
        self.update_grid()
    def update_grid(self):
        # check the points if they're inside the grid
        inside = np.sqrt(self.grid_x ** 2 + self.grid_y ** 2)
        inside = inside <= self.shape
        self.grid = inside
        print('after update_grid')
    def local_inside(self, pt):
        return np.sqrt(pt[0]**2 + pt[1]**2) <= self.shape
class BlockShape(Geometry):
    def __init__(self, shape, mins, maxs, resols):
        super().__init__(shape, mins, maxs, resols)
        self.update_grid()
    def update_grid(self):
        # check the points if they're inside the grid
        inside = (self.grid_x <= self.shape[0]/2) & (self.grid_y <= self.shape[1]/2) & \
                (self.grid_x >= -self.shape[0]/2) & (self.grid_y >= -self.shape[1]/2)
        self.grid = inside
    def local_inside(self, pt):
        inside = (pt[0] <= self.shape[0]/2) & (pt[1] <= self.shape[1]/2) & \
                (pt[0] >= -self.shape[0]/2) & (pt[1] >= -self.shape[1]/2)
        return inside

# %%
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
import matplotlib.tri as mtri

class Slider:
    def __init__(self, transform, shape):
        # transform: x,y,theta
        # shape: cylinder is radius, block is (height, width)
        self.transform = transform
        x,y,theta = transform
        tf_mat = [[np.cos(theta), -np.sin(theta),x], [np.sin(theta), np.cos(theta),y],[0,0,1]]
        tf_mat = np.array(tf_mat)
        self.tf_mat = tf_mat
        self.shape = shape
        self.tran_vel = np.zeros((2))
        self.rot_vel = 0
        self.type = 'none'
        self.hull = None
    def global_inside(self, pt):
        tf_mat = np.linalg.inv(self.tf_mat)
        pt = tf_mat[:2,:2].dot(pt) + tf_mat[:2,2]
        return self.geo.local_inside(pt)
    def get_tf_mat(self, transform):
        x,y,theta = transform
        tf_mat = [[np.cos(theta), -np.sin(theta),x], [np.sin(theta), np.cos(theta),y],[0,0,1]]
        tf_mat = np.array(tf_mat)
        return tf_mat
    def update_transform(self, new_transform):
        self.transform = new_transform
        self.tf_mat = self.get_tf_mat(new_transform)
    def update_vel(self, tran_vel, rot_vel):
        self.tran_vel = tran_vel
        self.rot_vel = rot_vel
    def get_contact_pt(self, contact_angle):
        pass
    def get_contact_angle_from_global(self, contact_pt):
        # first project contact pt to the local frame
        tf_mat_local = np.linalg.inv(self.tf_mat)
        contact_pt = tf_mat_local[:2,:2].dot(contact_pt) + tf_mat_local[:2,2]
        return self.get_contact_angle_from_local(contact_pt)
    def get_contact_angle_from_local(self, contact_pt):
        return np.arctan2(contact_pt[1], contact_pt[0])
        
    def get_normal_local(self, contact_angle):
        # any convex object can map 1-to-1 to a unit circle
        # this is in the local frame
        pass
    def get_tran_vel(self, contact_angle, vel):
        # get the vector from contact point to COM
        pt = self.get_contact_pt(contact_angle)
        pt = pt/np.linalg.norm(pt)
        return vel.dot(pt)*pt
    def get_rot_vel(self, contact_angle, vel):
        # get the vector from contact point to COM
        pt = self.get_contact_pt(contact_angle)
        norm = np.linalg.norm(pt)
        pt = pt/np.linalg.norm(pt)
        # linear_v = vel - vel.dot(norm)*norm
        linear_v = np.cross(vel, pt)  # |a||b|sin(theta)
        ang_v = linear_v / norm
        return ang_v
    def get_vel_in_local(self, vel):
        """
        given a velocity in the global frame, get the relative velocity in the local frame
        """
        tf_mat = self.tf_mat
        tf_mat = np.linalg.inv(tf_mat)
        return tf_mat[:2,:2].dot(vel)
    
    def get_vel_at_contact(self, contact_angle, tran_vel, rot_vel):
        # get the contact poitn velocity, assuming the object is undergoing velocity
        pass
    def get_cur_vel_at_contact(self, contact_angle):
        # get the contact point velocity based on the object current velocity
        pass
    """
    for getting the limit surface
    """
    def get_total_friction_at_pt(self, f, r):
        # TODO: consider coefficient and mass
        torque = np.cross(r, f)
        load = np.array([f[0], f[1], torque[2]])
        return load
    def get_total_friction_from_v(self, v):
        """
        v: [vx, vy, omega]
        """
        # get the local velocity of each point
        vx = np.zeros(self.geo.grid.shape) + v[0]
        vy = np.zeros(self.geo.grid.shape) + v[1]
        vx = vx - v[2] * self.geo.grid_y
        vy = vy + v[2] * self.geo.grid_x
        v_size = np.sqrt(vx ** 2 + vy ** 2)
        fx = vx / v_size
        fy = vy / v_size
        fw = self.geo.grid_x * fy - self.geo.grid_y * fx
        F = np.array([fx[self.geo.grid].sum(), fy[self.geo.grid].sum(), 
                      fw[self.geo.grid].sum()]) * self.geo.resols[0] * self.geo.resols[1]
        return F
    def construct_ls_db(self, n_samples=2500, ax=None):
        """
        sample velocities, and compute the (F,M) values. Then store them into a db
        Then we can:
        1. use convex hull of the sampled (F,M) to construct the limit surface
        2. use nearest neighbor to find velocity
        """
        points = np.random.normal(size=(n_samples,3))
        print(points.shape)
        points = points / np.linalg.norm(points, axis=1).reshape((-1,1))
        fs = []
        for i in range(len(points)):
            f = self.get_total_friction_from_v(points[i])
            fs.append(f)
        fs = np.array(fs)

        hull = ConvexHull(fs)

        # triple
        x = fs[:,0]
        y = fs[:,1]
        z = fs[:,2]

        # Triangulate parameter space to determine the triangles
        tri = mtri.Triangulation(x,y,triangles=hull.simplices)

        # Plot the surface.  The triangles in parameter space determine which x, y, z
        # points are connected by an edge.
        if ax is not None:
            ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
        
#         if ax is not None:
#             ax.plot_trisurf(fs[:,0], fs[:,1], fs[:,2], linewidth=0.2, antialiased=True)
        
#         # Plot defining corner points
#         if ax is not None:
#             ax.plot(fs[:,0], fs[:,1], fs[:,2], "ko")

#         # 12 = 2 * 6 faces are the simplices (2 simplices per square face)
#         for s in hull.simplices:
#             s = np.append(s, s[0])  # Here we cycle back to the first coordinate
#             if ax is not None:
#                 ax.plot(fs[s, 0], fs[s, 1], fs[s, 2], "r-")            
        self.hull = hull
        return hull
    def get_ls_vel(self, f, plot_scale=0.1, ax=None):
        # https://stackoverflow.com/questions/30486312/intersection-of-nd-line-with-convex-hull-in-python
        if self.hull is None:
            print('constructing hull...')
            self.construct_ls_db(ax=ax)
        # find the face that the force projects to
        eq=self.hull.equations.T
        V,b=eq[:-1].T,eq[-1]
        alpha=-b/np.dot(V,f)
        alpha[alpha<=0] = np.inf
        face_idx = np.argmin(alpha)
        proj_pt = alpha[face_idx]*f
        # TODO: plot this
        normal = self.hull.equations[face_idx,:-1]        
        normal = normal / np.linalg.norm(normal) * plot_scale
        if ax is not None:
            plt.plot([proj_pt[0],proj_pt[0]+normal[0]],
                     [proj_pt[1],proj_pt[1]+normal[1]],
                     [proj_pt[2],proj_pt[2]+normal[2]])
        print('projected point: ', proj_pt)
        print('normal: ', normal)
        return normal
    def get_ls_f(self, vel):
        # find the force that corresponds to the normal direction vel
        # the one with the max inner product
        if self.hull is None:
            print('constructing hull...')
            self.construct_ls_db(ax=ax)

        vel = vel / np.linalg.norm(vel)
        idx = np.argmax(self.hull.points.dot(vel))
        return self.hull.points[idx]
    
        

# TODO: implement cylinder and block sliders. Write an animation for these
class CylinderSlider(Slider):
    def __init__(self, transform, shape):
        super().__init__(transform, shape)
        self.radius = shape  # shape is a float
        self.type = 'cylinder'
        mins = np.array([-self.radius, -self.radius])
        maxs = np.array([self.radius, self.radius])
        resols = np.array([0.01, 0.01])
        self.geo = CylinderShape(shape, mins, maxs, resols)

    def get_contact_pt(self, contact_angle):
        return self.radius*np.array([np.cos(contact_angle),np.sin(contact_angle)])
    def get_contact_pt_in_world(self, contact_angle):
        contact_pt = self.get_contact_pt(contact_angle)
        return self.tf_mat[:2,:2].dot(contact_pt) + self.tf_mat[:2,2]

    def get_normal_local(self, contact_angle):
        return -np.array([np.cos(contact_angle),np.sin(contact_angle)])
    def get_vel_at_contact(self, contact_angle, tran_vel, rot_vel):
        linear_v = rot_vel * self.radius
        linear_v = np.array([0,0,linear_v])
        # get the vector pointing from the COM to the contact point. This is useful to get the
        # linear velocity at the contact point
        contact_pt = self.get_contact_pt(contact_angle)
        contact_pt_vec = self.tf_mat[:2,:2].dot(contact_pt)
        contact_pt_vec = contact_pt_vec / np.linalg.norm(contact_pt_vec)
        contact_pt_vec = np.array([contact_pt_vec[0], contact_pt_vec[1], 0])
        linear_v = np.cross(linear_v,contact_pt_vec)[:2]
        return tran_vel + linear_v
    def get_cur_vel_at_contact(self, contact_angle):
        # get the contact point velocity based on the object current velocity
        return self.get_vel_at_contact(contact_angle, self.tran_vel, self.rot_vel)
    
    
class BlockSlider(Slider):
    def __init__(self, transform, shape):
        super().__init__(transform, shape)
        self.width = shape[0]
        self.height = shape[1]
        shape = np.array(shape)
        self.shape = np.array(shape[:2])
        self.type = 'block'
        mins = -shape/2
        maxs = shape/2
        resols = np.array([0.01, 0.01])
        self.geo = BlockShape(shape, mins, maxs, resols)
        
    def get_contact_pt(self, contact_angle):
        pt = np.array([np.cos(contact_angle),np.sin(contact_angle)])
        # map to rectangular
        ratio = np.array([self.width,self.height])/2/np.abs(pt)
        ratio = np.min(ratio)
        pt = pt * ratio
        return pt
    def get_contact_pt_in_world(self, contact_angle):
        contact_pt = self.get_contact_pt(contact_angle)
        return self.tf_mat[:2,:2].dot(contact_pt) + self.tf_mat[:2,2]
    def get_normal_local(self, contact_angle):
        # this is useful to project the velocity to ignore friction
        pt = self.get_contact_pt(contact_angle)
        if (pt[0] > -self.width/2) and (pt[0] < self.width/2):
            norm = -np.array([0,np.sign(pt[1])])
        if (pt[1] > -self.height/2) and (pt[1] < self.height/2):
            norm = -np.array([np.sign(pt[0]),0])
        return norm
    def get_vel_at_contact(self, contact_angle, tran_vel, rot_vel):
        pt = self.get_contact_pt(contact_angle)
        linear_v = rot_vel * np.linalg.norm(pt)
        linear_v = np.array([0,0,linear_v])
        # get the vector pointing from the COM to the contact point. This is useful to get the
        # linear velocity at the contact point
        contact_pt = self.get_contact_pt(contact_angle)
        contact_pt_vec = self.tf_mat[:2,:2].dot(contact_pt)
        contact_pt_vec = contact_pt_vec / np.linalg.norm(contact_pt_vec)
        contact_pt_vec = np.array([contact_pt_vec[0], contact_pt_vec[1], 0])
        linear_v = np.cross(linear_v,contact_pt_vec)[:2]
        return tran_vel + linear_v
    def get_cur_vel_at_contact(self, contact_angle):
        # get the contact point velocity based on the object current velocity
        return self.get_vel_at_contact(contact_angle, self.tran_vel, self.rot_vel)

    
    

# TODO: what about robot models? How to infer that?
# maybe we can randomly select a point on the robot arm geometry, and assuming convex shape. Then
# iteratively refine until the robot geometry roughly covers the point and is normal to that.
# This pushing motion will be noisy, so we need a controller to decide the velocity after a certain
# period for feedback control

class System:
    def __init__(self, slider: Slider, dt):
        self.slider = slider
        self.dt = dt
    def get_contact_point(self, pusher_pt):
        """
        at current slider transform, get the current contact point given the pusher point in the world frame
        """
        pass
    def update_slider_transform(self, s0, v0, v1):
        """
        v0: velocity before updating the velocity of the slider. (e.g. default is static)
        v1: velocity after update
        both v0 and v1 are of form [vx, vy, omega]
        """
        # we use a simple euler integration
        s1 = s0 + self.dt * v1
        self.slider.update_transform(s1)
        return s1
    
    def get_vel_in_local(self, vel):
        """
        given a velocity in the global frame, get the relative velocity in the local frame
        """
        tf_mat = self.slider.tf_mat
        tf_mat = np.linalg.inv(tf_mat)
        return tf_mat[:2,:2].dot(vel)

    def update_slider_rel(self, contact_angle, pusher_rel_vel):
        """
        given the contact angle, update the slider velocity and transform.
        The pusher_rel_velocity is in the frame of the slider
        NOTE: in quasi-static assumption, we basically assume that the contact velocity is equivalent
        to the pusher velocity in the slider after the pusher-slider friction effect
        NOTE: the pusher and slider may lose contact if we don't project one to the other. We need
        to update the slider by projecting it at the contact to the pusher afterward.
        """
        # frictionless: we ignore the tangent velocity to the boundary, and only take the normal velocity
        print('input pusher_rel_vel: ', pusher_rel_vel)
        norm = self.slider.get_normal_local(contact_angle)
#         print('norm: ', norm)
        projection = pusher_rel_vel.dot(norm)
        projection = max(projection, 0)  # ignore when the object is departing
        pusher_rel_vel = projection * norm
        print('contact_angle: ', contact_angle)
        print('norm: ', norm)
        print('projection: ', projection)
        print('pusher_rel_vel: ', pusher_rel_vel)
        
        # if the pusher velociy is not pointing inside the object, then ignore
        
    
        pusher_vel = self.slider.tf_mat[:2,:2].dot(pusher_rel_vel)
        pt = self.slider.get_contact_pt(contact_angle)
        # get pt in the global
        pt_global = self.slider.tf_mat[:2,:2].dot(pt) + self.slider.tf_mat[:2,2]
        
        # quasi-static: don't count previous velocities anymore
        friction = np.array(pusher_rel_vel)
        friction = np.array([friction[0], friction[1], 0])
        friction = friction / np.linalg.norm(friction)
        f = self.slider.get_total_friction_at_pt(friction, pt)
        vel_dir = self.slider.get_ls_vel(f)  # this is normalized velocity. Only a direction
        # match the velocity of the pusher: the contact point needs to have similiar velocity size
        vel_contact = self.slider.get_vel_at_contact(contact_angle, vel_dir[:2], vel_dir[2])
        vel_scale = np.linalg.norm(pusher_rel_vel) / np.linalg.norm(vel_contact)
        vel_slider = vel_dir * vel_scale
        vel_dx = pusher_rel_vel - vel_contact * vel_scale
        
        
        self.slider.tran_vel = [0,0]
        self.slider.rot_vel = 0
        tran_vel = self.slider.tran_vel + self.slider.tf_mat[:2,:2].dot(vel_slider[:2])
        rot_vel = self.slider.rot_vel + vel_slider[2]
        
        tran_vel += self.slider.tf_mat[:2,:2].dot(vel_dx)
        v0 = np.array([self.slider.tran_vel[0],self.slider.tran_vel[1],self.slider.rot_vel])
        v1 = np.array([tran_vel[0],tran_vel[1],rot_vel])
        
        print('slider velocity: ', vel_slider)
        print('pusher velocity: ', pusher_rel_vel)
        print('contact velocity: ', vel_contact)

        
        
        transform = self.update_slider_transform(self.slider.transform, v0, v1)

        new_pt = self.slider.get_contact_pt_in_world(contact_angle)
        pt_dx = new_pt - pt_global
        print('new contact point: ', new_pt)
#         print('slider vs pusher: ', pt_dx - pusher_vel * dt)
#         print('pusher travel: ', pusher_vel * dt)

        # project the contact point to the pusher new waypoint
#         new_pt = self.slider.get_contact_pt_in_world(contact_angle)
#         # get the translation of the contact point
        dx = pusher_vel * self.dt - (new_pt - pt_global)
        tran_vel += dx  # project the slider so that the pusher is at the boundary
        transform[:2] += dx
#         # TODO: add cone control afterward



        self.slider.update_transform(transform)
        self.slider.update_vel(tran_vel, rot_vel)

    def update_slider(self, contact_angle, pusher_vel_in_slider):
        """
        given the contact angle, update the slider velocity and transform.
        The pusher_vel_in_slider is in the frame of the slider
        NOTE: in quasi-static assumption, we basically assume that 
        the object becomes static and follows pusher velocity again
        """
        self.update_slider_rel(contact_angle, pusher_vel_in_slider)

# %%
# visualize the velocity and friction in 2D
import matplotlib
# %matplotlib notebook


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib.tri as mtri
import matplotlib as mpl
from IPython import display

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
transform = [0,0,0]
shape = 0.4
cylinder = CylinderSlider(transform, shape)
n_samples = 2500
cylinder.construct_ls_db(n_samples, ax)
f = np.random.normal(size=(3))
f = f / np.linalg.norm(f)
vel = cylinder.get_ls_vel(f, ax=ax, plot_scale=0.4)
print('vel: ', f)
# Out:
# <img src="data:image/png;base64,..." width="640">
# after update_grid
# (2500, 3)
# projected point:  [ 0.13879941 -0.03715252  0.12375643]
# normal:  [ 0.03844979 -0.01318153  0.39792947]
# vel:  [ 0.73193127 -0.19591648  0.65260505]

# %%
print('vel: ', vel)
print("f: ", f)
# Out:
# vel:  [ 0.03844979 -0.01318153  0.39792947]
# f:  [ 0.73193127 -0.19591648  0.65260505]

# %%
f_ = cylinder.get_ls_f(vel)
print(f_/np.linalg.norm(f_))
print(f)
# Out:
# [ 0.64019814 -0.51733169  0.56790339]
# [ 0.73193127 -0.19591648  0.65260505]

# %%
fig, ax = plt.subplots(figsize=(8, 8))

plt.imshow(cylinder.geo.grid)
print(cylinder.geo.grid.sum()/np.prod(cylinder.geo.grid.shape))
# Out:
# <img src="data:image/png;base64,..." width="800">
# 0.785

# %%
# visualize the velocity and friction in 2D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
transform = [0,0,0]
shape = [0.4,0.4]
cylinder = BlockSlider(transform, shape)
n_samples = 5000
cylinder.construct_ls_db(n_samples, ax)
f = np.random.normal(size=(3))
f = f / np.linalg.norm(f)
vel = cylinder.get_ls_vel(f, plot_scale=0.05, ax=ax)
print('vel:', vel)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (5000, 3)
# projected point:  [-0.04166655 -0.05077315  0.02112496]
# normal:  [-0.00271631 -0.00307493  0.04983138]
# vel: [-0.00271631 -0.00307493  0.04983138]

# %%
f_ = cylinder.get_ls_f(vel)
print(f_/np.linalg.norm(f_))
print(f)
# Out:
# [-0.59732575 -0.59105404  0.54208585]
# [-0.60390883 -0.73589853  0.30618209]

# %%
fig, ax = plt.subplots(figsize=(8, 8))

plt.imshow(cylinder.geo.grid)
print(cylinder.geo.grid)
# Out:
# <img src="data:image/png;base64,..." width="800">
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
# visualize the velocity and friction in 2D
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib as mpl
from IPython import display

def get_ori(slider):
    # get the orientation x0, x1, y0, y1 for the slider
    vec = slider.tf_mat[:2,:2].dot([1,0]) * 0.1
    start_pos = slider.transform[:2]
    end_pos = start_pos + vec
    
    return start_pos, end_pos
fig, ax = plt.subplots(figsize=(8, 8))
transform = [0,0,0]
shape = 0.4
cylinder = CylinderSlider(transform, shape)

ax.set_xlim(transform[0]-shape, transform[0]+shape)
ax.set_ylim(transform[1]-shape, transform[1]+shape)


slider_anim = plt.Circle((cylinder.transform[0],cylinder.transform[1]),
                    cylinder.radius, color='b')
start_ori, end_ori = get_ori(cylinder)
# slider_ori_anim, = ax.plot([start_ori[0], end_ori[0]],
#                                [start_ori[1], end_ori[1]],
#                                color='r')
ax.add_patch(slider_anim)

# plot the velocity
vel = [0.1,0.2,0]
arrow = plt.arrow(transform[0],transform[1], vel[0],vel[1], width=0.02,color='r')
ax.add_patch(arrow)

friction = cylinder.get_total_friction_from_v(vel)
arrow = plt.arrow(transform[0],transform[1], friction[0],friction[1], width=0.02,color='black')
ax.add_patch(arrow)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# after update_grid

# %%
# visualize the velocity and friction in 2D
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib as mpl
from IPython import display

def get_ori(slider):
    # get the orientation x0, x1, y0, y1 for the slider
    vec = slider.tf_mat[:2,:2].dot([1,0]) * 0.1
    start_pos = slider.transform[:2]
    end_pos = start_pos + vec
    
    return start_pos, end_pos
transform = [0,0,0]
shape = 0.4
cylinder = CylinderSlider(transform, shape)
# Out:
# after update_grid

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(transform[0]-shape*2, transform[0]+shape*2)
ax.set_ylim(transform[1]-shape*2, transform[1]+shape*2)


slider_anim = plt.Circle((cylinder.transform[0],cylinder.transform[1]),
                    cylinder.radius, color='b')
start_ori, end_ori = get_ori(cylinder)
# slider_ori_anim, = ax.plot([start_ori[0], end_ori[0]],
#                                [start_ori[1], end_ori[1]],
#                                color='r')
ax.add_patch(slider_anim)

# plot the impact force
force = [0,0.1,0]
contact_angle = np.pi/2*3.1
contact_pt = [transform[0]+np.cos(contact_angle), transform[1]+np.sin(contact_angle)]
force = np.array(force)
contact_pt = np.array(contact_pt)
friction = cylinder.get_total_friction_at_pt(force, contact_pt)
print('friction: ', friction)
arrow = plt.arrow(transform[0]+shape*np.cos(contact_angle),transform[1]+shape*np.sin(contact_angle), 
                  force[0],force[1], width=0.02,color='black')
ax.add_patch(arrow)

# vel = [0.1,0.2,0]
vel = cylinder.get_ls_vel(friction)
print('vel: ', vel)
# friction = cylinder.get_total_friction_from_v(vel)
arrow = plt.arrow(transform[0],transform[1], vel[0],vel[1], width=0.02,color='red')
ax.add_patch(arrow)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# friction:  [0.         0.1        0.01564345]
# constructing hull...
# (2500, 3)
# projected point:  [0.         0.40248767 0.06296294]
# normal:  [0.00327848 0.03629405 0.09312354]
# vel:  [0.00327848 0.03629405 0.09312354]

# %%
# visualize the velocity and friction in 2D
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib as mpl
from IPython import display

def get_ori(slider):
    # get the orientation x0, x1, y0, y1 for the slider
    vec = slider.tf_mat[:2,:2].dot([1,0]) * 0.1
    start_pos = slider.transform[:2]
    end_pos = start_pos + vec
    
    return start_pos, end_pos
transform = [0,0,0]
shape = np.array([0.3,0.4])
slider = BlockSlider(transform, shape)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

ax.set_xlim(transform[0]-shape[0], transform[0]+shape[0])
ax.set_ylim(transform[1]-shape[1], transform[1]+shape[1])

contact_angle = np.pi/2*3.2
contact_pt = slider.get_contact_pt(contact_angle)

force = [0,0.1,0]
# contact_pt = [transform[0]+np.cos(contact_angle), transform[1]+np.sin(contact_angle)]
force = np.array(force)
contact_pt = np.array(contact_pt)
friction = slider.get_total_friction_at_pt(force, contact_pt)

slider_anim = plt.Rectangle(slider.transform[:2]-slider.shape/2,
                                 slider.width,
                                 slider.height,
                                 color='b')
transform = slider.transform
t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                transform[2]/np.pi * 180) + ax.transData
slider_anim.set_transform(t)

start_ori, end_ori = get_ori(slider)
# slider_ori_anim, = ax.plot([start_ori[0], end_ori[0]],
#                                [start_ori[1], end_ori[1]],
#                                color='r')
ax.add_patch(slider_anim)

# plot the velocity
# vel = [0.1,0.2,0]
arrow = plt.arrow(transform[0]+contact_pt[0],transform[1]+contact_pt[1], 
                  force[0],force[1], width=0.02,color='black')
ax.add_patch(arrow)

vel = slider.get_ls_vel(friction)
# friction = slider.get_total_friction_from_v(vel)
arrow = plt.arrow(transform[0],transform[1], vel[0],vel[1], width=0.02,color='red')
ax.add_patch(arrow)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# constructing hull...
# (2500, 3)
# projected point:  [0.         0.10372487 0.00674045]
# normal:  [-0.00240364  0.02029384  0.09788964]

# %% [markdown]
# # Now we have a working module to predict point contact -> velocity, and velocity -> friction force. We can predict the slider motion based on a point contact by a pusher.
# Next we can use this analytical model to predict the result of pushing. The steps are the following:
# 1. from the velocity of the pusher, transform the velocity to force, and obtain the velocity of the slider
# 2. simulate the slider. Find the next pusher position
# 3. compare if the pusher is moving accordingly (e.g. if it should be straight and it's not)
#
# **quasi-static: assume previous velocity no longer has effect on the object. The slider is not influenced by its previous velocities.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib as mpl
from IPython import display
"""
implement the animation for the pusher-slider system
"""
class SystemAnimationRelativePusher:
    def __init__(self, slider: Slider, pusher_contact_angle, pusher_rel_vel, dt):
        self.system = System(slider, dt)
        self.pusher_contact_angle = pusher_contact_angle
        self.pusher_rel_vel = pusher_rel_vel
        self.fig, self.ax = plt.subplots(figsize=(8, 8))
    
    def get_ori(self):
        # get the orientation x0, x1, y0, y1 for the slider
        vec = self.system.slider.tf_mat[:2,:2].dot([1,0]) * 0.1
        start_pos = self.system.slider.transform[:2]
        end_pos = start_pos + vec
        return start_pos, end_pos

    def init_anim(self):
        # plot the slider at the start position
        if self.system.slider.type == 'cylinder':
            self.slider_anim = plt.Circle((self.system.slider.transform[0],self.system.slider.transform[1]),
                                self.system.slider.radius, color='b')
            start_ori, end_ori = self.get_ori()
            self.slider_ori_anim, = self.ax.plot([start_ori[0], end_ori[0]],
                                           [start_ori[1], end_ori[1]],
                                           color='r')
        else:
            self.slider_anim = plt.Rectangle(self.system.slider.transform[:2]-self.system.slider.shape/2,
                                             self.system.slider.width,
                                             self.system.slider.height,
                                             color='b')
            transform = self.system.slider.transform
            t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                            transform[2]/np.pi * 180) + self.ax.transData
            self.slider_anim.set_transform(t)
            start_ori, end_ori = self.get_ori()
            self.slider_ori_anim, = self.ax.plot([start_ori[0], end_ori[0]],
                                           [start_ori[1], end_ori[1]],
                                           color='r')
            
        # plot the pusher
        # get the transform of the pusher in the world frame
        pusher_pt = self.system.slider.get_contact_pt_in_world(self.pusher_contact_angle)
        self.pusher_anim = plt.Circle((pusher_pt[0], pusher_pt[1]), 0.01, color='green')
        self.ax.set_xlim(-2, 2)
        self.ax.set_ylim(-2, 2)

        self.ax.add_patch(self.slider_anim)
        self.ax.add_patch(self.pusher_anim)
        return self.slider_anim, self.pusher_anim, self.slider_ori_anim, 
    def step(self, i):
        print('step: ', i)
        # update the slider based on the pusher
        self.system.update_slider(self.pusher_contact_angle, self.pusher_rel_vel)
        if self.system.slider.type == 'cylinder':
            self.slider_anim.center = self.system.slider.transform[0],self.system.slider.transform[1]
        else:
            transform = self.system.slider.transform
            self.slider_anim.set_xy([transform[0]-self.system.slider.width/2, 
                                     transform[1]-self.system.slider.height/2])
            t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                            transform[2]/np.pi * 180) + self.ax.transData
            self.slider_anim.set_transform(t)      
        start_ori, end_ori = self.get_ori()
#         print('start ori: ', start_ori)
#         print('start ori: ', start_ori)

        self.slider_ori_anim.set_xdata([start_ori[0], end_ori[0]])
        self.slider_ori_anim.set_ydata([start_ori[1], end_ori[1]])

        # get the relative position again
        pusher_pt = self.system.slider.get_contact_pt_in_world(self.pusher_contact_angle)
        self.pusher_anim.center = pusher_pt[0],pusher_pt[1]
        
        return self.slider_anim, self.pusher_anim,
    def anim(self):
        ani = FuncAnimation(self.fig, self.step, frames=np.arange(0,400,1),
                            init_func=self.init_anim, interval=int(1000*dt), blit=False)
        video = ani.to_html5_video()
        html = display.HTML(video)
        display.display(html)
        plt.close()

# %%
# slider = CylinderSlider([0,0,0], 0.2)
slider = BlockSlider([0,0,0], [0.2,0.2])

pusher_contact_angle = 3/2*np.pi + 30*np.pi/180
pusher_rel_vel = np.array([0,0.1])
dt = 0.01
anim = SystemAnimationRelativePusher(slider, pusher_contact_angle, pusher_rel_vel, dt)
# anim.anim()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Now we implement a simulator for a pusher pushing a slider. The pusher is independent of the slider, and follows an open-loop trajectory.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib as mpl
from IPython import display
"""
implement the animation for the pusher-slider system
"""
class SystemAnimationPusher:
    def __init__(self, slider: Slider, pusher_start, pusher_vels, pusher_durs, dt):
        self.system = System(slider, dt)
        self.pusher_start = pusher_start
        self.pusher_vels = pusher_vels
        self.pusher_durs = pusher_durs
        self.fig, self.ax = plt.subplots(figsize=(8, 8))
        self.pusher_pt = pusher_start
        self.dt = dt
    def get_ori(self):
        # get the orientation x0, x1, y0, y1 for the slider
        vec = self.system.slider.tf_mat[:2,:2].dot([1,0]) * 0.1
        start_pos = self.system.slider.transform[:2]
        end_pos = start_pos + vec
        return start_pos, end_pos

    def init_anim(self):
        # plot the slider at the start position
        if self.system.slider.type == 'cylinder':
            self.slider_anim = plt.Circle((self.system.slider.transform[0],self.system.slider.transform[1]),
                                self.system.slider.radius, color='b')
            start_ori, end_ori = self.get_ori()
            self.slider_ori_anim, = self.ax.plot([start_ori[0], end_ori[0]],
                                           [start_ori[1], end_ori[1]],
                                           color='r')
        else:
            self.slider_anim = plt.Rectangle(self.system.slider.transform[:2]-self.system.slider.shape/2,
                                             self.system.slider.width,
                                             self.system.slider.height,
                                             color='b')
            transform = self.system.slider.transform
            t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                            transform[2]/np.pi * 180) + self.ax.transData
            self.slider_anim.set_transform(t)
            start_ori, end_ori = self.get_ori()
            self.slider_ori_anim, = self.ax.plot([start_ori[0], end_ori[0]],
                                           [start_ori[1], end_ori[1]],
                                           color='r')
            
        # plot the pusher
        # get the transform of the pusher in the world frame
        self.pusher_pt = self.pusher_start
        self.pusher_anim = plt.Circle((self.pusher_start[0], self.pusher_start[1]), 0.01, color='red')
        self.ax.set_xlim(-2, 2)
        self.ax.set_ylim(-2, 2)

        self.ax.add_patch(self.slider_anim)
        self.ax.add_patch(self.pusher_anim)
        return self.slider_anim, self.pusher_anim, self.slider_ori_anim, 
    def step(self, i):
        print('step: ', i)
        # update the slider based on the pusher
        # compute the pusher contact angle
        pusher_contact_angle = self.system.slider.get_contact_angle_from_global(self.pusher_pt)
        print('pusher_contact_angle: ', pusher_contact_angle)
        # check if the pusher is at the boundary of the slider
        if self.system.slider.global_inside(self.pusher_pt):
            # convert the pusher_vel to the frame of the slider
            print('pusher inside the slider')
            rel_vel = self.system.get_vel_in_local(self.pusher_vels[0])
            self.system.update_slider(pusher_contact_angle, rel_vel)
        if self.system.slider.type == 'cylinder':
            self.slider_anim.center = self.system.slider.transform[0],self.system.slider.transform[1]
        else:
            transform = self.system.slider.transform
            self.slider_anim.set_xy([transform[0]-self.system.slider.width/2, 
                                     transform[1]-self.system.slider.height/2])
            t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                            transform[2]/np.pi * 180) + self.ax.transData
            self.slider_anim.set_transform(t)      
        start_ori, end_ori = self.get_ori()
#         print('start ori: ', start_ori)
#         print('start ori: ', start_ori)

        self.slider_ori_anim.set_xdata([start_ori[0], end_ori[0]])
        self.slider_ori_anim.set_ydata([start_ori[1], end_ori[1]])

        # get the relative position again
        self.pusher_pt = self.pusher_pt + pusher_vels[0] * self.dt
        print('new pusher_pt: ', self.pusher_pt)
        self.pusher_anim.center = self.pusher_pt[0],self.pusher_pt[1]
        
        return self.slider_anim, self.pusher_anim,
    def anim(self):
        ani = FuncAnimation(self.fig, self.step, frames=np.arange(0,800,1),
                            init_func=self.init_anim, interval=int(1000*dt), blit=False)
        video = ani.to_html5_video()
        html = display.HTML(video)
        display.display(html)
        plt.close()

# %%
# slider = CylinderSlider([0,0,0], 0.2)
slider = BlockSlider([0,0,0], [0.2,0.2])

dt = 0.005
pusher_start = np.array([0.04,-0.2])
pusher_vels = np.array([[0,0.1]])
pusher_durs = np.array([0.5])
anim = SystemAnimationPusher(slider, pusher_start, pusher_vels, pusher_durs, dt)
anim.anim()
# Out:
# <img src="data:image/png;base64,..." width="800">
# step:  0
# pusher_contact_angle:  -1.373400766945016
# new pusher_pt:  [ 0.04   -0.1995]
# step:  1
# pusher_contact_angle:  -1.3729188392714824
# new pusher_pt:  [ 0.04  -0.199]
# step:  2
# pusher_contact_angle:  -1.372434583670784
# new pusher_pt:  [ 0.04   -0.1985]
# step:  3
# pusher_contact_angle:  -1.3719479834634567
# new pusher_pt:  [ 0.04  -0.198]
# step:  4
# pusher_contact_angle:  -1.3714590218125726
# new pusher_pt:  [ 0.04   -0.1975]
# step:  5
# pusher_contact_angle:  -1.3709676817219063
# new pusher_pt:  [ 0.04  -0.197]
# step:  6
# pusher_contact_angle:  -1.370473946034075
# new pusher_pt:  [ 0.04   -0.1965]
# step:  7
# pusher_contact_angle:  -1.3699777974286518
# new pusher_pt:  [ 0.04  -0.196]
# step:  8
# pusher_contact_angle:  -1.3694792184202558
# new pusher_pt:  [ 0.04   -0.1955]
# step:  9
# pusher_contact_angle:  -1.3689781913566135
# new pusher_pt:  [ 0.04  -0.195]
# step:  10
# pusher_contact_angle:  -1.368474698416593
# new pusher_pt:  [ 0.04   -0.1945]
# step:  11
# pusher_contact_angle:  -1.3679687216082126
# new pusher_pt:  [ 0.04  -0.194]
# step:  12
# pusher_contact_angle:  -1.367460242766621
# new pusher_pt:  [ 0.04   -0.1935]
# step:  13
# pusher_contact_angle:  -1.3669492435520472
# new pusher_pt:  [ 0.04  -0.193]
# step:  14
# pusher_contact_angle:  -1.3664357054477256
# new pusher_pt:  [ 0.04   -0.1925]
# step:  15
# pusher_contact_angle:  -1.3659196097577881
# new pusher_pt:  [ 0.04  -0.192]
# step:  16
# pusher_contact_angle:  -1.3654009376051293
# new pusher_pt:  [ 0.04   -0.1915]
# step:  17
# pusher_contact_angle:  -1.3648796699292396
# new pusher_pt:  [ 0.04  -0.191]
# step:  18
# pusher_contact_angle:  -1.3643557874840098
# new pusher_pt:  [ 0.04   -0.1905]
# step:  19
# pusher_contact_angle:  -1.3638292708355026
# new pusher_pt:  [ 0.04 -0.19]
# step:  20
# pusher_contact_angle:  -1.3633001003596938
# new pusher_pt:  [ 0.04   -0.1895]
# step:  21
# pusher_contact_angle:  -1.362768256240181
# new pusher_pt:  [ 0.04  -0.189]
# step:  22
# pusher_contact_angle:  -1.3622337184658595
# new pusher_pt:  [ 0.04   -0.1885]
# step:  23
# pusher_contact_angle:  -1.3616964668285652
# new pusher_pt:  [ 0.04  -0.188]
# step:  24
# pusher_contact_angle:  -1.3611564809206842
# new pusher_pt:  [ 0.04   -0.1875]
# step:  25
# pusher_contact_angle:  -1.3606137401327272
# new pusher_pt:  [ 0.04  -0.187]
# step:  26
# pusher_contact_angle:  -1.36006822365087
# new pusher_pt:  [ 0.04   -0.1865]
# step:  27
# pusher_contact_angle:  -1.3595199104544593
# new pusher_pt:  [ 0.04  -0.186]
# step:  28
# pusher_contact_angle:  -1.358968779313479
# new pusher_pt:  [ 0.04   -0.1855]
# step:  29
# pusher_contact_angle:  -1.3584148087859853
# new pusher_pt:  [ 0.04  -0.185]
# step:  30
# pusher_contact_angle:  -1.3578579772154995
# new pusher_pt:  [ 0.04   -0.1845]
# step:  31
# pusher_contact_angle:  -1.357298262728367
# new pusher_pt:  [ 0.04  -0.184]
# step:  32
# pusher_contact_angle:  -1.356735643231075
# new pusher_pt:  [ 0.04   -0.1835]
# step:  33
# pusher_contact_angle:  -1.3561700964075338
# new pusher_pt:  [ 0.04  -0.183]
# step:  34
# pusher_contact_angle:  -1.3556015997163156
# new pusher_pt:  [ 0.04   -0.1825]
# step:  35
# pusher_contact_angle:  -1.3550301303878542
# new pusher_pt:  [ 0.04  -0.182]
# step:  36
# pusher_contact_angle:  -1.354455665421606
# new pusher_pt:  [ 0.04   -0.1815]
# step:  37
# pusher_contact_angle:  -1.3538781815831644
# new pusher_pt:  [ 0.04  -0.181]
# step:  38
# pusher_contact_angle:  -1.353297655401336
# new pusher_pt:  [ 0.04   -0.1805]
# step:  39
# pusher_contact_angle:  -1.3527140631651717
# new pusher_pt:  [ 0.04 -0.18]
# step:  40
# pusher_contact_angle:  -1.3521273809209546
# new pusher_pt:  [ 0.04   -0.1795]
# step:  41
# pusher_contact_angle:  -1.3515375844691428
# new pusher_pt:  [ 0.04  -0.179]
# step:  42
# pusher_contact_angle:  -1.3509446493612678
# new pusher_pt:  [ 0.04   -0.1785]
# step:  43
# pusher_contact_angle:  -1.3503485508967845
# new pusher_pt:  [ 0.04  -0.178]
# step:  44
# pusher_contact_angle:  -1.3497492641198778
# new pusher_pt:  [ 0.04   -0.1775]
# step:  45
# pusher_contact_angle:  -1.3491467638162191
# new pusher_pt:  [ 0.04  -0.177]
# step:  46
# pusher_contact_angle:  -1.3485410245096736
# new pusher_pt:  [ 0.04   -0.1765]
# step:  47
# pusher_contact_angle:  -1.3479320204589609
# new pusher_pt:  [ 0.04  -0.176]
# step:  48
# pusher_contact_angle:  -1.3473197256542635
# new pusher_pt:  [ 0.04   -0.1755]
# step:  49
# pusher_contact_angle:  -1.3467041138137845
# new pusher_pt:  [ 0.04  -0.175]
# step:  50
# pusher_contact_angle:  -1.346085158380254
# new pusher_pt:  [ 0.04   -0.1745]
# step:  51
# pusher_contact_angle:  -1.3454628325173812
# new pusher_pt:  [ 0.04  -0.174]
# step:  52
# pusher_contact_angle:  -1.3448371091062559
# new pusher_pt:  [ 0.04   -0.1735]
# step:  53
# pusher_contact_angle:  -1.344207960741691
# new pusher_pt:  [ 0.04  -0.173]
# step:  54
# pusher_contact_angle:  -1.3435753597285138
# new pusher_pt:  [ 0.04   -0.1725]
# step:  55
# pusher_contact_angle:  -1.342939278077797
# new pusher_pt:  [ 0.04  -0.172]
# step:  56
# pusher_contact_angle:  -1.3422996875030342
# new pusher_pt:  [ 0.04   -0.1715]
# step:  57
# pusher_contact_angle:  -1.3416565594162577
# new pusher_pt:  [ 0.04  -0.171]
# step:  58
# pusher_contact_angle:  -1.3410098649240938
# new pusher_pt:  [ 0.04   -0.1705]
# step:  59
# pusher_contact_angle:  -1.34035957482376
# new pusher_pt:  [ 0.04 -0.17]
# step:  60
# pusher_contact_angle:  -1.3397056595989996
# new pusher_pt:  [ 0.04   -0.1695]
# step:  61
# pusher_contact_angle:  -1.3390480894159535
# new pusher_pt:  [ 0.04  -0.169]
# step:  62
# pusher_contact_angle:  -1.338386834118969
# new pusher_pt:  [ 0.04   -0.1685]
# step:  63
# pusher_contact_angle:  -1.3377218632263423
# new pusher_pt:  [ 0.04  -0.168]
# step:  64
# pusher_contact_angle:  -1.3370531459259951
# new pusher_pt:  [ 0.04   -0.1675]
# step:  65
# pusher_contact_angle:  -1.3363806510710858
# new pusher_pt:  [ 0.04  -0.167]
# step:  66
# pusher_contact_angle:  -1.3357043471755492
# new pusher_pt:  [ 0.04   -0.1665]
# step:  67
# pusher_contact_angle:  -1.3350242024095695
# new pusher_pt:  [ 0.04  -0.166]
# step:  68
# pusher_contact_angle:  -1.3343401845949794
# new pusher_pt:  [ 0.04   -0.1655]
# step:  69
# pusher_contact_angle:  -1.3336522612005903
# new pusher_pt:  [ 0.04  -0.165]
# step:  70
# pusher_contact_angle:  -1.332960399337446
# new pusher_pt:  [ 0.04   -0.1645]
# step:  71
# pusher_contact_angle:  -1.332264565754003
# new pusher_pt:  [ 0.04  -0.164]
# step:  72
# pusher_contact_angle:  -1.331564726831236
# new pusher_pt:  [ 0.04   -0.1635]
# step:  73
# pusher_contact_angle:  -1.3308608485776625
# new pusher_pt:  [ 0.04  -0.163]
# step:  74
# pusher_contact_angle:  -1.3301528966242921
# new pusher_pt:  [ 0.04   -0.1625]
# step:  75
# pusher_contact_angle:  -1.3294408362194927
# new pusher_pt:  [ 0.04  -0.162]
# step:  76
# pusher_contact_angle:  -1.3287246322237776
# new pusher_pt:  [ 0.04   -0.1615]
# step:  77
# pusher_contact_angle:  -1.3280042491045065
# new pusher_pt:  [ 0.04  -0.161]
# step:  78
# pusher_contact_angle:  -1.3272796509305047
# new pusher_pt:  [ 0.04   -0.1605]
# step:  79
# pusher_contact_angle:  -1.3265508013665928
# new pusher_pt:  [ 0.04 -0.16]
# step:  80
# pusher_contact_angle:  -1.3258176636680323
# new pusher_pt:  [ 0.04   -0.1595]
# step:  81
# pusher_contact_angle:  -1.325080200674879
# new pusher_pt:  [ 0.04  -0.159]
# step:  82
# pusher_contact_angle:  -1.3243383748062454
# new pusher_pt:  [ 0.04   -0.1585]
# step:  83
# pusher_contact_angle:  -1.3235921480544726
# new pusher_pt:  [ 0.04  -0.158]
# step:  84
# pusher_contact_angle:  -1.3228414819792058
# new pusher_pt:  [ 0.04   -0.1575]
# step:  85
# pusher_contact_angle:  -1.3220863377013736
# new pusher_pt:  [ 0.04  -0.157]
# step:  86
# pusher_contact_angle:  -1.3213266758970719
# new pusher_pt:  [ 0.04   -0.1565]
# step:  87
# pusher_contact_angle:  -1.3205624567913434
# new pusher_pt:  [ 0.04  -0.156]
# step:  88
# pusher_contact_angle:  -1.319793640151862
# new pusher_pt:  [ 0.04   -0.1555]
# step:  89
# pusher_contact_angle:  -1.319020185282507
# new pusher_pt:  [ 0.04  -0.155]
# step:  90
# pusher_contact_angle:  -1.318242051016837
# new pusher_pt:  [ 0.04   -0.1545]
# step:  91
# pusher_contact_angle:  -1.3174591957114548
# new pusher_pt:  [ 0.04  -0.154]
# step:  92
# pusher_contact_angle:  -1.3166715772392625
# new pusher_pt:  [ 0.04   -0.1535]
# step:  93
# pusher_contact_angle:  -1.3158791529826057
# new pusher_pt:  [ 0.04  -0.153]
# step:  94
# pusher_contact_angle:  -1.3150818798263055
# new pusher_pt:  [ 0.04   -0.1525]
# step:  95
# pusher_contact_angle:  -1.314279714150573
# new pusher_pt:  [ 0.04  -0.152]
# step:  96
# pusher_contact_angle:  -1.3134726118238078
# new pusher_pt:  [ 0.04   -0.1515]
# step:  97
# pusher_contact_angle:  -1.3126605281952766
# new pusher_pt:  [ 0.04  -0.151]
# step:  98
# pusher_contact_angle:  -1.3118434180876684
# new pusher_pt:  [ 0.04   -0.1505]
# step:  99
# pusher_contact_angle:  -1.3110212357895268
# new pusher_pt:  [ 0.04 -0.15]
# step:  100
# pusher_contact_angle:  -1.3101939350475555
# new pusher_pt:  [ 0.04   -0.1495]
# step:  101
# pusher_contact_angle:  -1.3093614690587938
# new pusher_pt:  [ 0.04  -0.149]
# step:  102
# pusher_contact_angle:  -1.3085237904626612
# new pusher_pt:  [ 0.04   -0.1485]
# step:  103
# pusher_contact_angle:  -1.3076808513328686
# new pusher_pt:  [ 0.04  -0.148]
# step:  104
# pusher_contact_angle:  -1.306832603169192
# new pusher_pt:  [ 0.04   -0.1475]
# step:  105
# pusher_contact_angle:  -1.3059789968891078
# new pusher_pt:  [ 0.04  -0.147]
# step:  106
# pusher_contact_angle:  -1.3051199828192857
# new pusher_pt:  [ 0.04   -0.1465]
# step:  107
# pusher_contact_angle:  -1.3042555106869385
# new pusher_pt:  [ 0.04  -0.146]
# step:  108
# pusher_contact_angle:  -1.303385529611023
# new pusher_pt:  [ 0.04   -0.1455]
# step:  109
# pusher_contact_angle:  -1.3025099880932927
# new pusher_pt:  [ 0.04  -0.145]
# step:  110
# pusher_contact_angle:  -1.3016288340091962
# new pusher_pt:  [ 0.04   -0.1445]
# step:  111
# pusher_contact_angle:  -1.3007420145986204
# new pusher_pt:  [ 0.04  -0.144]
# step:  112
# pusher_contact_angle:  -1.299849476456476
# new pusher_pt:  [ 0.04   -0.1435]
# step:  113
# pusher_contact_angle:  -1.2989511655231194
# new pusher_pt:  [ 0.04  -0.143]
# step:  114
# pusher_contact_angle:  -1.2980470270746114
# new pusher_pt:  [ 0.04   -0.1425]
# step:  115
# pusher_contact_angle:  -1.2971370057128062
# new pusher_pt:  [ 0.04  -0.142]
# step:  116
# pusher_contact_angle:  -1.2962210453552712
# new pusher_pt:  [ 0.04   -0.1415]
# step:  117
# pusher_contact_angle:  -1.2952990892250305
# new pusher_pt:  [ 0.04  -0.141]
# step:  118
# pusher_contact_angle:  -1.2943710798401311
# new pusher_pt:  [ 0.04   -0.1405]
# step:  119
# pusher_contact_angle:  -1.2934369590030284
# new pusher_pt:  [ 0.04 -0.14]
# step:  120
# pusher_contact_angle:  -1.2924966677897851
# new pusher_pt:  [ 0.04   -0.1395]
# step:  121
# pusher_contact_angle:  -1.291550146539084
# new pusher_pt:  [ 0.04  -0.139]
# step:  122
# pusher_contact_angle:  -1.290597334841046
# new pusher_pt:  [ 0.04   -0.1385]
# step:  123
# pusher_contact_angle:  -1.2896381715258551
# new pusher_pt:  [ 0.04  -0.138]
# step:  124
# pusher_contact_angle:  -1.288672594652181
# new pusher_pt:  [ 0.04   -0.1375]
# step:  125
# pusher_contact_angle:  -1.287700541495401
# new pusher_pt:  [ 0.04  -0.137]
# step:  126
# pusher_contact_angle:  -1.2867219485356112
# new pusher_pt:  [ 0.04   -0.1365]
# step:  127
# pusher_contact_angle:  -1.285736751445429
# new pusher_pt:  [ 0.04  -0.136]
# step:  128
# pusher_contact_angle:  -1.2847448850775782
# new pusher_pt:  [ 0.04   -0.1355]
# step:  129
# pusher_contact_angle:  -1.2837462834522555
# new pusher_pt:  [ 0.04  -0.135]
# step:  130
# pusher_contact_angle:  -1.2827408797442708
# new pusher_pt:  [ 0.04   -0.1345]
# step:  131
# pusher_contact_angle:  -1.2817286062699604
# new pusher_pt:  [ 0.04  -0.134]
# step:  132
# pusher_contact_angle:  -1.2807093944738683
# new pusher_pt:  [ 0.04   -0.1335]
# step:  133
# pusher_contact_angle:  -1.2796831749151862
# new pusher_pt:  [ 0.04  -0.133]
# step:  134
# pusher_contact_angle:  -1.2786498772539545
# new pusher_pt:  [ 0.04   -0.1325]
# step:  135
# pusher_contact_angle:  -1.2776094302370142
# new pusher_pt:  [ 0.04  -0.132]
# step:  136
# pusher_contact_angle:  -1.2765617616837088
# new pusher_pt:  [ 0.04   -0.1315]
# step:  137
# pusher_contact_angle:  -1.275506798471326
# new pusher_pt:  [ 0.04  -0.131]
# step:  138
# pusher_contact_angle:  -1.2744444665202816
# new pusher_pt:  [ 0.04   -0.1305]
# step:  139
# pusher_contact_angle:  -1.273374690779032
# new pusher_pt:  [ 0.04 -0.13]
# step:  140
# pusher_contact_angle:  -1.2722973952087173
# new pusher_pt:  [ 0.04   -0.1295]
# step:  141
# pusher_contact_angle:  -1.2712125027675245
# new pusher_pt:  [ 0.04  -0.129]
# step:  142
# pusher_contact_angle:  -1.270119935394769
# new pusher_pt:  [ 0.04   -0.1285]
# step:  143
# pusher_contact_angle:  -1.2690196139946854
# new pusher_pt:  [ 0.04  -0.128]
# step:  144
# pusher_contact_angle:  -1.2679114584199251
# new pusher_pt:  [ 0.04   -0.1275]
# step:  145
# pusher_contact_angle:  -1.266795387454752
# new pusher_pt:  [ 0.04  -0.127]
# step:  146
# pusher_contact_angle:  -1.2656713187979323
# new pusher_pt:  [ 0.04   -0.1265]
# step:  147
# pusher_contact_angle:  -1.264539169045312
# new pusher_pt:  [ 0.04  -0.126]
# step:  148
# pusher_contact_angle:  -1.263398853672075
# new pusher_pt:  [ 0.04   -0.1255]
# step:  149
# pusher_contact_angle:  -1.2622502870146755
# new pusher_pt:  [ 0.04  -0.125]
# step:  150
# pusher_contact_angle:  -1.2610933822524404
# new pusher_pt:  [ 0.04   -0.1245]
# step:  151
# pusher_contact_angle:  -1.2599280513888311
# new pusher_pt:  [ 0.04  -0.124]
# step:  152
# pusher_contact_angle:  -1.2587542052323633
# new pusher_pt:  [ 0.04   -0.1235]
# step:  153
# pusher_contact_angle:  -1.2575717533771713
# new pusher_pt:  [ 0.04  -0.123]
# step:  154
# pusher_contact_angle:  -1.2563806041832168
# new pusher_pt:  [ 0.04   -0.1225]
# step:  155
# pusher_contact_angle:  -1.25518066475613
# new pusher_pt:  [ 0.04  -0.122]
# step:  156
# pusher_contact_angle:  -1.2539718409266774
# new pusher_pt:  [ 0.04   -0.1215]
# step:  157
# pusher_contact_angle:  -1.252754037229848
# new pusher_pt:  [ 0.04  -0.121]
# step:  158
# pusher_contact_angle:  -1.2515271568835549
# new pusher_pt:  [ 0.04   -0.1205]
# step:  159
# pusher_contact_angle:  -1.250291101766936
# new pusher_pt:  [ 0.04 -0.12]
# step:  160
# pusher_contact_angle:  -1.2490457723982542
# new pusher_pt:  [ 0.04   -0.1195]
# step:  161
# pusher_contact_angle:  -1.2477910679123838
# new pusher_pt:  [ 0.04  -0.119]
# step:  162
# pusher_contact_angle:  -1.2465268860378773
# new pusher_pt:  [ 0.04   -0.1185]
# step:  163
# pusher_contact_angle:  -1.2452531230736053
# new pusher_pt:  [ 0.04  -0.118]
# step:  164
# pusher_contact_angle:  -1.2439696738649557
# new pusher_pt:  [ 0.04   -0.1175]
# step:  165
# pusher_contact_angle:  -1.242676431779591
# new pusher_pt:  [ 0.04  -0.117]
# step:  166
# pusher_contact_angle:  -1.2413732886827489
# new pusher_pt:  [ 0.04   -0.1165]
# step:  167
# pusher_contact_angle:  -1.2400601349120794
# new pusher_pt:  [ 0.04  -0.116]
# step:  168
# pusher_contact_angle:  -1.238736859252011
# new pusher_pt:  [ 0.04   -0.1155]
# step:  169
# pusher_contact_angle:  -1.2374033489076317
# new pusher_pt:  [ 0.04  -0.115]
# step:  170
# pusher_contact_angle:  -1.2360594894780819
# new pusher_pt:  [ 0.04   -0.1145]
# step:  171
# pusher_contact_angle:  -1.2347051649294425
# new pusher_pt:  [ 0.04  -0.114]
# step:  172
# pusher_contact_angle:  -1.2333402575671149
# new pusher_pt:  [ 0.04   -0.1135]
# step:  173
# pusher_contact_angle:  -1.231964648007678
# new pusher_pt:  [ 0.04  -0.113]
# step:  174
# pusher_contact_angle:  -1.2305782151502132
# new pusher_pt:  [ 0.04   -0.1125]
# step:  175
# pusher_contact_angle:  -1.2291808361470893
# new pusher_pt:  [ 0.04  -0.112]
# step:  176
# pusher_contact_angle:  -1.227772386374193
# new pusher_pt:  [ 0.04   -0.1115]
# step:  177
# pusher_contact_angle:  -1.2263527394005975
# new pusher_pt:  [ 0.04  -0.111]
# step:  178
# pusher_contact_angle:  -1.224921766957655
# new pusher_pt:  [ 0.04   -0.1105]
# step:  179
# pusher_contact_angle:  -1.223479338907506
# new pusher_pt:  [ 0.04 -0.11]
# step:  180
# pusher_contact_angle:  -1.2220253232109894
# new pusher_pt:  [ 0.04   -0.1095]
# step:  181
# pusher_contact_angle:  -1.220559585894945
# new pusher_pt:  [ 0.04  -0.109]
# step:  182
# pusher_contact_angle:  -1.2190819910188966
# new pusher_pt:  [ 0.04   -0.1085]
# step:  183
# pusher_contact_angle:  -1.2175924006411014
# new pusher_pt:  [ 0.04  -0.108]
# step:  184
# pusher_contact_angle:  -1.2160906747839562
# new pusher_pt:  [ 0.04   -0.1075]
# step:  185
# pusher_contact_angle:  -1.2145766713987463
# new pusher_pt:  [ 0.04  -0.107]
# step:  186
# pusher_contact_angle:  -1.2130502463297257
# new pusher_pt:  [ 0.04   -0.1065]
# step:  187
# pusher_contact_angle:  -1.2115112532775154
# new pusher_pt:  [ 0.04  -0.106]
# step:  188
# pusher_contact_angle:  -1.2099595437618056
# new pusher_pt:  [ 0.04   -0.1055]
# step:  189
# pusher_contact_angle:  -1.208394967083353
# new pusher_pt:  [ 0.04  -0.105]
# step:  190
# pusher_contact_angle:  -1.2068173702852523
# new pusher_pt:  [ 0.04   -0.1045]
# step:  191
# pusher_contact_angle:  -1.2052265981134787
# new pusher_pt:  [ 0.04  -0.104]
# step:  192
# pusher_contact_angle:  -1.2036224929766772
# new pusher_pt:  [ 0.04   -0.1035]
# step:  193
# pusher_contact_angle:  -1.2020048949051922
# new pusher_pt:  [ 0.04  -0.103]
# step:  194
# pusher_contact_angle:  -1.200373641509321
# new pusher_pt:  [ 0.04   -0.1025]
# step:  195
# pusher_contact_angle:  -1.1987285679367758
# new pusher_pt:  [ 0.04  -0.102]
# step:  196
# pusher_contact_angle:  -1.1970695068293429
# new pusher_pt:  [ 0.04   -0.1015]
# step:  197
# pusher_contact_angle:  -1.1953962882787201
# new pusher_pt:  [ 0.04  -0.101]
# step:  198
# pusher_contact_angle:  -1.1937087397815231
# new pusher_pt:  [ 0.04   -0.1005]
# step:  199
# pusher_contact_angle:  -1.1920066861934415
# new pusher_pt:  [ 0.04 -0.1 ]
# step:  200
# pusher_contact_angle:  -1.1902899496825314
# pusher inside the slider
# input pusher_rel_vel:  [0.  0.1]
# contact_angle:  -1.1902899496825314
# norm:  [-0.  1.]
# projection:  0.1
# pusher_rel_vel:  [-0.   0.1]
# constructing hull...
# (2500, 3)
# projected point:  [-0.          0.03225599  0.00129024]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00144166  0.05157661  0.64693934]
# pusher velocity:  [-0.   0.1]
# contact velocity:  [0.00974621 0.01193451]
# new contact point:  [ 0.03999979 -0.09949948]
# new pusher_pt:  [ 0.04   -0.0995]
# step:  201
# pusher_contact_angle:  -1.1902899496825314
# pusher inside the slider
# input pusher_rel_vel:  [0.00032347 0.09999948]
# contact_angle:  -1.1902899496825314
# norm:  [-0.  1.]
# projection:  0.09999947683731392
# pusher_rel_vel:  [-0.          0.09999948]
# projected point:  [-0.          0.03225599  0.00129024]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00144009  0.05152017  0.64623148]
# pusher velocity:  [-0.          0.09999948]
# contact velocity:  [0.00973326 0.01196673]
# new contact point:  [ 0.03999859 -0.09900053]
# new pusher_pt:  [ 0.04  -0.099]
# step:  202
# pusher_contact_angle:  -1.1902760252199613
# new pusher_pt:  [ 0.04   -0.0985]
# step:  203
# pusher_contact_angle:  -1.188516440702487
# pusher inside the slider
# input pusher_rel_vel:  [0.00064658 0.09999791]
# contact_angle:  -1.188516440702487
# norm:  [-0.  1.]
# projection:  0.09999790964382603
# pusher_rel_vel:  [-0.          0.09999791]
# projected point:  [-0.          0.03220062  0.00129465]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00143703  0.05141069  0.64485813]
# pusher velocity:  [-0.          0.09999791]
# contact velocity:  [0.00972009 0.0120194 ]
# new contact point:  [ 0.04020166 -0.09850025]
# new pusher_pt:  [ 0.04  -0.098]
# step:  204
# pusher_contact_angle:  -1.1884723055842887
# pusher inside the slider
# input pusher_rel_vel:  [0.000969   0.09999531]
# contact_angle:  -1.1884723055842887
# norm:  [-0.  1.]
# projection:  0.09999530509145887
# pusher_rel_vel:  [-0.          0.09999531]
# projected point:  [-0.          0.03219924  0.00129476]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00143541  0.05135272  0.64413106]
# pusher velocity:  [-0.          0.09999531]
# contact velocity:  [0.0097069  0.01205194]
# new contact point:  [ 0.04020239 -0.09800128]
# new pusher_pt:  [ 0.04   -0.0975]
# step:  205
# pusher_contact_angle:  -1.188414240550236
# pusher inside the slider
# input pusher_rel_vel:  [0.00129104 0.09999167]
# contact_angle:  -1.188414240550236
# norm:  [-0.  1.]
# projection:  0.0999916656778644
# pusher_rel_vel:  [-0.          0.09999167]
# projected point:  [-0.          0.03219743  0.00129491]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00143377  0.05129413  0.64339615]
# pusher velocity:  [-0.          0.09999167]
# contact velocity:  [0.00969362 0.01208457]
# new contact point:  [ 0.04020313 -0.09750229]
# new pusher_pt:  [ 0.04  -0.097]
# step:  206
# pusher_contact_angle:  -1.1883422637062513
# pusher inside the slider
# input pusher_rel_vel:  [0.00161271 0.099987  ]
# contact_angle:  -1.1883422637062513
# norm:  [-0.  1.]
# projection:  0.09998699501618102
# pusher_rel_vel:  [-0.        0.099987]
# projected point:  [-0.          0.03219519  0.00129509]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00143211  0.05123492  0.6426535 ]
# pusher velocity:  [-0.        0.099987]
# contact velocity:  [0.00968024 0.01211728]
# new contact point:  [ 0.04020388 -0.0970033 ]
# new pusher_pt:  [ 0.04   -0.0965]
# step:  207
# pusher_contact_angle:  -1.1882563939353117
# pusher inside the slider
# input pusher_rel_vel:  [0.00193398 0.0999813 ]
# contact_angle:  -1.1882563939353117
# norm:  [-0.  1.]
# projection:  0.0999812967755085
# pusher_rel_vel:  [-0.         0.0999813]
# projected point:  [-0.          0.03219251  0.0012953 ]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00143044  0.05117511  0.64190319]
# pusher velocity:  [-0.         0.0999813]
# contact velocity:  [0.00966677 0.01215008]
# new contact point:  [ 0.04020466 -0.0965043 ]
# new pusher_pt:  [ 0.04  -0.096]
# step:  208
# pusher_contact_angle:  -1.1881566508928312
# pusher inside the slider
# input pusher_rel_vel:  [0.00225487 0.09997457]
# contact_angle:  -1.1881566508928312
# norm:  [-0.  1.]
# projection:  0.09997457467995155
# pusher_rel_vel:  [-0.          0.09997457]
# projected point:  [-0.          0.0321894   0.00129555]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00142875  0.05111468  0.64114531]
# pusher velocity:  [-0.          0.09997457]
# contact velocity:  [0.00965321 0.01218295]
# new contact point:  [ 0.04020545 -0.09600529]
# new pusher_pt:  [ 0.04   -0.0955]
# step:  209
# pusher_contact_angle:  -1.1880430550020193
# pusher inside the slider
# input pusher_rel_vel:  [0.00257534 0.09996683]
# contact_angle:  -1.1880430550020193
# norm:  [-0.  1.]
# projection:  0.09996683250766293
# pusher_rel_vel:  [-0.          0.09996683]
# projected point:  [-0.          0.03218586  0.00129583]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00142705  0.05105367  0.64037994]
# pusher velocity:  [-0.          0.09996683]
# contact velocity:  [0.00963954 0.0122159 ]
# new contact point:  [ 0.04020625 -0.09550627]
# new pusher_pt:  [ 0.04  -0.095]
# step:  210
# pusher_contact_angle:  -1.1879156274492164
# pusher inside the slider
# input pusher_rel_vel:  [0.00289541 0.09995807]
# contact_angle:  -1.1879156274492164
# norm:  [-0.  1.]
# projection:  0.09995807408988727
# pusher_rel_vel:  [-0.          0.09995807]
# projected point:  [-0.          0.03218189  0.00129615]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00142532  0.05099206  0.63960717]
# pusher velocity:  [-0.          0.09995807]
# contact velocity:  [0.00962578 0.01224893]
# new contact point:  [ 0.04020707 -0.09500724]
# new pusher_pt:  [ 0.04   -0.0945]
# step:  211
# pusher_contact_angle:  -1.187774390179213
# pusher inside the slider
# input pusher_rel_vel:  [0.00321507 0.0999483 ]
# contact_angle:  -1.187774390179213
# norm:  [-0.  1.]
# projection:  0.09994830331000543
# pusher_rel_vel:  [-0.         0.0999483]
# projected point:  [-0.          0.03217749  0.0012965 ]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00142359  0.05092987  0.63882707]
# pusher velocity:  [-0.         0.0999483]
# contact velocity:  [0.00961192 0.01228204]
# new contact point:  [ 0.04020791 -0.0945082 ]
# new pusher_pt:  [ 0.04  -0.094]
# step:  212
# pusher_contact_angle:  -1.187619365890545
# pusher inside the slider
# input pusher_rel_vel:  [0.0035343  0.09993752]
# contact_angle:  -1.187619365890545
# norm:  [-0.  1.]
# projection:  0.09993752410257967
# pusher_rel_vel:  [-0.          0.09993752]
# projected point:  [-0.          0.03217266  0.00129688]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00142183  0.0508671   0.63803975]
# pusher velocity:  [-0.          0.09993752]
# contact velocity:  [0.00959796 0.01231522]
# new contact point:  [ 0.04020877 -0.09400915]
# new pusher_pt:  [ 0.04   -0.0935]
# step:  213
# pusher_contact_angle:  -1.1874505780307716
# pusher inside the slider
# input pusher_rel_vel:  [0.0038531  0.09992574]
# contact_angle:  -1.1874505780307716
# norm:  [-0.  1.]
# projection:  0.09992574045239999
# pusher_rel_vel:  [-0.          0.09992574]
# projected point:  [-0.         0.0321674  0.0012973]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00142006  0.05080376  0.63724527]
# pusher velocity:  [-0.          0.09992574]
# contact velocity:  [0.0095839  0.01234848]
# new contact point:  [ 0.04020964 -0.09351009]
# new pusher_pt:  [ 0.04  -0.093]
# step:  214
# pusher_contact_angle:  -1.1872680507917377
# pusher inside the slider
# input pusher_rel_vel:  [0.00417147 0.09991296]
# contact_angle:  -1.1872680507917377
# norm:  [-0.  1.]
# projection:  0.0999129563935322
# pusher_rel_vel:  [-0.          0.09991296]
# projected point:  [-0.          0.03216171  0.00129776]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00141828  0.05073986  0.63644373]
# pusher velocity:  [-0.          0.09991296]
# contact velocity:  [0.00956974 0.01238182]
# new contact point:  [ 0.04021053 -0.09301102]
# new pusher_pt:  [ 0.04   -0.0925]
# step:  215
# pusher_contact_angle:  -1.1870718091048162
# pusher inside the slider
# input pusher_rel_vel:  [0.00448939 0.09989918]
# contact_angle:  -1.1870718091048162
# norm:  [-0.  1.]
# projection:  0.0998991760083672
# pusher_rel_vel:  [-0.          0.09989918]
# projected point:  [-0.          0.0321556   0.00129824]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00141647  0.0506754   0.6356352 ]
# pusher velocity:  [-0.          0.09989918]
# contact velocity:  [0.00955548 0.01241523]
# new contact point:  [ 0.04021143 -0.09251194]
# new pusher_pt:  [ 0.04  -0.092]
# step:  216
# pusher_contact_angle:  -1.1868618786361353
# pusher inside the slider
# input pusher_rel_vel:  [0.00480687 0.0998844 ]
# contact_angle:  -1.1868618786361353
# norm:  [-0.  1.]
# projection:  0.09988440342667253
# pusher_rel_vel:  [-0.         0.0998844]
# projected point:  [-0.          0.03214906  0.00129876]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00141466  0.05061039  0.63481978]
# pusher velocity:  [-0.         0.0998844]
# contact velocity:  [0.00954111 0.01244871]
# new contact point:  [ 0.04021236 -0.09201285]
# new pusher_pt:  [ 0.04   -0.0915]
# step:  217
# pusher_contact_angle:  -1.1866382857817899
# pusher inside the slider
# input pusher_rel_vel:  [0.00512388 0.09986864]
# contact_angle:  -1.1866382857817899
# norm:  [-0.  1.]
# projection:  0.09986864282464604
# pusher_rel_vel:  [-0.          0.09986864]
# projected point:  [-0.          0.0321421   0.00129932]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00141282  0.05054484  0.63399754]
# pusher velocity:  [-0.          0.09986864]
# contact velocity:  [0.00952664 0.01248227]
# new contact point:  [ 0.04021329 -0.09151375]
# new pusher_pt:  [ 0.04  -0.091]
# step:  218
# pusher_contact_angle:  -1.186401057663039
# pusher inside the slider
# input pusher_rel_vel:  [0.00544044 0.0998519 ]
# contact_angle:  -1.186401057663039
# norm:  [-0.  1.]
# projection:  0.09985189842397192
# pusher_rel_vel:  [-0.         0.0998519]
# projected point:  [-0.          0.03213472  0.00129991]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00141098  0.05047875  0.63316858]
# pusher velocity:  [-0.         0.0998519]
# contact velocity:  [0.00951207 0.01251589]
# new contact point:  [ 0.04021425 -0.09101464]
# new pusher_pt:  [ 0.04   -0.0905]
# step:  219
# pusher_contact_angle:  -1.1861502221214864
# pusher inside the slider
# input pusher_rel_vel:  [0.00575653 0.09983417]
# contact_angle:  -1.1861502221214864
# norm:  [-0.  1.]
# projection:  0.09983417449087943
# pusher_rel_vel:  [-0.          0.09983417]
# projected point:  [-0.          0.03212692  0.00130053]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00140911  0.05041213  0.63233296]
# pusher velocity:  [-0.          0.09983417]
# contact velocity:  [0.00949739 0.01254959]
# new contact point:  [ 0.04021522 -0.09051552]
# new pusher_pt:  [ 0.04 -0.09]
# step:  220
# pusher_contact_angle:  -1.1858858077142507
# pusher inside the slider
# input pusher_rel_vel:  [0.00607214 0.09981548]
# contact_angle:  -1.1858858077142507
# norm:  [-0.  1.]
# projection:  0.0998154753352045
# pusher_rel_vel:  [-0.          0.09981548]
# projected point:  [-0.          0.03211869  0.00130119]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00140724  0.05034499  0.63149078]
# pusher velocity:  [-0.          0.09981548]
# contact velocity:  [0.0094826  0.01258336]
# new contact point:  [ 0.0402162  -0.09001638]
# new pusher_pt:  [ 0.04   -0.0895]
# step:  221
# pusher_contact_angle:  -1.18560784370912
# pusher inside the slider
# input pusher_rel_vel:  [0.00638727 0.09979581]
# contact_angle:  -1.18560784370912
# norm:  [-0.  1.]
# projection:  0.09979580530945453
# pusher_rel_vel:  [-0.          0.09979581]
# projected point:  [-0.          0.03211005  0.00130187]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00140535  0.05027733  0.63064212]
# pusher velocity:  [-0.          0.09979581]
# contact velocity:  [0.00946771 0.0126172 ]
# new contact point:  [ 0.0402172  -0.08951724]
# new pusher_pt:  [ 0.04  -0.089]
# step:  222
# pusher_contact_angle:  -1.1853163600796932
# pusher inside the slider
# input pusher_rel_vel:  [0.00670192 0.09977517]
# contact_angle:  -1.1853163600796932
# norm:  [-0.  1.]
# projection:  0.09977516880787629
# pusher_rel_vel:  [-0.          0.09977517]
# projected point:  [-0.          0.03210099  0.0013026 ]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00140344  0.05020916  0.62978706]
# pusher velocity:  [-0.          0.09977517]
# contact velocity:  [0.00945271 0.01265111]
# new contact point:  [ 0.04021822 -0.08901809]
# new pusher_pt:  [ 0.04   -0.0885]
# step:  223
# pusher_contact_angle:  -1.185011387500513
# pusher inside the slider
# input pusher_rel_vel:  [0.00701607 0.09975357]
# contact_angle:  -1.185011387500513
# norm:  [-0.  1.]
# projection:  0.09975357026552768
# pusher_rel_vel:  [-0.          0.09975357]
# projected point:  [-0.          0.03209152  0.00130335]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00140152  0.05014049  0.62892569]
# pusher velocity:  [-0.          0.09975357]
# contact velocity:  [0.0094376  0.01268508]
# new contact point:  [ 0.04021925 -0.08851892]
# new pusher_pt:  [ 0.04  -0.088]
# step:  224
# pusher_contact_angle:  -1.1846929573421812
# pusher inside the slider
# input pusher_rel_vel:  [0.00732972 0.09973101]
# contact_angle:  -1.1846929573421812
# norm:  [-0.  1.]
# projection:  0.09973101415735297
# pusher_rel_vel:  [-0.          0.09973101]
# projected point:  [-0.          0.03208162  0.00130414]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00139959  0.05007132  0.62805808]
# pusher velocity:  [-0.          0.09973101]
# contact velocity:  [0.00942238 0.01271912]
# new contact point:  [ 0.0402203  -0.08801974]
# new pusher_pt:  [ 0.04   -0.0875]
# step:  225
# pusher_contact_angle:  -1.1843611016664681
# pusher inside the slider
# input pusher_rel_vel:  [0.00764287 0.0997075 ]
# contact_angle:  -1.1843611016664681
# norm:  [-0.  1.]
# projection:  0.09970750499726211
# pusher_rel_vel:  [-0.         0.0997075]
# projected point:  [-0.          0.03207132  0.00130496]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00139764  0.05000166  0.62718431]
# pusher velocity:  [-0.         0.0997075]
# contact velocity:  [0.00940705 0.01275323]
# new contact point:  [ 0.04022136 -0.08752055]
# new pusher_pt:  [ 0.04  -0.087]
# step:  226
# pusher_contact_angle:  -1.1840158532214078
# pusher inside the slider
# input pusher_rel_vel:  [0.00795551 0.09968305]
# contact_angle:  -1.1840158532214078
# norm:  [-0.  1.]
# projection:  0.09968304733721424
# pusher_rel_vel:  [-0.          0.09968305]
# projected point:  [-0.          0.03206061  0.00130582]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00139568  0.04993151  0.62630447]
# pusher velocity:  [-0.          0.09968305]
# contact velocity:  [0.00939161 0.0127874 ]
# new contact point:  [ 0.04022244 -0.08702135]
# new pusher_pt:  [ 0.04   -0.0865]
# step:  227
# pusher_contact_angle:  -1.1836572454363825
# pusher inside the slider
# input pusher_rel_vel:  [0.00826763 0.09965765]
# contact_angle:  -1.1836572454363825
# norm:  [-0.  1.]
# projection:  0.0996576457663053
# pusher_rel_vel:  [-0.          0.09965765]
# projected point:  [-0.          0.03204948  0.0013067 ]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00139371  0.04986089  0.62541864]
# pusher velocity:  [-0.          0.09965765]
# contact velocity:  [0.00937606 0.01282164]
# new contact point:  [ 0.04022353 -0.08652214]
# new pusher_pt:  [ 0.04  -0.086]
# step:  228
# pusher_contact_angle:  -1.1832853124171994
# pusher inside the slider
# input pusher_rel_vel:  [0.00857922 0.0996313 ]
# contact_angle:  -1.1832853124171994
# norm:  [-0.  1.]
# projection:  0.09963130490986057
# pusher_rel_vel:  [-0.         0.0996313]
# projected point:  [-0.          0.03203794  0.00130762]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00139172  0.0497898   0.6245269 ]
# pusher velocity:  [-0.         0.0996313]
# contact velocity:  [0.0093604  0.01285594]
# new contact point:  [ 0.04022464 -0.08602292]
# new pusher_pt:  [ 0.04   -0.0855]
# step:  229
# pusher_contact_angle:  -1.182900088941153
# pusher inside the slider
# input pusher_rel_vel:  [0.00889029 0.09960403]
# contact_angle:  -1.182900088941153
# norm:  [-0.  1.]
# projection:  0.09960402942853142
# pusher_rel_vel:  [-0.          0.09960403]
# projected point:  [-0.          0.032026    0.00130858]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00138972  0.04971824  0.62362933]
# pusher velocity:  [-0.          0.09960403]
# contact velocity:  [0.00934463 0.0128903 ]
# new contact point:  [ 0.04022577 -0.08552368]
# new pusher_pt:  [ 0.04  -0.085]
# step:  230
# pusher_contact_angle:  -1.1825016104520816
# pusher inside the slider
# input pusher_rel_vel:  [0.00920083 0.09957582]
# contact_angle:  -1.1825016104520816
# norm:  [-0.  1.]
# projection:  0.09957582401739745
# pusher_rel_vel:  [-0.          0.09957582]
# projected point:  [-0.          0.03201366  0.00130956]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00138771  0.04964622  0.62272601]
# pusher velocity:  [-0.          0.09957582]
# contact velocity:  [0.00932874 0.01292472]
# new contact point:  [ 0.04022691 -0.08502443]
# new pusher_pt:  [ 0.04   -0.0845]
# step:  231
# pusher_contact_angle:  -1.1820899130554108
# pusher inside the slider
# input pusher_rel_vel:  [0.00951083 0.09954669]
# contact_angle:  -1.1820899130554108
# norm:  [-0.  1.]
# projection:  0.09954669340507313
# pusher_rel_vel:  [-0.          0.09954669]
# projected point:  [-0.          0.0320009   0.00131058]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00138568  0.04957376  0.62181702]
# pusher velocity:  [-0.          0.09954669]
# contact velocity:  [0.00931274 0.01295921]
# new contact point:  [ 0.04022806 -0.08452517]
# new pusher_pt:  [ 0.04  -0.084]
# step:  232
# pusher_contact_angle:  -1.1816650335131906
# pusher inside the slider
# input pusher_rel_vel:  [0.00982028 0.09951664]
# contact_angle:  -1.1816650335131906
# norm:  [-0.  1.]
# projection:  0.0995166423528202
# pusher_rel_vel:  [-0.          0.09951664]
# projected point:  [-0.          0.03198775  0.00131163]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00138364  0.04950084  0.62090243]
# pusher velocity:  [-0.          0.09951664]
# contact velocity:  [0.00929663 0.01299375]
# new contact point:  [ 0.04022923 -0.0840259 ]
# new pusher_pt:  [ 0.04   -0.0835]
# step:  233
# pusher_contact_angle:  -1.1812270092391195
# pusher inside the slider
# input pusher_rel_vel:  [0.01012918 0.09948568]
# contact_angle:  -1.1812270092391195
# norm:  [-0.  1.]
# projection:  0.099485675653665
# pusher_rel_vel:  [-0.          0.09948568]
# projected point:  [-0.          0.0319742   0.00131271]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00138159  0.04942749  0.61998234]
# pusher velocity:  [-0.          0.09948568]
# contact velocity:  [0.0092804  0.01302835]
# new contact point:  [ 0.04023042 -0.08352662]
# new pusher_pt:  [ 0.04  -0.083]
# step:  234
# pusher_contact_angle:  -1.1807758782935627
# pusher inside the slider
# input pusher_rel_vel:  [0.01043753 0.0994538 ]
# contact_angle:  -1.1807758782935627
# norm:  [-0.  1.]
# projection:  0.09945379813152162
# pusher_rel_vel:  [-0.         0.0994538]
# projected point:  [-0.          0.03196024  0.00131382]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00137953  0.0493537   0.6190568 ]
# pusher velocity:  [-0.         0.0994538]
# contact velocity:  [0.00926405 0.01306301]
# new contact point:  [ 0.04023162 -0.08302732]
# new pusher_pt:  [ 0.04   -0.0825]
# step:  235
# pusher_contact_angle:  -1.1803116793785575
# pusher inside the slider
# input pusher_rel_vel:  [0.01074532 0.09942101]
# contact_angle:  -1.1803116793785575
# norm:  [-0.  1.]
# projection:  0.09942101464032051
# pusher_rel_vel:  [-0.          0.09942101]
# projected point:  [-0.          0.03194589  0.00131496]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00137746  0.04927949  0.61812592]
# pusher velocity:  [-0.          0.09942101]
# contact velocity:  [0.00924759 0.01309773]
# new contact point:  [ 0.04023283 -0.08252801]
# new pusher_pt:  [ 0.04  -0.082]
# step:  236
# pusher_contact_angle:  -1.1798344518328137
# pusher inside the slider
# input pusher_rel_vel:  [0.01105254 0.09938733]
# contact_angle:  -1.1798344518328137
# norm:  [-0.  1.]
# projection:  0.099387330063143
# pusher_rel_vel:  [-0.          0.09938733]
# projected point:  [-0.          0.03193115  0.00131614]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00137537  0.04920485  0.61718975]
# pusher velocity:  [-0.          0.09938733]
# contact velocity:  [0.00923101 0.0131325 ]
# new contact point:  [ 0.04023406 -0.08202869]
# new pusher_pt:  [ 0.04   -0.0815]
# step:  237
# pusher_contact_angle:  -1.1793442356267003
# pusher inside the slider
# input pusher_rel_vel:  [0.01135919 0.09935275]
# contact_angle:  -1.1793442356267003
# norm:  [-0.  1.]
# projection:  0.09935274931136187
# pusher_rel_vel:  [-0.          0.09935275]
# projected point:  [-0.          0.03191601  0.00131734]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00137327  0.0491298   0.61624838]
# pusher velocity:  [-0.          0.09935275]
# contact velocity:  [0.00921432 0.01316733]
# new contact point:  [ 0.0402353  -0.08152935]
# new pusher_pt:  [ 0.04  -0.081]
# step:  238
# pusher_contact_angle:  -1.1788410713572273
# pusher inside the slider
# input pusher_rel_vel:  [0.01166527 0.09931728]
# contact_angle:  -1.1788410713572273
# norm:  [-0.  1.]
# projection:  0.09931727732378774
# pusher_rel_vel:  [-0.          0.09931728]
# projected point:  [-0.          0.03190048  0.00131858]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00137116  0.04905434  0.61530189]
# pusher velocity:  [-0.          0.09931728]
# contact velocity:  [0.0091975  0.01320221]
# new contact point:  [ 0.04023656 -0.08103001]
# new pusher_pt:  [ 0.04   -0.0805]
# step:  239
# pusher_contact_angle:  -1.1783250002430146
# pusher inside the slider
# input pusher_rel_vel:  [0.01197076 0.09928092]
# contact_angle:  -1.1783250002430146
# norm:  [-0.  1.]
# projection:  0.09928091906582201
# pusher_rel_vel:  [-0.          0.09928092]
# projected point:  [-0.          0.03188457  0.00131985]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00136904  0.04897848  0.61435035]
# pusher velocity:  [-0.          0.09928092]
# contact velocity:  [0.00918057 0.01323715]
# new contact point:  [ 0.04023783 -0.08053065]
# new pusher_pt:  [ 0.04 -0.08]
# step:  240
# pusher_contact_angle:  -1.1777960641192542
# pusher inside the slider
# input pusher_rel_vel:  [0.01227567 0.09924368]
# contact_angle:  -1.1777960641192542
# norm:  [-0.  1.]
# projection:  0.09924367952861586
# pusher_rel_vel:  [-0.          0.09924368]
# projected point:  [-0.          0.03186826  0.00132115]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00136691  0.04890223  0.61339384]
# pusher velocity:  [-0.          0.09924368]
# contact velocity:  [0.00916352 0.01327214]
# new contact point:  [ 0.04023912 -0.08003127]
# new pusher_pt:  [ 0.04   -0.0795]
# step:  241
# pusher_contact_angle:  -1.1772543054326616
# pusher inside the slider
# input pusher_rel_vel:  [0.01257999 0.09920556]
# contact_angle:  -1.1772543054326616
# norm:  [-0.  1.]
# projection:  0.09920556372823582
# pusher_rel_vel:  [-0.          0.09920556]
# projected point:  [-0.          0.03185157  0.00132248]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00136477  0.04882558  0.61243244]
# pusher velocity:  [-0.          0.09920556]
# contact velocity:  [0.00914635 0.01330718]
# new contact point:  [ 0.04024042 -0.07953189]
# new pusher_pt:  [ 0.04  -0.079]
# step:  242
# pusher_contact_angle:  -1.1766997672364197
# pusher inside the slider
# input pusher_rel_vel:  [0.01288371 0.09916658]
# contact_angle:  -1.1766997672364197
# norm:  [-0.  1.]
# projection:  0.09916657670483593
# pusher_rel_vel:  [-0.          0.09916658]
# projected point:  [-0.          0.0318345   0.00132384]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00136261  0.04874855  0.61146621]
# pusher velocity:  [-0.          0.09916658]
# contact velocity:  [0.00912905 0.01334227]
# new contact point:  [ 0.04024173 -0.07903249]
# new pusher_pt:  [ 0.04   -0.0785]
# step:  243
# pusher_contact_angle:  -1.1761324931851098
# pusher inside the slider
# input pusher_rel_vel:  [0.01318684 0.09912672]
# contact_angle:  -1.1761324931851098
# norm:  [-0.  1.]
# projection:  0.09912672352183655
# pusher_rel_vel:  [-0.          0.09912672]
# projected point:  [-0.          0.03181704  0.00132523]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00136045  0.04867114  0.61049524]
# pusher velocity:  [-0.          0.09912672]
# contact velocity:  [0.00911164 0.01337741]
# new contact point:  [ 0.04024306 -0.07853307]
# new pusher_pt:  [ 0.04  -0.078]
# step:  244
# pusher_contact_angle:  -1.1755525275296372
# pusher inside the slider
# input pusher_rel_vel:  [0.01348936 0.09908601]
# contact_angle:  -1.1755525275296372
# norm:  [-0.  1.]
# projection:  0.09908600926510985
# pusher_rel_vel:  [-0.          0.09908601]
# projected point:  [-0.          0.03179921  0.00132666]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00135828  0.04859336  0.60951959]
# pusher velocity:  [-0.          0.09908601]
# contact velocity:  [0.00909411 0.0134126 ]
# new contact point:  [ 0.0402444  -0.07803365]
# new pusher_pt:  [ 0.04   -0.0775]
# step:  245
# pusher_contact_angle:  -1.174959915112144
# pusher inside the slider
# input pusher_rel_vel:  [0.01379127 0.09904444]
# contact_angle:  -1.174959915112144
# norm:  [-0.  1.]
# projection:  0.09904443904217253
# pusher_rel_vel:  [-0.          0.09904444]
# projected point:  [-0.          0.03178099  0.00132811]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00135609  0.04851521  0.60853935]
# pusher velocity:  [-0.          0.09904444]
# contact velocity:  [0.00907645 0.01344783]
# new contact point:  [ 0.04024575 -0.0775342 ]
# new pusher_pt:  [ 0.04  -0.077]
# step:  246
# pusher_contact_angle:  -1.1743547013609115
# pusher inside the slider
# input pusher_rel_vel:  [0.01409257 0.09900202]
# contact_angle:  -1.1743547013609115
# norm:  [-0.  1.]
# projection:  0.0990020179813849
# pusher_rel_vel:  [-0.          0.09900202]
# projected point:  [-0.          0.03176241  0.00132959]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.0013539   0.0484367   0.60755459]
# pusher velocity:  [-0.          0.09900202]
# contact velocity:  [0.00905867 0.01348312]
# new contact point:  [ 0.04024712 -0.07703475]
# new pusher_pt:  [ 0.04   -0.0765]
# step:  247
# pusher_contact_angle:  -1.1737369322852562
# pusher inside the slider
# input pusher_rel_vel:  [0.01439325 0.09895875]
# contact_angle:  -1.1737369322852562
# norm:  [-0.  1.]
# projection:  0.09895875123115777
# pusher_rel_vel:  [-0.          0.09895875]
# projected point:  [-0.          0.03174345  0.0013311 ]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00135169  0.04835783  0.60656538]
# pusher velocity:  [-0.          0.09895875]
# contact velocity:  [0.00904077 0.01351845]
# new contact point:  [ 0.0402485  -0.07653528]
# new pusher_pt:  [ 0.04  -0.076]
# step:  248
# pusher_contact_angle:  -1.173106654470412
# pusher inside the slider
# input pusher_rel_vel:  [0.0146933  0.09891464]
# contact_angle:  -1.173106654470412
# norm:  [-0.  1.]
# projection:  0.0989146439591659
# pusher_rel_vel:  [-0.          0.09891464]
# projected point:  [-0.          0.03172412  0.00133264]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00134948  0.04827862  0.60557179]
# pusher velocity:  [-0.          0.09891464]
# contact velocity:  [0.00902274 0.01355383]
# new contact point:  [ 0.0402499 -0.0760358]
# new pusher_pt:  [ 0.04   -0.0755]
# step:  249
# pusher_contact_angle:  -1.1724639150724026
# pusher inside the slider
# input pusher_rel_vel:  [0.01499274 0.0988697 ]
# contact_angle:  -1.1724639150724026
# norm:  [-0.  1.]
# projection:  0.09886970135156893
# pusher_rel_vel:  [-0.         0.0988697]
# projected point:  [-0.          0.03170442  0.00133421]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00134726  0.04819906  0.60457389]
# pusher velocity:  [-0.         0.0988697]
# contact velocity:  [0.0090046  0.01358925]
# new contact point:  [ 0.0402513  -0.07553631]
# new pusher_pt:  [ 0.04  -0.075]
# step:  250
# pusher_contact_angle:  -1.1718087618129034
# pusher inside the slider
# input pusher_rel_vel:  [0.01529154 0.09882393]
# contact_angle:  -1.1718087618129034
# norm:  [-0.  1.]
# projection:  0.09882392861223967
# pusher_rel_vel:  [-0.          0.09882393]
# projected point:  [-0.          0.03168435  0.00133581]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00134502  0.04811917  0.60357176]
# pusher velocity:  [-0.          0.09882393]
# contact velocity:  [0.00898632 0.01362471]
# new contact point:  [ 0.04025272 -0.0750368 ]
# new pusher_pt:  [ 0.04   -0.0745]
# step:  251
# pusher_contact_angle:  -1.1711412429740935
# pusher inside the slider
# input pusher_rel_vel:  [0.0155897  0.09877733]
# contact_angle:  -1.1711412429740935
# norm:  [-0.  1.]
# projection:  0.09877733096199964
# pusher_rel_vel:  [-0.          0.09877733]
# projected point:  [-0.          0.03166392  0.00133744]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00134278  0.04803894  0.60256547]
# pusher velocity:  [-0.          0.09877733]
# contact velocity:  [0.00896792 0.01366022]
# new contact point:  [ 0.04025416 -0.07453727]
# new pusher_pt:  [ 0.04  -0.074]
# step:  252
# pusher_contact_angle:  -1.1704614073934947
# pusher inside the slider
# input pusher_rel_vel:  [0.01588723 0.09872991]
# contact_angle:  -1.1704614073934947
# norm:  [-0.  1.]
# projection:  0.0987299136378621
# pusher_rel_vel:  [-0.          0.09872991]
# projected point:  [-0.          0.03164313  0.0013391 ]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00134053  0.04795839  0.60155509]
# pusher velocity:  [-0.          0.09872991]
# contact velocity:  [0.0089494  0.01369577]
# new contact point:  [ 0.0402556  -0.07403774]
# new pusher_pt:  [ 0.04   -0.0735]
# step:  253
# pusher_contact_angle:  -1.1697693044587993
# pusher inside the slider
# input pusher_rel_vel:  [0.01618412 0.09868168]
# contact_angle:  -1.1697693044587993
# norm:  [-0.  1.]
# projection:  0.09868168189228277
# pusher_rel_vel:  [-0.          0.09868168]
# projected point:  [-0.          0.03162198  0.00134079]
# normal:  [-0.00022214  0.00794717  0.09968346]
# slider velocity:  [-0.00133827  0.04787752  0.60054068]
# pusher velocity:  [-0.          0.09868168]
# contact velocity:  [0.00893075 0.01373136]
# new contact point:  [ 0.04025706 -0.07353819]
# new pusher_pt:  [ 0.04  -0.073]
# step:  254
# ...
# step:  614
# pusher_contact_angle:  -0.34226494132510693
# new pusher_pt:  [0.04   0.1075]
# step:  615
# pusher_contact_angle:  -0.3391214661249831
# new pusher_pt:  [0.04  0.108]
# step:  616
# pusher_contact_angle:  -0.33598621900095665
# new pusher_pt:  [0.04   0.1085]
# step:  617
# pusher_contact_angle:  -0.3328592290847245
# new pusher_pt:  [0.04  0.109]
# step:  618
# pusher_contact_angle:  -0.32974052470883813
# new pusher_pt:  [0.04   0.1095]
# step:  619
# pusher_contact_angle:  -0.32663013341121583
# new pusher_pt:  [0.04 0.11]
# step:  620
# pusher_contact_angle:  -0.3235280819397767
# new pusher_pt:  [0.04   0.1105]
# step:  621
# pusher_contact_angle:  -0.3204343962571943
# new pusher_pt:  [0.04  0.111]
# step:  622
# pusher_contact_angle:  -0.3173491015457653
# new pusher_pt:  [0.04   0.1115]
# step:  623
# pusher_contact_angle:  -0.3142722222123895
# new pusher_pt:  [0.04  0.112]
# step:  624
# pusher_contact_angle:  -0.3112037818936585
# new pusher_pt:  [0.04   0.1125]
# step:  625
# pusher_contact_angle:  -0.3081438034610494
# new pusher_pt:  [0.04  0.113]
# step:  626
# pusher_contact_angle:  -0.30509230902621887
# new pusher_pt:  [0.04   0.1135]
# step:  627
# pusher_contact_angle:  -0.3020493199463955
# new pusher_pt:  [0.04  0.114]
# step:  628
# pusher_contact_angle:  -0.2990148568298676
# new pusher_pt:  [0.04   0.1145]
# step:  629
# pusher_contact_angle:  -0.29598893954156036
# new pusher_pt:  [0.04  0.115]
# step:  630
# pusher_contact_angle:  -0.292971587208702
# new pusher_pt:  [0.04   0.1155]
# step:  631
# pusher_contact_angle:  -0.2899628182265732
# new pusher_pt:  [0.04  0.116]
# step:  632
# pusher_contact_angle:  -0.2869626502643388
# new pusher_pt:  [0.04   0.1165]
# step:  633
# pusher_contact_angle:  -0.2839711002709558
# new pusher_pt:  [0.04  0.117]
# step:  634
# pusher_contact_angle:  -0.28098818448115676
# new pusher_pt:  [0.04   0.1175]
# step:  635
# pusher_contact_angle:  -0.27801391842150414
# new pusher_pt:  [0.04  0.118]
# step:  636
# pusher_contact_angle:  -0.2750483169165119
# new pusher_pt:  [0.04   0.1185]
# step:  637
# pusher_contact_angle:  -0.2720913940948335
# new pusher_pt:  [0.04  0.119]
# step:  638
# pusher_contact_angle:  -0.26914316339551
# new pusher_pt:  [0.04   0.1195]
# step:  639
# pusher_contact_angle:  -0.26620363757427734
# new pusher_pt:  [0.04 0.12]
# step:  640
# pusher_contact_angle:  -0.2632728287099292
# new pusher_pt:  [0.04   0.1205]
# step:  641
# pusher_contact_angle:  -0.2603507482107324
# new pusher_pt:  [0.04  0.121]
# step:  642
# pusher_contact_angle:  -0.25743740682089133
# new pusher_pt:  [0.04   0.1215]
# step:  643
# pusher_contact_angle:  -0.25453281462705935
# new pusher_pt:  [0.04  0.122]
# step:  644
# pusher_contact_angle:  -0.2516369810648936
# new pusher_pt:  [0.04   0.1225]
# step:  645
# pusher_contact_angle:  -0.24874991492565013
# new pusher_pt:  [0.04  0.123]
# step:  646
# pusher_contact_angle:  -0.2458716243628183
# new pusher_pt:  [0.04   0.1235]
# step:  647
# pusher_contact_angle:  -0.24300211689878862
# new pusher_pt:  [0.04  0.124]
# step:  648
# pusher_contact_angle:  -0.2401413994315539
# new pusher_pt:  [0.04   0.1245]
# step:  649
# pusher_contact_angle:  -0.23728947824144014
# new pusher_pt:  [0.04  0.125]
# step:  650
# pusher_contact_angle:  -0.23444635899786387
# new pusher_pt:  [0.04   0.1255]
# step:  651
# pusher_contact_angle:  -0.23161204676611422
# new pusher_pt:  [0.04  0.126]
# step:  652
# pusher_contact_angle:  -0.22878654601415727
# new pusher_pt:  [0.04   0.1265]
# step:  653
# pusher_contact_angle:  -0.2259698606194591
# new pusher_pt:  [0.04  0.127]
# step:  654
# pusher_contact_angle:  -0.2231619938758256
# new pusher_pt:  [0.04   0.1275]
# step:  655
# pusher_contact_angle:  -0.22036294850025706
# new pusher_pt:  [0.04  0.128]
# step:  656
# pusher_contact_angle:  -0.2175727266398152
# new pusher_pt:  [0.04   0.1285]
# step:  657
# pusher_contact_angle:  -0.21479132987849867
# new pusher_pt:  [0.04  0.129]
# step:  658
# pusher_contact_angle:  -0.21201875924412714
# new pusher_pt:  [0.04   0.1295]
# step:  659
# pusher_contact_angle:  -0.20925501521523016
# new pusher_pt:  [0.04 0.13]
# step:  660
# pusher_contact_angle:  -0.20650009772793834
# new pusher_pt:  [0.04   0.1305]
# step:  661
# pusher_contact_angle:  -0.20375400618287656
# new pusher_pt:  [0.04  0.131]
# step:  662
# pusher_contact_angle:  -0.20101673945205512
# new pusher_pt:  [0.04   0.1315]
# step:  663
# pusher_contact_angle:  -0.19828829588575736
# new pusher_pt:  [0.04  0.132]
# step:  664
# pusher_contact_angle:  -0.19556867331942263
# new pusher_pt:  [0.04   0.1325]
# step:  665
# pusher_contact_angle:  -0.1928578690805212
# new pusher_pt:  [0.04  0.133]
# step:  666
# pusher_contact_angle:  -0.19015587999542083
# new pusher_pt:  [0.04   0.1335]
# step:  667
# pusher_contact_angle:  -0.18746270239624127
# new pusher_pt:  [0.04  0.134]
# step:  668
# pusher_contact_angle:  -0.18477833212769676
# new pusher_pt:  [0.04   0.1345]
# step:  669
# pusher_contact_angle:  -0.18210276455392277
# new pusher_pt:  [0.04  0.135]
# step:  670
# pusher_contact_angle:  -0.17943599456528767
# new pusher_pt:  [0.04   0.1355]
# step:  671
# pusher_contact_angle:  -0.17677801658518513
# new pusher_pt:  [0.04  0.136]
# step:  672
# pusher_contact_angle:  -0.1741288245768076
# new pusher_pt:  [0.04   0.1365]
# step:  673
# pusher_contact_angle:  -0.17148841204989768
# new pusher_pt:  [0.04  0.137]
# step:  674
# pusher_contact_angle:  -0.16885677206747732
# new pusher_pt:  [0.04   0.1375]
# step:  675
# pusher_contact_angle:  -0.16623389725255258
# new pusher_pt:  [0.04  0.138]
# step:  676
# pusher_contact_angle:  -0.1636197797947919
# new pusher_pt:  [0.04   0.1385]
# step:  677
# pusher_contact_angle:  -0.161014411457178
# new pusher_pt:  [0.04  0.139]
# step:  678
# pusher_contact_angle:  -0.15841778358263076
# new pusher_pt:  [0.04   0.1395]
# step:  679
# pusher_contact_angle:  -0.15582988710059956
# new pusher_pt:  [0.04 0.14]
# step:  680
# pusher_contact_angle:  -0.15325071253362588
# new pusher_pt:  [0.04   0.1405]
# step:  681
# pusher_contact_angle:  -0.15068025000387203
# new pusher_pt:  [0.04  0.141]
# step:  682
# pusher_contact_angle:  -0.1481184892396169
# new pusher_pt:  [0.04   0.1415]
# step:  683
# pusher_contact_angle:  -0.14556541958171654
# new pusher_pt:  [0.04  0.142]
# step:  684
# pusher_contact_angle:  -0.1430210299900294
# new pusher_pt:  [0.04   0.1425]
# step:  685
# pusher_contact_angle:  -0.14048530904980377
# new pusher_pt:  [0.04  0.143]
# step:  686
# pusher_contact_angle:  -0.13795824497802778
# new pusher_pt:  [0.04   0.1435]
# step:  687
# pusher_contact_angle:  -0.13543982562974008
# new pusher_pt:  [0.04  0.144]
# step:  688
# pusher_contact_angle:  -0.1329300385043003
# new pusher_pt:  [0.04   0.1445]
# step:  689
# pusher_contact_angle:  -0.1304288707516193
# new pusher_pt:  [0.04  0.145]
# step:  690
# pusher_contact_angle:  -0.12793630917834672
# new pusher_pt:  [0.04   0.1455]
# step:  691
# pusher_contact_angle:  -0.12545234025401666
# new pusher_pt:  [0.04  0.146]
# step:  692
# pusher_contact_angle:  -0.12297695011714894
# new pusher_pt:  [0.04   0.1465]
# step:  693
# pusher_contact_angle:  -0.1205101245813073
# new pusher_pt:  [0.04  0.147]
# step:  694
# pusher_contact_angle:  -0.11805184914111169
# new pusher_pt:  [0.04   0.1475]
# step:  695
# pusher_contact_angle:  -0.11560210897820523
# new pusher_pt:  [0.04  0.148]
# step:  696
# pusher_contact_angle:  -0.1131608889671748
# new pusher_pt:  [0.04   0.1485]
# step:  697
# pusher_contact_angle:  -0.11072817368142439
# new pusher_pt:  [0.04  0.149]
# step:  698
# pusher_contact_angle:  -0.10830394739900145
# new pusher_pt:  [0.04   0.1495]
# step:  699
# pusher_contact_angle:  -0.10588819410837438
# new pusher_pt:  [0.04 0.15]
# step:  700
# pusher_contact_angle:  -0.10348089751416176
# new pusher_pt:  [0.04   0.1505]
# step:  701
# pusher_contact_angle:  -0.10108204104281222
# new pusher_pt:  [0.04  0.151]
# step:  702
# pusher_contact_angle:  -0.0986916078482343
# new pusher_pt:  [0.04   0.1515]
# step:  703
# pusher_contact_angle:  -0.09630958081737703
# new pusher_pt:  [0.04  0.152]
# step:  704
# pusher_contact_angle:  -0.09393594257575905
# new pusher_pt:  [0.04   0.1525]
# step:  705
# pusher_contact_angle:  -0.09157067549294721
# new pusher_pt:  [0.04  0.153]
# step:  706
# pusher_contact_angle:  -0.08921376168798363
# new pusher_pt:  [0.04   0.1535]
# step:  707
# pusher_contact_angle:  -0.0868651830347616
# new pusher_pt:  [0.04  0.154]
# step:  708
# pusher_contact_angle:  -0.08452492116734893
# new pusher_pt:  [0.04   0.1545]
# step:  709
# pusher_contact_angle:  -0.0821929574852594
# new pusher_pt:  [0.04  0.155]
# step:  710
# pusher_contact_angle:  -0.07986927315867179
# new pusher_pt:  [0.04   0.1555]
# step:  711
# pusher_contact_angle:  -0.07755384913359556
# new pusher_pt:  [0.04  0.156]
# step:  712
# pusher_contact_angle:  -0.0752466661369848
# new pusher_pt:  [0.04   0.1565]
# step:  713
# pusher_contact_angle:  -0.07294770468179786
# new pusher_pt:  [0.04  0.157]
# step:  714
# pusher_contact_angle:  -0.07065694507200439
# new pusher_pt:  [0.04   0.1575]
# step:  715
# pusher_contact_angle:  -0.0683743674075389
# new pusher_pt:  [0.04  0.158]
# step:  716
# pusher_contact_angle:  -0.06609995158920028
# new pusher_pt:  [0.04   0.1585]
# step:  717
# pusher_contact_angle:  -0.0638336773234988
# new pusher_pt:  [0.04  0.159]
# step:  718
# pusher_contact_angle:  -0.061575524127448315
# new pusher_pt:  [0.04   0.1595]
# step:  719
# pusher_contact_angle:  -0.05932547133330539
# new pusher_pt:  [0.04 0.16]
# step:  720
# pusher_contact_angle:  -0.05708349809325421
# new pusher_pt:  [0.04   0.1605]
# step:  721
# pusher_contact_angle:  -0.05484958338403842
# new pusher_pt:  [0.04  0.161]
# step:  722
# pusher_contact_angle:  -0.05262370601153843
# new pusher_pt:  [0.04   0.1615]
# step:  723
# pusher_contact_angle:  -0.05040584461529544
# new pusher_pt:  [0.04  0.162]
# step:  724
# pusher_contact_angle:  -0.048195977672981706
# new pusher_pt:  [0.04   0.1625]
# step:  725
# pusher_contact_angle:  -0.04599408350481678
# new pusher_pt:  [0.04  0.163]
# step:  726
# pusher_contact_angle:  -0.04380014027793103
# new pusher_pt:  [0.04   0.1635]
# step:  727
# pusher_contact_angle:  -0.04161412601067487
# new pusher_pt:  [0.04  0.164]
# step:  728
# pusher_contact_angle:  -0.03943601857687509
# new pusher_pt:  [0.04   0.1645]
# step:  729
# pusher_contact_angle:  -0.03726579571003755
# new pusher_pt:  [0.04  0.165]
# step:  730
# pusher_contact_angle:  -0.0351034350074975
# new pusher_pt:  [0.04   0.1655]
# step:  731
# pusher_contact_angle:  -0.03294891393451621
# new pusher_pt:  [0.04  0.166]
# step:  732
# pusher_contact_angle:  -0.030802209828325256
# new pusher_pt:  [0.04   0.1665]
# step:  733
# pusher_contact_angle:  -0.028663299902118144
# new pusher_pt:  [0.04  0.167]
# step:  734
# pusher_contact_angle:  -0.026532161248989185
# new pusher_pt:  [0.04   0.1675]
# step:  735
# pusher_contact_angle:  -0.02440877084582099
# new pusher_pt:  [0.04  0.168]
# step:  736
# pusher_contact_angle:  -0.02229310555711916
# new pusher_pt:  [0.04   0.1685]
# step:  737
# pusher_contact_angle:  -0.020185142138795648
# new pusher_pt:  [0.04  0.169]
# step:  738
# pusher_contact_angle:  -0.01808485724190061
# new pusher_pt:  [0.04   0.1695]
# step:  739
# pusher_contact_angle:  -0.015992227416302563
# new pusher_pt:  [0.04 0.17]
# step:  740
# pusher_contact_angle:  -0.013907229114318733
# new pusher_pt:  [0.04   0.1705]
# step:  741
# pusher_contact_angle:  -0.011829838694292895
# new pusher_pt:  [0.04  0.171]
# step:  742
# pusher_contact_angle:  -0.00976003242412419
# new pusher_pt:  [0.04   0.1715]
# step:  743
# pusher_contact_angle:  -0.007697786484745806
# new pusher_pt:  [0.04  0.172]
# step:  744
# pusher_contact_angle:  -0.005643076973552271
# new pusher_pt:  [0.04   0.1725]
# step:  745
# pusher_contact_angle:  -0.0035958799077794984
# new pusher_pt:  [0.04  0.173]
# step:  746
# pusher_contact_angle:  -0.001556171227833294
# new pusher_pt:  [0.04   0.1735]
# step:  747
# pusher_contact_angle:  0.00047607319942950577
# new pusher_pt:  [0.04  0.174]
# step:  748
# pusher_contact_angle:  0.002500877577468493
# new pusher_pt:  [0.04   0.1745]
# step:  749
# pusher_contact_angle:  0.004518266176876758
# new pusher_pt:  [0.04  0.175]
# step:  750
# pusher_contact_angle:  0.006528263332244495
# new pusher_pt:  [0.04   0.1755]
# step:  751
# pusher_contact_angle:  0.00853089343907017
# new pusher_pt:  [0.04  0.176]
# step:  752
# pusher_contact_angle:  0.010526180950720401
# new pusher_pt:  [0.04   0.1765]
# step:  753
# pusher_contact_angle:  0.012514150375434421
# new pusher_pt:  [0.04  0.177]
# step:  754
# pusher_contact_angle:  0.014494826273377266
# new pusher_pt:  [0.04   0.1775]
# step:  755
# pusher_contact_angle:  0.016468233253737585
# new pusher_pt:  [0.04  0.178]
# step:  756
# pusher_contact_angle:  0.018434395971871173
# new pusher_pt:  [0.04   0.1785]
# step:  757
# pusher_contact_angle:  0.020393339126491355
# new pusher_pt:  [0.04  0.179]
# step:  758
# pusher_contact_angle:  0.022345087456902106
# new pusher_pt:  [0.04   0.1795]
# step:  759
# pusher_contact_angle:  0.02428966574027799
# new pusher_pt:  [0.04 0.18]
# step:  760
# pusher_contact_angle:  0.0262270987889868
# new pusher_pt:  [0.04   0.1805]
# step:  761
# pusher_contact_angle:  0.028157411447956006
# new pusher_pt:  [0.04  0.181]
# step:  762
# pusher_contact_angle:  0.030080628592084095
# new pusher_pt:  [0.04   0.1815]
# step:  763
# pusher_contact_angle:  0.031996775123692665
# new pusher_pt:  [0.04  0.182]
# step:  764
# pusher_contact_angle:  0.03390587597002339
# new pusher_pt:  [0.04   0.1825]
# step:  765
# pusher_contact_angle:  0.03580795608077566
# new pusher_pt:  [0.04  0.183]
# step:  766
# pusher_contact_angle:  0.03770304042568602
# new pusher_pt:  [0.04   0.1835]
# step:  767
# pusher_contact_angle:  0.03959115399215052
# new pusher_pt:  [0.04  0.184]
# step:  768
# pusher_contact_angle:  0.04147232178288574
# new pusher_pt:  [0.04   0.1845]
# step:  769
# pusher_contact_angle:  0.04334656881363265
# new pusher_pt:  [0.04  0.185]
# step:  770
# pusher_contact_angle:  0.04521392011089912
# new pusher_pt:  [0.04   0.1855]
# step:  771
# pusher_contact_angle:  0.047074400709742226
# new pusher_pt:  [0.04  0.186]
# step:  772
# pusher_contact_angle:  0.04892803565159106
# new pusher_pt:  [0.04   0.1865]
# step:  773
# pusher_contact_angle:  0.050774849982107316
# new pusher_pt:  [0.04  0.187]
# step:  774
# pusher_contact_angle:  0.052614868749084165
# new pusher_pt:  [0.04   0.1875]
# step:  775
# pusher_contact_angle:  0.054448117000384856
# new pusher_pt:  [0.04  0.188]
# step:  776
# pusher_contact_angle:  0.05627461978191666
# new pusher_pt:  [0.04   0.1885]
# step:  777
# pusher_contact_angle:  0.05809440213564425
# new pusher_pt:  [0.04  0.189]
# step:  778
# pusher_contact_angle:  0.05990748909763852
# new pusher_pt:  [0.04   0.1895]
# step:  779
# pusher_contact_angle:  0.06171390569616179
# new pusher_pt:  [0.04 0.19]
# step:  780
# pusher_contact_angle:  0.06351367694979035
# new pusher_pt:  [0.04   0.1905]
# step:  781
# pusher_contact_angle:  0.06530682786557064
# new pusher_pt:  [0.04  0.191]
# step:  782
# pusher_contact_angle:  0.06709338343721251
# new pusher_pt:  [0.04   0.1915]
# step:  783
# pusher_contact_angle:  0.0688733686433159
# new pusher_pt:  [0.04  0.192]
# step:  784
# pusher_contact_angle:  0.07064680844563201
# new pusher_pt:  [0.04   0.1925]
# step:  785
# pusher_contact_angle:  0.07241372778735951
# new pusher_pt:  [0.04  0.193]
# step:  786
# pusher_contact_angle:  0.07417415159147242
# new pusher_pt:  [0.04   0.1935]
# step:  787
# pusher_contact_angle:  0.07592810475908306
# new pusher_pt:  [0.04  0.194]
# step:  788
# pusher_contact_angle:  0.0776756121678364
# new pusher_pt:  [0.04   0.1945]
# step:  789
# pusher_contact_angle:  0.07941669867033661
# new pusher_pt:  [0.04  0.195]
# step:  790
# pusher_contact_angle:  0.08115138909260697
# new pusher_pt:  [0.04   0.1955]
# step:  791
# pusher_contact_angle:  0.08287970823257912
# new pusher_pt:  [0.04  0.196]
# step:  792
# pusher_contact_angle:  0.08460168085861564
# new pusher_pt:  [0.04   0.1965]
# step:  793
# pusher_contact_angle:  0.08631733170806169
# new pusher_pt:  [0.04  0.197]
# step:  794
# pusher_contact_angle:  0.08802668548582712
# new pusher_pt:  [0.04   0.1975]
# step:  795
# pusher_contact_angle:  0.0897297668629999
# new pusher_pt:  [0.04  0.198]
# step:  796
# pusher_contact_angle:  0.0914266004754868
# new pusher_pt:  [0.04   0.1985]
# step:  797
# pusher_contact_angle:  0.09311721092268542
# new pusher_pt:  [0.04  0.199]
# step:  798
# pusher_contact_angle:  0.09480162276618356
# new pusher_pt:  [0.04   0.1995]
# step:  799
# pusher_contact_angle:  0.09647986052848687
# new pusher_pt:  [0.04 0.2 ]
# <video width="800" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# TODO: need to think about how to fix the boundary problem
slider = CylinderSlider([0,0,0], 0.2)
# slider = BlockSlider([0,0,0], [0.2,0.2])

dt = 0.005
pusher_start = np.array([0.04,-0.2])
pusher_vels = np.array([[0,0.1]])
pusher_durs = np.array([0.5])
anim = SystemAnimationPusher(slider, pusher_start, pusher_vels, pusher_durs, dt)
anim.anim()
# Out:
# after update_grid
# <img src="data:image/png;base64,..." width="800">
# step:  0
# pusher_contact_angle:  -1.373400766945016
# new pusher_pt:  [ 0.04   -0.1995]
# step:  1
# pusher_contact_angle:  -1.3729188392714824
# new pusher_pt:  [ 0.04  -0.199]
# step:  2
# pusher_contact_angle:  -1.372434583670784
# new pusher_pt:  [ 0.04   -0.1985]
# step:  3
# pusher_contact_angle:  -1.3719479834634567
# new pusher_pt:  [ 0.04  -0.198]
# step:  4
# pusher_contact_angle:  -1.3714590218125726
# new pusher_pt:  [ 0.04   -0.1975]
# step:  5
# pusher_contact_angle:  -1.3709676817219063
# new pusher_pt:  [ 0.04  -0.197]
# step:  6
# pusher_contact_angle:  -1.370473946034075
# new pusher_pt:  [ 0.04   -0.1965]
# step:  7
# pusher_contact_angle:  -1.3699777974286518
# new pusher_pt:  [ 0.04  -0.196]
# step:  8
# pusher_contact_angle:  -1.3694792184202558
# new pusher_pt:  [ 0.04   -0.1955]
# step:  9
# pusher_contact_angle:  -1.3689781913566135
# pusher inside the slider
# input pusher_rel_vel:  [0.  0.1]
# contact_angle:  -1.3689781913566135
# norm:  [-0.2004509   0.97970375]
# projection:  0.097970375042776
# pusher_rel_vel:  [-0.01963825  0.09598194]
# constructing hull...
# (2500, 3)
# projected point:  [-0.02533424  0.12382108  0.        ]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01894989  0.09608589  0.00982969]
# pusher velocity:  [-0.01963825  0.09598194]
# contact velocity:  [-0.01729561  0.0980201 ]
# new contact point:  [ 0.03999199 -0.19546084]
# new pusher_pt:  [ 0.04  -0.195]
# step:  10
# pusher_contact_angle:  -1.3684758235903884
# pusher inside the slider
# input pusher_rel_vel:  [4.91484568e-06 9.99999999e-02]
# contact_angle:  -1.3684758235903884
# norm:  [-0.20094304  0.97960293]
# projection:  0.09795930495144062
# pusher_rel_vel:  [-0.01968424  0.09596122]
# projected point:  [-2.53965312e-02  1.23808797e-01  8.76984016e-19]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01894754  0.09607397  0.00982847]
# pusher velocity:  [-0.01968424  0.09596122]
# contact velocity:  [-0.01729583  0.09802118]
# new contact point:  [ 0.03999197 -0.19496087]
# new pusher_pt:  [ 0.04   -0.1945]
# step:  11
# pusher_contact_angle:  -1.3679721021465452
# pusher inside the slider
# input pusher_rel_vel:  [9.82908164e-06 9.99999995e-02]
# contact_angle:  -1.3679721021465452
# norm:  [-0.20143646  0.97950158]
# projection:  0.09794817790574091
# pusher_rel_vel:  [-0.01973033  0.0959404 ]
# projected point:  [-0.02545899  0.12379648  0.        ]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01894518  0.09606199  0.00982725]
# pusher velocity:  [-0.01973033  0.0959404 ]
# contact velocity:  [-0.01729606  0.09802226]
# new contact point:  [ 0.03999195 -0.1944609 ]
# new pusher_pt:  [ 0.04  -0.194]
# step:  12
# pusher_contact_angle:  -1.3674670238718913
# pusher inside the slider
# input pusher_rel_vel:  [1.47427049e-05 9.99999989e-02]
# contact_angle:  -1.3674670238718913
# norm:  [-0.20193116  0.97939972]
# projection:  0.097936993627026
# pusher_rel_vel:  [-0.01977653  0.09591946]
# projected point:  [-0.02552163  0.12378413  0.        ]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01894281  0.09604995  0.00982602]
# pusher velocity:  [-0.01977653  0.09591946]
# contact velocity:  [-0.01729628  0.09802335]
# new contact point:  [ 0.03999194 -0.19396093]
# new pusher_pt:  [ 0.04   -0.1935]
# step:  13
# pusher_contact_angle:  -1.366960585607118
# pusher inside the slider
# input pusher_rel_vel:  [1.96557124e-05 9.99999981e-02]
# contact_angle:  -1.366960585607118
# norm:  [-0.20242714  0.97929733]
# projection:  0.09792575183536974
# pusher_rel_vel:  [-0.01982283  0.09589843]
# projected point:  [-0.02558443  0.12377174  0.        ]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01894042  0.09603786  0.00982478]
# pusher velocity:  [-0.01982283  0.09589843]
# contact velocity:  [-0.0172965   0.09802443]
# new contact point:  [ 0.03999192 -0.19346096]
# new pusher_pt:  [ 0.04  -0.193]
# step:  14
# pusher_contact_angle:  -1.3664527841867986
# pusher inside the slider
# input pusher_rel_vel:  [2.45681012e-05 9.99999970e-02]
# contact_angle:  -1.3664527841867986
# norm:  [-0.2029244   0.97919441]
# projection:  0.09791445224956556
# pusher_rel_vel:  [-0.01986923  0.09587728]
# projected point:  [-2.56473960e-02  1.23759322e-01  8.76999297e-19]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01893802  0.0960257   0.00982353]
# pusher velocity:  [-0.01986923  0.09587728]
# contact velocity:  [-0.01729673  0.09802552]
# new contact point:  [ 0.03999191 -0.19296099]
# new pusher_pt:  [ 0.04   -0.1925]
# step:  15
# pusher_contact_angle:  -1.3659436164393852
# pusher inside the slider
# input pusher_rel_vel:  [2.94798682e-05 9.99999957e-02]
# contact_angle:  -1.3659436164393852
# norm:  [-0.20342295  0.97909096]
# projection:  0.0979030945871215
# pusher_rel_vel:  [-0.01991574  0.09585603]
# projected point:  [-2.57105363e-02  1.23746870e-01  8.77003708e-19]
# normal:  [-0.0192524   0.09761974  0.00998661]
# slider velocity:  [-0.01893561  0.09601349  0.00982228]
# pusher velocity:  [-0.01991574  0.09585603]
# contact velocity:  [-0.01729696  0.09802661]
# new contact point:  [ 0.03999189 -0.19246102]
# new pusher_pt:  [ 0.04  -0.192]
# step:  16
# pusher_contact_angle:  -1.3654330791872071
# pusher inside the slider
# input pusher_rel_vel:  [3.43910104e-05 9.99999941e-02]
# contact_angle:  -1.3654330791872071
# norm:  [-0.20392279  0.97898697]
# projection:  0.09789167856425497
# pusher_rel_vel:  [-0.01996234  0.09583468]
# projected point:  [-0.0257737   0.12373369  0.        ]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02034375  0.09573712 -0.00748239]
# pusher velocity:  [-0.01996234  0.09583468]
# contact velocity:  [-0.0222174   0.09721998]
# new contact point:  [ 0.03999187 -0.19196104]
# new pusher_pt:  [ 0.04   -0.1915]
# step:  17
# pusher_contact_angle:  -1.3649213641813243
# pusher inside the slider
# input pusher_rel_vel:  [3.06498137e-05 9.99999953e-02]
# contact_angle:  -1.3649213641813243
# norm:  [-0.20442372  0.9788825 ]
# projection:  0.09788197946540396
# pusher_rel_vel:  [-0.0200094   0.09581496]
# projected point:  [-0.02583697  0.12372025  0.        ]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02034188  0.09572833 -0.00748171]
# pusher velocity:  [-0.0200094   0.09581496]
# contact velocity:  [-0.02221725  0.09721927]
# new contact point:  [ 0.03999186 -0.19146107]
# new pusher_pt:  [ 0.04  -0.191]
# step:  18
# pusher_contact_angle:  -1.364408485905057
# pusher inside the slider
# input pusher_rel_vel:  [2.69089606e-05 9.99999964e-02]
# contact_angle:  -1.364408485905057
# norm:  [-0.20492574  0.97877752]
# projection:  0.09787223440722333
# pusher_rel_vel:  [-0.02005654  0.09579514]
# projected point:  [-0.02590037  0.12370677  0.        ]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02034     0.0957195  -0.00748102]
# pusher velocity:  [-0.02005654  0.09579514]
# contact velocity:  [-0.0222171   0.09721856]
# new contact point:  [ 0.03999185 -0.1909611 ]
# new pusher_pt:  [ 0.04   -0.1905]
# step:  19
# pusher_contact_angle:  -1.3638944416131562
# pusher inside the slider
# input pusher_rel_vel:  [2.31684526e-05 9.99999973e-02]
# contact_angle:  -1.3638944416131562
# norm:  [-0.20542885  0.97867205]
# projection:  0.09786244317222309
# pusher_rel_vel:  [-0.02010377  0.09577524]
# projected point:  [-0.02596392  0.12369327  0.        ]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02033811  0.09571062 -0.00748032]
# pusher velocity:  [-0.02010377  0.09577524]
# contact velocity:  [-0.02221696  0.09721785]
# new contact point:  [ 0.03999183 -0.19046113]
# new pusher_pt:  [ 0.04 -0.19]
# step:  20
# pusher_contact_angle:  -1.363379228554722
# pusher inside the slider
# input pusher_rel_vel:  [1.94282915e-05 9.99999981e-02]
# contact_angle:  -1.363379228554722
# norm:  [-0.20593305  0.97856608]
# projection:  0.09785260554191622
# pusher_rel_vel:  [-0.02015109  0.09575524]
# projected point:  [-2.60276184e-02  1.23679733e-01 -8.76998049e-19]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02033622  0.0957017  -0.00747962]
# pusher velocity:  [-0.02015109  0.09575524]
# contact velocity:  [-0.02221681  0.09721714]
# new contact point:  [ 0.03999182 -0.18996116]
# new pusher_pt:  [ 0.04   -0.1895]
# step:  21
# pusher_contact_angle:  -1.3628628439731987
# pusher inside the slider
# input pusher_rel_vel:  [1.56884791e-05 9.99999988e-02]
# contact_angle:  -1.3628628439731987
# norm:  [-0.20643834  0.97845961]
# projection:  0.09784272129681479
# pusher_rel_vel:  [-0.02019849  0.09573515]
# projected point:  [-0.02609146  0.12366617  0.        ]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02033431  0.09569273 -0.00747892]
# pusher velocity:  [-0.02019849  0.09573515]
# contact velocity:  [-0.02221665  0.09721642]
# new contact point:  [ 0.03999181 -0.1894612 ]
# new pusher_pt:  [ 0.04  -0.189]
# step:  22
# pusher_contact_angle:  -1.3623452851063682
# pusher inside the slider
# input pusher_rel_vel:  [1.19490171e-05 9.99999993e-02]
# contact_angle:  -1.3623452851063682
# norm:  [-0.20694472  0.97835264]
# projection:  0.09783279021642562
# pusher_rel_vel:  [-0.02024598  0.09571497]
# projected point:  [-2.61554432e-02  1.23652571e-01 -8.76996737e-19]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.0203324   0.09568372 -0.00747822]
# pusher velocity:  [-0.02024598  0.09571497]
# contact velocity:  [-0.0222165   0.09721571]
# new contact point:  [ 0.03999179 -0.18896123]
# new pusher_pt:  [ 0.04   -0.1885]
# step:  23
# pusher_contact_angle:  -1.3618265491863468
# pusher inside the slider
# input pusher_rel_vel:  [8.20990711e-06 9.99999997e-02]
# contact_angle:  -1.3618265491863468
# norm:  [-0.2074522   0.97824516]
# projection:  0.09782281207924601
# pusher_rel_vel:  [-0.02029356  0.09569469]
# projected point:  [-0.02621957  0.12363894  0.        ]
# normal:  [-0.02072502  0.09753138 -0.00762262]
# slider velocity:  [-0.02033047  0.09567466 -0.00747751]
# pusher velocity:  [-0.02029356  0.09569469]
# contact velocity:  [-0.02221635  0.09721499]
# new contact point:  [ 0.03999178 -0.18846126]
# new pusher_pt:  [ 0.04  -0.188]
# step:  24
# pusher_contact_angle:  -1.3613066334395778
# pusher inside the slider
# input pusher_rel_vel:  [4.47115099e-06 9.99999999e-02]
# contact_angle:  -1.3613066334395778
# norm:  [-0.20796078  0.97813717]
# projection:  0.09781278666275978
# pusher_rel_vel:  [-0.02034122  0.09567432]
# projected point:  [-0.02628383  0.12362521  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.0205521   0.09560863 -0.00890745]
# pusher velocity:  [-0.02034122  0.09567432]
# contact velocity:  [-0.02270387  0.09698629]
# new contact point:  [ 0.03999177 -0.18796129]
# new pusher_pt:  [ 0.04   -0.1875]
# step:  25
# pusher_contact_angle:  -1.3607855511976208
# pusher inside the slider
# input pusher_rel_vel:  [1.74271097e-08 1.00000000e-01]
# contact_angle:  -1.3607855511976208
# norm:  [-0.20847044  0.97802867]
# projection:  0.09780286320570512
# pusher_rel_vel:  [-0.02038901  0.095654  ]
# projected point:  [-2.63482213e-02  1.23611366e-01  8.76994902e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.0205502   0.09559976 -0.00890662]
# pusher velocity:  [-0.02038901  0.095654  ]
# contact velocity:  [-0.02270369  0.09698544]
# new contact point:  [ 0.03999175 -0.18746132]
# new pusher_pt:  [ 0.04  -0.187]
# step:  26
# pusher_contact_angle:  -1.3602633011299088
# pusher inside the slider
# input pusher_rel_vel:  [-4.43588357e-06  9.99999999e-02]
# contact_angle:  -1.3602633011299088
# norm:  [-0.20898119  0.97791966]
# projection:  0.09779289305153453
# pusher_rel_vel:  [-0.02043687  0.09563359]
# projected point:  [-0.02641275  0.12359749  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02054828  0.09559085 -0.00890579]
# pusher velocity:  [-0.02043687  0.09563359]
# contact velocity:  [-0.02270351  0.09698459]
# new contact point:  [ 0.03999174 -0.18696135]
# new pusher_pt:  [ 0.04   -0.1865]
# step:  27
# pusher_contact_angle:  -1.3597398804838703
# pusher inside the slider
# input pusher_rel_vel:  [-8.88877901e-06  9.99999996e-02]
# contact_angle:  -1.3597398804838703
# norm:  [-0.20949302  0.97781014]
# projection:  0.09778287598019546
# pusher_rel_vel:  [-0.02048483  0.09561309]
# projected point:  [-2.64774303e-02  1.23583592e-01 -8.76993797e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02054635  0.09558189 -0.00890496]
# pusher velocity:  [-0.02048483  0.09561309]
# contact velocity:  [-0.02270333  0.09698374]
# new contact point:  [ 0.03999173 -0.18646138]
# new pusher_pt:  [ 0.04  -0.186]
# step:  28
# pusher_contact_angle:  -1.3592152865012899
# pusher inside the slider
# input pusher_rel_vel:  [-1.33412571e-05  9.99999991e-02]
# contact_angle:  -1.3592152865012899
# norm:  [-0.21000594  0.97770011]
# projection:  0.09777281177063002
# pusher_rel_vel:  [-0.02053287  0.09559249]
# projected point:  [-2.65422520e-02  1.23569657e-01  8.76993604e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02054442  0.09557289 -0.00890412]
# pusher velocity:  [-0.02053287  0.09559249]
# contact velocity:  [-0.02270315  0.09698289]
# new contact point:  [ 0.03999172 -0.18596141]
# new pusher_pt:  [ 0.04   -0.1855]
# step:  29
# pusher_contact_angle:  -1.3586895164183022
# pusher inside the slider
# input pusher_rel_vel:  [-1.77933159e-05  9.99999984e-02]
# contact_angle:  -1.3586895164183022
# norm:  [-0.21051996  0.97758956]
# projection:  0.09776270020077064
# pusher_rel_vel:  [-0.020581    0.09557179]
# projected point:  [-2.66072190e-02  1.23555692e-01  8.76993653e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02054247  0.09556384 -0.00890327]
# pusher velocity:  [-0.020581    0.09557179]
# contact velocity:  [-0.02270296  0.09698204]
# new contact point:  [ 0.0399917  -0.18546144]
# new pusher_pt:  [ 0.04  -0.185]
# step:  30
# pusher_contact_angle:  -1.3581625674653872
# pusher inside the slider
# input pusher_rel_vel:  [-2.22449532e-05  9.99999975e-02]
# contact_angle:  -1.3581625674653872
# norm:  [-0.21103507  0.97747849]
# projection:  0.09775254104753604
# pusher_rel_vel:  [-0.02062921  0.09555101]
# projected point:  [-0.02667233  0.1235417   0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02054052  0.09555475 -0.00890243]
# pusher velocity:  [-0.02062921  0.09555101]
# contact velocity:  [-0.02270278  0.09698118]
# new contact point:  [ 0.03999169 -0.18496147]
# new pusher_pt:  [ 0.04   -0.1845]
# step:  31
# pusher_contact_angle:  -1.3576344368673652
# pusher inside the slider
# input pusher_rel_vel:  [-2.66961670e-05  9.99999964e-02]
# contact_angle:  -1.3576344368673652
# norm:  [-0.21155128  0.9773669 ]
# projection:  0.09774233408682688
# pusher_rel_vel:  [-0.02067752  0.09553012]
# projected point:  [-2.67375905e-02  1.23527667e-01 -8.76994481e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02053856  0.09554561 -0.00890158]
# pusher velocity:  [-0.02067752  0.09553012]
# contact velocity:  [-0.02270259  0.09698033]
# new contact point:  [ 0.03999168 -0.18446151]
# new pusher_pt:  [ 0.04  -0.184]
# step:  32
# pusher_contact_angle:  -1.3571051218433907
# pusher inside the slider
# input pusher_rel_vel:  [-3.11469551e-05  9.99999951e-02]
# contact_angle:  -1.3571051218433907
# norm:  [-0.21206858  0.97725479]
# projection:  0.09773207909352151
# pusher_rel_vel:  [-0.0207259   0.09550914]
# projected point:  [-0.026803    0.12351361  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02053658  0.09553643 -0.00890072]
# pusher velocity:  [-0.0207259   0.09550914]
# contact velocity:  [-0.02270241  0.09697947]
# new contact point:  [ 0.03999167 -0.18396154]
# new pusher_pt:  [ 0.04   -0.1835]
# step:  33
# pusher_contact_angle:  -1.3565746196069501
# pusher inside the slider
# input pusher_rel_vel:  [-3.55973155e-05  9.99999937e-02]
# contact_angle:  -1.3565746196069501
# norm:  [-0.21258699  0.97714215]
# projection:  0.09772177584147193
# pusher_rel_vel:  [-0.02077438  0.09548807]
# projected point:  [-0.02686855  0.12349952  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.0205346   0.09552721 -0.00889986]
# pusher velocity:  [-0.02077438  0.09548807]
# contact velocity:  [-0.02270222  0.0969786 ]
# new contact point:  [ 0.03999165 -0.18346157]
# new pusher_pt:  [ 0.04  -0.183]
# step:  34
# pusher_contact_angle:  -1.3560429273658536
# pusher inside the slider
# input pusher_rel_vel:  [-4.00472461e-05  9.99999920e-02]
# contact_angle:  -1.3560429273658536
# norm:  [-0.2131065   0.97702898]
# projection:  0.09771142410349919
# pusher_rel_vel:  [-0.02082294  0.09546689]
# projected point:  [-0.02693425  0.12348539  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02053261  0.09551794 -0.008899  ]
# pusher velocity:  [-0.02082294  0.09546689]
# contact velocity:  [-0.02270203  0.09697774]
# new contact point:  [ 0.03999164 -0.1829616 ]
# new pusher_pt:  [ 0.04   -0.1825]
# step:  35
# pusher_contact_angle:  -1.3555100423222322
# pusher inside the slider
# input pusher_rel_vel:  [-4.44967446e-05  9.99999901e-02]
# contact_angle:  -1.3555100423222322
# norm:  [-0.21362711  0.97691528]
# projection:  0.09770102365138948
# pusher_rel_vel:  [-0.02087159  0.09544562]
# projected point:  [-2.70000941e-02  1.23471239e-01  8.76999112e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.0205306   0.09550862 -0.00889813]
# pusher velocity:  [-0.02087159  0.09544562]
# contact velocity:  [-0.02270185  0.09697687]
# new contact point:  [ 0.03999163 -0.18246163]
# new pusher_pt:  [ 0.04  -0.182]
# step:  36
# pusher_contact_angle:  -1.3549759616725325
# pusher inside the slider
# input pusher_rel_vel:  [-4.89458091e-05  9.99999880e-02]
# contact_angle:  -1.3549759616725325
# norm:  [-0.21414883  0.97680104]
# projection:  0.09769057425588958
# pusher_rel_vel:  [-0.02092032  0.09542425]
# projected point:  [-2.70660890e-02  1.23457053e-01 -8.77000899e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02052859  0.09549925 -0.00889726]
# pusher velocity:  [-0.02092032  0.09542425]
# contact velocity:  [-0.02270166  0.09697601]
# new contact point:  [ 0.03999162 -0.18196167]
# new pusher_pt:  [ 0.04   -0.1815]
# step:  37
# pusher_contact_angle:  -1.3544406826075122
# pusher inside the slider
# input pusher_rel_vel:  [-5.33944372e-05  9.99999857e-02]
# contact_angle:  -1.3544406826075122
# norm:  [-0.21467166  0.97668627]
# projection:  0.0976800756867027
# pusher_rel_vel:  [-0.02096914  0.09540279]
# projected point:  [-0.02713223  0.12344283  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02052657  0.09548985 -0.00889638]
# pusher velocity:  [-0.02096914  0.09540279]
# contact velocity:  [-0.02270146  0.09697514]
# new contact point:  [ 0.0399916 -0.1814617]
# new pusher_pt:  [ 0.04  -0.181]
# step:  38
# pusher_contact_angle:  -1.3539042023122347
# pusher inside the slider
# input pusher_rel_vel:  [-5.78426270e-05  9.99999833e-02]
# contact_angle:  -1.3539042023122347
# norm:  [-0.21519561  0.97657097]
# projection:  0.09766952771248415
# pusher_rel_vel:  [-0.02101805  0.09538122]
# projected point:  [-2.71985242e-02  1.23428585e-01  8.77005239e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02052454  0.09548039 -0.0088955 ]
# pusher velocity:  [-0.02101805  0.09538122]
# contact velocity:  [-0.02270127  0.09697427]
# new contact point:  [ 0.03999159 -0.18096173]
# new pusher_pt:  [ 0.04   -0.1805]
# step:  39
# pusher_contact_angle:  -1.3533665179660652
# pusher inside the slider
# input pusher_rel_vel:  [-6.22903761e-05  9.99999806e-02]
# contact_angle:  -1.3533665179660652
# norm:  [-0.21572066  0.97645512]
# projection:  0.09765893010083694
# pusher_rel_vel:  [-0.02106705  0.09535956]
# projected point:  [-0.02726497  0.1234143   0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02052249  0.09547089 -0.00889461]
# pusher velocity:  [-0.02106705  0.09535956]
# contact velocity:  [-0.02270108  0.09697339]
# new contact point:  [ 0.03999158 -0.18046176]
# new pusher_pt:  [ 0.04 -0.18]
# step:  40
# pusher_contact_angle:  -1.3528276267426658
# pusher inside the slider
# input pusher_rel_vel:  [-6.67376825e-05  9.99999777e-02]
# contact_angle:  -1.3528276267426658
# norm:  [-0.21624683  0.97633873]
# projection:  0.09764828261830755
# pusher_rel_vel:  [-0.02111613  0.0953378 ]
# projected point:  [-0.02733156  0.12339999  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02052044  0.09546134 -0.00889372]
# pusher velocity:  [-0.02111613  0.0953378 ]
# contact velocity:  [-0.02270089  0.09697252]
# new contact point:  [ 0.03999157 -0.1799618 ]
# new pusher_pt:  [ 0.04   -0.1795]
# step:  41
# pusher_contact_angle:  -1.3522875258099907
# pusher inside the slider
# input pusher_rel_vel:  [-7.11845439e-05  9.99999747e-02]
# contact_angle:  -1.3522875258099907
# norm:  [-0.21677412  0.97622179]
# projection:  0.09763758503038153
# pusher_rel_vel:  [-0.0211653   0.09531594]
# projected point:  [-0.0273983   0.12338564  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02051838  0.09545174 -0.00889283]
# pusher velocity:  [-0.0211653   0.09531594]
# contact velocity:  [-0.02270069  0.09697164]
# new contact point:  [ 0.03999155 -0.17946183]
# new pusher_pt:  [ 0.04  -0.179]
# step:  42
# pusher_contact_angle:  -1.351746212330282
# pusher inside the slider
# input pusher_rel_vel:  [-7.56309582e-05  9.99999714e-02]
# contact_angle:  -1.351746212330282
# norm:  [-0.21730253  0.9761043 ]
# projection:  0.09762683710147908
# pusher_rel_vel:  [-0.02121456  0.09529398]
# projected point:  [-0.02746519  0.12337126  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.0205163   0.0954421  -0.00889193]
# pusher velocity:  [-0.02121456  0.09529398]
# contact velocity:  [-0.0227005   0.09697076]
# new contact point:  [ 0.03999154 -0.17896186]
# new pusher_pt:  [ 0.04   -0.1785]
# step:  43
# pusher_contact_angle:  -1.3512036834600654
# pusher inside the slider
# input pusher_rel_vel:  [-8.00769230e-05  9.99999679e-02]
# contact_angle:  -1.3512036834600654
# norm:  [-0.21783207  0.97598627]
# projection:  0.09761603859495083
# pusher_rel_vel:  [-0.0212639   0.09527191]
# projected point:  [-0.02753223  0.12335685  0.        ]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02051422  0.09543241 -0.00889103]
# pusher velocity:  [-0.0212639   0.09527191]
# contact velocity:  [-0.0227003   0.09696988]
# new contact point:  [ 0.03999153 -0.1784619 ]
# new pusher_pt:  [ 0.04  -0.178]
# step:  44
# pusher_contact_angle:  -1.3506599363501455
# pusher inside the slider
# input pusher_rel_vel:  [-8.45224363e-05  9.99999643e-02]
# contact_angle:  -1.3506599363501455
# norm:  [-0.21836272  0.97586768]
# projection:  0.09760518927307325
# pusher_rel_vel:  [-0.02131334  0.09524975]
# projected point:  [-2.75994223e-02  1.23342407e-01  8.77024518e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02051213  0.09542267 -0.00889012]
# pusher velocity:  [-0.02131334  0.09524975]
# contact velocity:  [-0.02270011  0.09696899]
# new contact point:  [ 0.03999152 -0.17796193]
# new pusher_pt:  [ 0.04   -0.1775]
# step:  45
# pusher_contact_angle:  -1.3501149681456022
# pusher inside the slider
# input pusher_rel_vel:  [-8.89674958e-05  9.99999604e-02]
# contact_angle:  -1.3501149681456022
# norm:  [-0.21889451  0.97574853]
# projection:  0.09759428889704443
# pusher_rel_vel:  [-0.02136285  0.09522748]
# projected point:  [-2.76667666e-02  1.23327931e-01  8.77028662e-19]
# normal:  [-0.02092936  0.09736365 -0.00907095]
# slider velocity:  [-0.02051002  0.09541288 -0.00888921]
# pusher velocity:  [-0.02136285  0.09522748]
# contact velocity:  [-0.02269991  0.0969681 ]
# new contact point:  [ 0.0399915  -0.17746196]
# new pusher_pt:  [ 0.04  -0.177]
# step:  46
# pusher_contact_angle:  -1.3495687759857853
# pusher inside the slider
# input pusher_rel_vel:  [-9.34120991e-05  9.99999564e-02]
# contact_angle:  -1.3495687759857853
# norm:  [-0.21942742  0.97562883]
# projection:  0.09758333722697952
# pusher_rel_vel:  [-0.02141246  0.09520512]
# projected point:  [-2.77341470e-02  1.23312907e-01 -8.77029414e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02166882  0.09514751  0.00284523]
# pusher velocity:  [-0.02141246  0.09520512]
# contact velocity:  [-0.02162713  0.0975894 ]
# new contact point:  [ 0.03999149 -0.17696199]
# new pusher_pt:  [ 0.04   -0.1765]
# step:  47
# pusher_contact_angle:  -1.3490212250266462
# pusher inside the slider
# input pusher_rel_vel:  [-9.19894836e-05  9.99999577e-02]
# contact_angle:  -1.3490212250266462
# norm:  [-0.2199616   0.97550853]
# projection:  0.09757104610198293
# pusher_rel_vel:  [-0.02146188  0.09518139]
# projected point:  [-0.02780163  0.12329754  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02166602  0.09513521  0.00284486]
# pusher velocity:  [-0.02146188  0.09518139]
# contact velocity:  [-0.0216272   0.09758972]
# new contact point:  [ 0.03999147 -0.17646202]
# new pusher_pt:  [ 0.04  -0.176]
# step:  48
# pusher_contact_angle:  -1.3484723006617383
# pusher inside the slider
# input pusher_rel_vel:  [-9.05670518e-05  9.99999590e-02]
# contact_angle:  -1.3484723006617383
# norm:  [-0.22049704  0.97538764]
# projection:  0.09755869406280793
# pusher_rel_vel:  [-0.0215114   0.09515754]
# projected point:  [-0.02786927  0.12328213  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02166321  0.09512286  0.0028445 ]
# pusher velocity:  [-0.0215114   0.09515754]
# contact velocity:  [-0.02162727  0.09759004]
# new contact point:  [ 0.03999146 -0.17596206]
# new pusher_pt:  [ 0.04   -0.1755]
# step:  49
# pusher_contact_angle:  -1.3479219997124459
# pusher inside the slider
# input pusher_rel_vel:  [-8.91448048e-05  9.99999603e-02]
# contact_angle:  -1.3479219997124459
# norm:  [-0.22103377  0.97526616]
# projection:  0.09754628081751159
# pusher_rel_vel:  [-0.02156102  0.09513359]
# projected point:  [-0.02793709  0.12326669  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02166038  0.09511044  0.00284412]
# pusher velocity:  [-0.02156102  0.09513359]
# contact velocity:  [-0.02162734  0.09759036]
# new contact point:  [ 0.03999144 -0.17546209]
# new pusher_pt:  [ 0.04  -0.175]
# step:  50
# pusher_contact_angle:  -1.3473703189941237
# pusher inside the slider
# input pusher_rel_vel:  [-8.77227434e-05  9.99999615e-02]
# contact_angle:  -1.3473703189941237
# norm:  [-0.22157177  0.97514407]
# projection:  0.09753380607283574
# pusher_rel_vel:  [-0.02161074  0.09510951]
# projected point:  [-2.80050798e-02  1.23251205e-01 -1.75405268e-18]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02165754  0.09509796  0.00284375]
# pusher velocity:  [-0.02161074  0.09510951]
# contact velocity:  [-0.02162742  0.09759068]
# new contact point:  [ 0.03999143 -0.17496212]
# new pusher_pt:  [ 0.04   -0.1745]
# step:  51
# pusher_contact_angle:  -1.3468172553160953
# pusher inside the slider
# input pusher_rel_vel:  [-8.63008685e-05  9.99999628e-02]
# contact_angle:  -1.3468172553160953
# norm:  [-0.22211105  0.97502137]
# projection:  0.09752126953420191
# pusher_rel_vel:  [-0.02166055  0.09508532]
# projected point:  [-2.80732379e-02  1.23235683e-01  8.77026236e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02165469  0.09508543  0.00284338]
# pusher velocity:  [-0.02166055  0.09508532]
# contact velocity:  [-0.02162749  0.097591  ]
# new contact point:  [ 0.03999141 -0.17446216]
# new pusher_pt:  [ 0.04  -0.174]
# step:  52
# pusher_contact_angle:  -1.3462628054816514
# pusher inside the slider
# input pusher_rel_vel:  [-8.48791811e-05  9.99999640e-02]
# contact_angle:  -1.3462628054816514
# norm:  [-0.22265162  0.97489808]
# projection:  0.09750867090570609
# pusher_rel_vel:  [-0.02171046  0.09506102]
# projected point:  [-2.81415668e-02  1.23220121e-01  8.77026400e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02165182  0.09507283  0.002843  ]
# pusher velocity:  [-0.02171046  0.09506102]
# contact velocity:  [-0.02162756  0.09759133]
# new contact point:  [ 0.0399914  -0.17396219]
# new pusher_pt:  [ 0.04   -0.1735]
# step:  53
# pusher_contact_angle:  -1.34570696628805
# pusher inside the slider
# input pusher_rel_vel:  [-8.34576820e-05  9.99999652e-02]
# contact_angle:  -1.34570696628805
# norm:  [-0.22319347  0.97477417]
# projection:  0.09749600989011359
# pusher_rel_vel:  [-0.02176047  0.09503659]
# projected point:  [-0.02821007  0.12320452  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02164893  0.09506017  0.00284262]
# pusher velocity:  [-0.02176047  0.09503659]
# contact velocity:  [-0.02162764  0.09759165]
# new contact point:  [ 0.03999138 -0.17346223]
# new pusher_pt:  [ 0.04  -0.173]
# step:  54
# pusher_contact_angle:  -1.3451497345265144
# pusher inside the slider
# input pusher_rel_vel:  [-8.20363723e-05  9.99999664e-02]
# contact_angle:  -1.3451497345265144
# norm:  [-0.22373661  0.97464964]
# projection:  0.09748328618885403
# pusher_rel_vel:  [-0.02181058  0.09501205]
# projected point:  [-2.82787389e-02  1.23188882e-01 -8.77027542e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02164604  0.09504744  0.00284224]
# pusher velocity:  [-0.02181058  0.09501205]
# contact velocity:  [-0.02162771  0.09759197]
# new contact point:  [ 0.03999137 -0.17296226]
# new pusher_pt:  [ 0.04   -0.1725]
# step:  55
# pusher_contact_angle:  -1.3445911069822332
# pusher inside the slider
# input pusher_rel_vel:  [-8.06152527e-05  9.99999675e-02]
# contact_angle:  -1.3445911069822332
# norm:  [-0.22428104  0.97452451]
# projection:  0.09747049950201603
# pusher_rel_vel:  [-0.02186079  0.09498739]
# projected point:  [-0.02834758  0.1231732   0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02164312  0.09503466  0.00284186]
# pusher velocity:  [-0.02186079  0.09498739]
# contact velocity:  [-0.02162779  0.0975923 ]
# new contact point:  [ 0.03999136 -0.1724623 ]
# new pusher_pt:  [ 0.04  -0.172]
# step:  56
# pusher_contact_angle:  -1.344031080434359
# pusher inside the slider
# input pusher_rel_vel:  [-7.91943242e-05  9.99999686e-02]
# contact_angle:  -1.344031080434359
# norm:  [-0.22482677  0.97439875]
# projection:  0.09745764952834209
# pusher_rel_vel:  [-0.02191109  0.09496261]
# projected point:  [-0.0284166   0.12315749  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.0216402   0.09502181  0.00284147]
# pusher velocity:  [-0.02191109  0.09496261]
# contact velocity:  [-0.02162786  0.09759263]
# new contact point:  [ 0.03999134 -0.17196234]
# new pusher_pt:  [ 0.04   -0.1715]
# step:  57
# pusher_contact_angle:  -1.3434696516560083
# pusher inside the slider
# input pusher_rel_vel:  [-7.77735879e-05  9.99999698e-02]
# contact_angle:  -1.3434696516560083
# norm:  [-0.22537379  0.97427237]
# projection:  0.09744473596522338
# pusher_rel_vel:  [-0.02196149  0.09493771]
# projected point:  [-2.84857892e-02  1.23141728e-01  8.77031324e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02163726  0.0950089   0.00284109]
# pusher velocity:  [-0.02196149  0.09493771]
# contact velocity:  [-0.02162794  0.09759295]
# new contact point:  [ 0.03999133 -0.17146237]
# new pusher_pt:  [ 0.04  -0.171]
# step:  58
# pusher_contact_angle:  -1.3429068174142609
# pusher inside the slider
# input pusher_rel_vel:  [-7.63530445e-05  9.99999709e-02]
# contact_angle:  -1.3429068174142609
# norm:  [-0.2259221   0.97414537]
# projection:  0.0974317585086946
# pusher_rel_vel:  [-0.02201199  0.0949127 ]
# projected point:  [-2.85551524e-02  1.23125932e-01 -8.77033144e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.0216343   0.09499593  0.0028407 ]
# pusher velocity:  [-0.02201199  0.0949127 ]
# contact velocity:  [-0.02162801  0.09759328]
# new contact point:  [ 0.03999131 -0.17096241]
# new pusher_pt:  [ 0.04   -0.1705]
# step:  59
# pusher_contact_angle:  -1.3423425744701594
# pusher inside the slider
# input pusher_rel_vel:  [-7.49326951e-05  9.99999719e-02]
# contact_angle:  -1.3423425744701594
# norm:  [-0.22647172  0.97401774]
# projection:  0.09741871685342865
# pusher_rel_vel:  [-0.02206258  0.09488756]
# projected point:  [-2.86246894e-02  1.23110095e-01 -8.77035248e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02163134  0.09498289  0.00284031]
# pusher velocity:  [-0.02206258  0.09488756]
# contact velocity:  [-0.02162809  0.09759361]
# new contact point:  [ 0.0399913  -0.17046244]
# new pusher_pt:  [ 0.04 -0.17]
# step:  60
# pusher_contact_angle:  -1.3417769195787086
# pusher inside the slider
# input pusher_rel_vel:  [-7.35125406e-05  9.99999730e-02]
# contact_angle:  -1.3417769195787086
# norm:  [-0.22702264  0.97388948]
# projection:  0.0974056106927316
# pusher_rel_vel:  [-0.02211328  0.0948623 ]
# projected point:  [-0.0286944   0.12309422  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02162835  0.09496979  0.00283992]
# pusher velocity:  [-0.02211328  0.0948623 ]
# contact velocity:  [-0.02162816  0.09759394]
# new contact point:  [ 0.03999128 -0.16996248]
# new pusher_pt:  [ 0.04   -0.1695]
# step:  61
# pusher_contact_angle:  -1.3412098494888758
# pusher inside the slider
# input pusher_rel_vel:  [-7.20925819e-05  9.99999740e-02]
# contact_angle:  -1.3412098494888758
# norm:  [-0.22757487  0.97376059]
# projection:  0.09739243971853723
# pusher_rel_vel:  [-0.02216407  0.09483692]
# projected point:  [-0.02876429  0.1230783   0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02162535  0.09495663  0.00283952]
# pusher velocity:  [-0.02216407  0.09483692]
# contact velocity:  [-0.02162824  0.09759427]
# new contact point:  [ 0.03999127 -0.16946252]
# new pusher_pt:  [ 0.04  -0.169]
# step:  62
# pusher_contact_angle:  -1.3406413609435905
# pusher inside the slider
# input pusher_rel_vel:  [-7.06728201e-05  9.99999750e-02]
# contact_angle:  -1.3406413609435905
# norm:  [-0.22812841  0.97363105]
# projection:  0.09737920362140201
# pusher_rel_vel:  [-0.02221496  0.09481142]
# projected point:  [-0.02883435  0.12306235  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02162234  0.0949434   0.00283913]
# pusher velocity:  [-0.02221496  0.09481142]
# contact velocity:  [-0.02162832  0.0975946 ]
# new contact point:  [ 0.03999125 -0.16896255]
# new pusher_pt:  [ 0.04   -0.1685]
# step:  63
# pusher_contact_angle:  -1.3400714506797446
# pusher inside the slider
# input pusher_rel_vel:  [-6.92532559e-05  9.99999760e-02]
# contact_angle:  -1.3400714506797446
# norm:  [-0.22868325  0.97350088]
# projection:  0.09736590209049961
# pusher_rel_vel:  [-0.02226595  0.09478579]
# projected point:  [-2.89045858e-02  1.23046352e-01  8.77046540e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02161931  0.09493011  0.00283873]
# pusher velocity:  [-0.02226595  0.09478579]
# contact velocity:  [-0.0216284   0.09759493]
# new contact point:  [ 0.03999124 -0.16846259]
# new pusher_pt:  [ 0.04  -0.168]
# step:  64
# pusher_contact_angle:  -1.3395001154281918
# pusher inside the slider
# input pusher_rel_vel:  [-6.78338906e-05  9.99999770e-02]
# contact_angle:  -1.3395001154281918
# norm:  [-0.22923941  0.97337007]
# projection:  0.09735253481361589
# pusher_rel_vel:  [-0.02231704  0.09476004]
# projected point:  [-0.028975    0.12303032  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02161627  0.09491675  0.00283833]
# pusher velocity:  [-0.02231704  0.09476004]
# contact velocity:  [-0.02162847  0.09759526]
# new contact point:  [ 0.03999122 -0.16796263]
# new pusher_pt:  [ 0.04   -0.1675]
# step:  65
# pusher_contact_angle:  -1.3389273519137486
# pusher inside the slider
# input pusher_rel_vel:  [-6.64147249e-05  9.99999779e-02]
# contact_angle:  -1.3389273519137486
# norm:  [-0.22979688  0.97323861]
# projection:  0.0973391014771434
# pusher_rel_vel:  [-0.02236822  0.09473417]
# projected point:  [-2.90455892e-02  1.23014240e-01 -8.77053942e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02161322  0.09490333  0.00283793]
# pusher velocity:  [-0.02236822  0.09473417]
# contact velocity:  [-0.02162855  0.0975956 ]
# new contact point:  [ 0.03999121 -0.16746266]
# new pusher_pt:  [ 0.04  -0.167]
# step:  66
# pusher_contact_angle:  -1.3383531568551947
# pusher inside the slider
# input pusher_rel_vel:  [-6.49957599e-05  9.99999789e-02]
# contact_angle:  -1.3383531568551947
# norm:  [-0.23035567  0.9731065 ]
# projection:  0.09732560176607626
# pusher_rel_vel:  [-0.0224195   0.09470818]
# projected point:  [-0.02911636  0.12299812  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02161014  0.09488985  0.00283753]
# pusher velocity:  [-0.0224195   0.09470818]
# contact velocity:  [-0.02162863  0.09759593]
# new contact point:  [ 0.0399912 -0.1669627]
# new pusher_pt:  [ 0.04   -0.1665]
# step:  67
# pusher_contact_angle:  -1.3377775269652727
# pusher inside the slider
# input pusher_rel_vel:  [-6.35769965e-05  9.99999798e-02]
# contact_angle:  -1.3377775269652727
# norm:  [-0.23091578  0.97297374]
# projection:  0.09731203536400472
# pusher_rel_vel:  [-0.02247088  0.09468206]
# projected point:  [-2.91873008e-02  1.22981967e-01  8.77062538e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02160706  0.09487629  0.00283712]
# pusher velocity:  [-0.02247088  0.09468206]
# contact velocity:  [-0.02162871  0.09759626]
# new contact point:  [ 0.03999118 -0.16646274]
# new pusher_pt:  [ 0.04  -0.166]
# step:  68
# pusher_contact_angle:  -1.3372004589506892
# pusher inside the slider
# input pusher_rel_vel:  [-6.21584357e-05  9.99999807e-02]
# contact_angle:  -1.3372004589506892
# norm:  [-0.23147722  0.97284032]
# projection:  0.09729840195311007
# pusher_rel_vel:  [-0.02252236  0.09465581]
# projected point:  [-2.92584234e-02  1.22965769e-01 -8.77067290e-19]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02160396  0.09486267  0.00283671]
# pusher velocity:  [-0.02252236  0.09465581]
# contact velocity:  [-0.02162879  0.0975966 ]
# new contact point:  [ 0.03999117 -0.16596278]
# new pusher_pt:  [ 0.04   -0.1655]
# step:  69
# pusher_contact_angle:  -1.3366219495121152
# pusher inside the slider
# input pusher_rel_vel:  [-6.07400786e-05  9.99999816e-02]
# contact_angle:  -1.3366219495121152
# norm:  [-0.23203998  0.97270625]
# projection:  0.09728470121415904
# pusher_rel_vel:  [-0.02257394  0.09462944]
# projected point:  [-0.02932972  0.12294953  0.        ]
# normal:  [-0.02219593  0.09746203  0.00291444]
# slider velocity:  [-0.02160084  0.09484899  0.00283631]
# pusher velocity:  [-0.02257394  0.09462944]
# contact velocity:  [-0.02162887  0.09759694]
# new contact point:  [ 0.03999115 -0.16546281]
# new pusher_pt:  [ 0.04  -0.165]
# step:  70
# pusher_contact_angle:  -1.3360419953441867
# pusher inside the slider
# input pusher_rel_vel:  [-5.93219261e-05  9.99999824e-02]
# contact_angle:  -1.3360419953441867
# norm:  [-0.23260406  0.97257151]
# projection:  0.09727093282649865
# pusher_rel_vel:  [-0.02262561  0.09460294]
# projected point:  [-0.02940102  0.12293247  0.        ]
# normal:  [-0.02347179  0.09680792 -0.00879218]
# slider velocity:  [-0.02291492  0.09451114 -0.00858359]
# pusher velocity:  [-0.02262561  0.09460294]
# contact velocity:  [-0.02518224  0.09639991]
# new contact point:  [ 0.03999114 -0.16496286]
# new pusher_pt:  [ 0.04   -0.1645]
# step:  71
# pusher_contact_angle:  -1.3354607213494494
# pusher inside the slider
# input pusher_rel_vel:  [-6.36137195e-05  9.99999798e-02]
# contact_angle:  -1.3354607213494494
# norm:  [-0.23316935  0.97243614]
# projection:  0.09725842741328931
# pusher_rel_vel:  [-0.02267768  0.09457761]
# projected point:  [-0.02947242  0.12291516  0.        ]
# normal:  [-0.02347179  0.09680792 -0.00879218]
# slider velocity:  [-0.02291219  0.09449989 -0.00858257]
# pusher velocity:  [-0.02267768  0.09457761]
# contact velocity:  [-0.02518202  0.09639899]
# new contact point:  [ 0.03999113 -0.1644629 ]
# new pusher_pt:  [ 0.04  -0.164]
# step:  72
# pusher_contact_angle:  -1.3348781354055606
# pusher inside the slider
# input pusher_rel_vel:  [-6.79050017e-05  9.99999769e-02]
# contact_angle:  -1.3348781354055606
# norm:  [-0.23373584  0.97230014]
# projection:  0.09724586311459504
# pusher_rel_vel:  [-0.02272984  0.09455217]
# projected point:  [-2.95439867e-02  1.22897807e-01 -8.77069550e-19]
# normal:  [-0.02347179  0.09680792 -0.00879218]
# slider velocity:  [-0.02290945  0.09448858 -0.00858154]
# pusher velocity:  [-0.02272984  0.09455217]
# contact velocity:  [-0.0251818   0.09639807]
# new contact point:  [ 0.03999112 -0.16396293]
# new pusher_pt:  [ 0.04   -0.1635]
# step:  73
# pusher_contact_angle:  -1.3342942344729527
# pusher inside the slider
# input pusher_rel_vel:  [-7.21957704e-05  9.99999739e-02]
# contact_angle:  -1.3342942344729527
# norm:  [-0.23430353  0.97216349]
# projection:  0.09723323965510956
# pusher_rel_vel:  [-0.02278209  0.09452661]
# projected point:  [-0.02961571  0.12288042  0.        ]
# normal:  [-0.02347179  0.09680792 -0.00879218]
# slider velocity:  [-0.0229067   0.09447722 -0.00858051]
# pusher velocity:  [-0.02278209  0.09452661]
# contact velocity:  [-0.02518158  0.09639714]
# new contact point:  [ 0.0399911  -0.16346297]
# new pusher_pt:  [ 0.04  -0.163]
# step:  74
# pusher_contact_angle:  -1.3337090155062248
# pusher inside the slider
# input pusher_rel_vel:  [-7.64860228e-05  9.99999707e-02]
# contact_angle:  -1.3337090155062248
# norm:  [-0.23487242  0.97202621]
# projection:  0.09722055675829681
# pusher_rel_vel:  [-0.02283443  0.09450093]
# projected point:  [-2.96876014e-02  1.22862987e-01  8.77068151e-19]
# normal:  [-0.02347179  0.09680792 -0.00879218]
# slider velocity:  [-0.02290393  0.0944658  -0.00857947]
# pusher velocity:  [-0.02283443  0.09450093]
# contact velocity:  [-0.02518135  0.09639621]
# new contact point:  [ 0.03999109 -0.16296301]
# new pusher_pt:  [ 0.04   -0.1625]
# step:  75
# pusher_contact_angle:  -1.3331224754541395
# pusher inside the slider
# input pusher_rel_vel:  [-8.07757566e-05  9.99999674e-02]
# contact_angle:  -1.3331224754541395
# norm:  [-0.23544251  0.97188828]
# projection:  0.09720781414638617
# pusher_rel_vel:  [-0.02288685  0.09447514]
# projected point:  [-2.97596464e-02  1.22845495e-01 -8.77067740e-19]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02314843  0.09440815  0.00601897]
# pusher velocity:  [-0.02288685  0.09447514]
# contact velocity:  [-0.02256705  0.09722745]
# new contact point:  [ 0.03999108 -0.16246304]
# new pusher_pt:  [ 0.04  -0.162]
# step:  76
# pusher_contact_angle:  -1.3325344474192378
# pusher inside the slider
# input pusher_rel_vel:  [-7.77662719e-05  9.99999698e-02]
# contact_angle:  -1.3325344474192378
# norm:  [-0.23601397  0.97174966]
# projection:  0.09719329086700448
# pusher_rel_vel:  [-0.02293897  0.09444755]
# projected point:  [-0.02983183  0.12282779  0.        ]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02314479  0.09439333  0.00601803]
# pusher velocity:  [-0.02293897  0.09444755]
# contact velocity:  [-0.02256723  0.09722819]
# new contact point:  [ 0.03999106 -0.16196308]
# new pusher_pt:  [ 0.04   -0.1615]
# step:  77
# pusher_contact_angle:  -1.3319449140941086
# pusher inside the slider
# input pusher_rel_vel:  [-7.47572599e-05  9.99999721e-02]
# contact_angle:  -1.3319449140941086
# norm:  [-0.2365868   0.97161036]
# projection:  0.09717869506016716
# pusher_rel_vel:  [-0.0229912   0.09441983]
# projected point:  [-2.99042068e-02  1.22810049e-01 -1.75413096e-18]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02314114  0.09437843  0.00601708]
# pusher velocity:  [-0.0229912   0.09441983]
# contact velocity:  [-0.02256741  0.09722893]
# new contact point:  [ 0.03999105 -0.16146312]
# new pusher_pt:  [ 0.04  -0.161]
# step:  78
# pusher_contact_angle:  -1.331353872051423
# pusher inside the slider
# input pusher_rel_vel:  [-7.17487227e-05  9.99999743e-02]
# contact_angle:  -1.331353872051423
# norm:  [-0.23716102  0.97147035]
# projection:  0.09716402637989052
# pusher_rel_vel:  [-0.02304352  0.09439197]
# projected point:  [-2.99767643e-02  1.22792259e-01  8.77064803e-19]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02313747  0.09436345  0.00601612]
# pusher velocity:  [-0.02304352  0.09439197]
# contact velocity:  [-0.02256759  0.09722968]
# new contact point:  [ 0.03999103 -0.16096316]
# new pusher_pt:  [ 0.04   -0.1605]
# step:  79
# pusher_contact_angle:  -1.3307613178577984
# pusher inside the slider
# input pusher_rel_vel:  [-6.87406628e-05  9.99999764e-02]
# contact_angle:  -1.3307613178577984
# norm:  [-0.23773663  0.97132965]
# projection:  0.09714928447866575
# pusher_rel_vel:  [-0.02309594  0.09436398]
# projected point:  [-0.03004951  0.12277442  0.        ]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02313378  0.09434841  0.00601516]
# pusher velocity:  [-0.02309594  0.09436398]
# contact velocity:  [-0.02256778  0.09723043]
# new contact point:  [ 0.03999102 -0.1604632 ]
# new pusher_pt:  [ 0.04 -0.16]
# step:  80
# pusher_contact_angle:  -1.3301672480738018
# pusher inside the slider
# input pusher_rel_vel:  [-6.57330823e-05  9.99999784e-02]
# contact_angle:  -1.3301672480738018
# norm:  [-0.23831363  0.97118825]
# projection:  0.09713446900745351
# pusher_rel_vel:  [-0.02314847  0.09433585]
# projected point:  [-0.03012244  0.12275654  0.        ]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02313007  0.09433329  0.0060142 ]
# pusher velocity:  [-0.02314847  0.09433585]
# contact velocity:  [-0.02256796  0.09723118]
# new contact point:  [ 0.039991   -0.15996324]
# new pusher_pt:  [ 0.04   -0.1595]
# step:  81
# pusher_contact_angle:  -1.3295716592539526
# pusher inside the slider
# input pusher_rel_vel:  [-6.27259837e-05  9.99999803e-02]
# contact_angle:  -1.3295716592539526
# norm:  [-0.23889201  0.97104614]
# projection:  0.09711957961567828
# pusher_rel_vel:  [-0.02320109  0.09430759]
# projected point:  [-3.01955522e-02  1.22738613e-01 -1.75412924e-18]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02312635  0.0943181   0.00601323]
# pusher velocity:  [-0.02320109  0.09430759]
# contact velocity:  [-0.02256814  0.09723193]
# new contact point:  [ 0.03999099 -0.15946328]
# new pusher_pt:  [ 0.04  -0.159]
# step:  82
# pusher_contact_angle:  -1.3289745479467263
# pusher inside the slider
# input pusher_rel_vel:  [-5.97193693e-05  9.99999822e-02]
# contact_angle:  -1.3289745479467263
# norm:  [-0.23947179  0.97090332]
# projection:  0.09710461595122286
# pusher_rel_vel:  [-0.02325382  0.09427919]
# projected point:  [-3.02688548e-02  1.22720639e-01 -8.77065180e-19]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.0231226   0.09430284  0.00601226]
# pusher velocity:  [-0.02325382  0.09427919]
# contact velocity:  [-0.02256833  0.09723268]
# new contact point:  [ 0.03999098 -0.15896332]
# new pusher_pt:  [ 0.04   -0.1585]
# step:  83
# pusher_contact_angle:  -1.3283759106945578
# pusher inside the slider
# input pusher_rel_vel:  [-5.67132414e-05  9.99999839e-02]
# contact_angle:  -1.3283759106945578
# norm:  [-0.24005297  0.97075979]
# projection:  0.09708957766042273
# pusher_rel_vel:  [-0.02330664  0.09425066]
# projected point:  [-3.03423449e-02  1.22702620e-01 -8.77066057e-19]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02311884  0.0942875   0.00601128]
# pusher velocity:  [-0.02330664  0.09425066]
# contact velocity:  [-0.02256851  0.09723343]
# new contact point:  [ 0.03999096 -0.15846336]
# new pusher_pt:  [ 0.04  -0.158]
# step:  84
# pusher_contact_angle:  -1.3277757440338445
# pusher inside the slider
# input pusher_rel_vel:  [-5.37076024e-05  9.99999856e-02]
# contact_angle:  -1.3277757440338445
# norm:  [-0.24063554  0.97061554]
# projection:  0.09707446438806058
# pusher_rel_vel:  [-0.02335957  0.09422198]
# projected point:  [-3.04160228e-02  1.22684555e-01 -1.75413450e-18]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02311506  0.09427209  0.0060103 ]
# pusher velocity:  [-0.02335957  0.09422198]
# contact velocity:  [-0.0225687   0.09723419]
# new contact point:  [ 0.03999095 -0.1579634 ]
# new pusher_pt:  [ 0.04   -0.1575]
# step:  85
# pusher_contact_angle:  -1.3271740444949498
# pusher inside the slider
# input pusher_rel_vel:  [-5.07024547e-05  9.99999871e-02]
# contact_angle:  -1.3271740444949498
# norm:  [-0.24121952  0.97047058]
# projection:  0.0970592757773606
# pusher_rel_vel:  [-0.02341259  0.09419317]
# projected point:  [-3.04898892e-02  1.22666443e-01  8.77068766e-19]
# normal:  [-0.02376858  0.0969374   0.00618022]
# slider velocity:  [-0.02311127  0.0942566   0.00600931]
# pusher velocity:  [-0.02341259  0.09419317]
# contact velocity:  [-0.02256889  0.09723495]
# new contact point:  [ 0.03999093 -0.15746344]
# new pusher_pt:  [ 0.04  -0.157]
# step:  86
# ...
# slider velocity:  [-0.03458971  0.0143051  -0.00384967]
# pusher velocity:  [-0.03477429  0.01385413]
# contact velocity:  [-0.09269016  0.03611927]
# new contact point:  [0.04010378 0.18645811]
# new pusher_pt:  [0.04  0.187]
# step:  774
# pusher_contact_angle:  -0.37680586713641645
# pusher inside the slider
# input pusher_rel_vel:  [-0.00045598  0.09999896]
# contact_angle:  -0.37680586713641645
# norm:  [-0.92984467  0.3679523 ]
# projection:  0.037218838753704485
# pusher_rel_vel:  [-0.03460774  0.01369476]
# projected point:  [-0.11751466  0.04650216  0.        ]
# normal:  [-0.09192424  0.03801666 -0.01023074]
# slider velocity:  [-0.03439395  0.01422414 -0.00382789]
# pusher velocity:  [-0.03460774  0.01369476]
# contact velocity:  [-0.09268579  0.03611751]
# new contact point:  [0.04010437 0.18695815]
# new pusher_pt:  [0.04   0.1875]
# step:  775
# pusher_contact_angle:  -0.37448203811419334
# pusher inside the slider
# input pusher_rel_vel:  [-0.00045789  0.09999895]
# contact_angle:  -0.37448203811419334
# norm:  [-0.93069721  0.36579051]
# projection:  0.037004828671980704
# pusher_rel_vel:  [-0.03444029  0.01353602]
# projected point:  [-0.11762692  0.04623073  0.        ]
# normal:  [-0.09192424  0.03801666 -0.01023074]
# slider velocity:  [-0.03419781  0.01414302 -0.00380606]
# pusher velocity:  [-0.03444029  0.01353602]
# contact velocity:  [-0.09268141  0.03611576]
# new contact point:  [0.04010497 0.18745819]
# new pusher_pt:  [0.04  0.188]
# step:  776
# pusher_contact_angle:  -0.3721560735882693
# pusher inside the slider
# input pusher_rel_vel:  [-0.0004598   0.09999894]
# contact_angle:  -0.3721560735882693
# norm:  [-0.93154551  0.36362476]
# projection:  0.036790413313552726
# pusher_rel_vel:  [-0.03427194  0.01337791]
# projected point:  [-1.17737843e-01  4.59584572e-02  1.75401071e-18]
# normal:  [-0.09158617  0.03699671 -0.01559543]
# slider velocity:  [-0.03410303  0.01377609 -0.00580711]
# pusher velocity:  [-0.03427194  0.01337791]
# contact velocity:  [-0.09273369  0.03409638]
# new contact point:  [0.04010558 0.18795823]
# new pusher_pt:  [0.04   0.1885]
# step:  777
# pusher_contact_angle:  -0.3698279988811886
# pusher inside the slider
# input pusher_rel_vel:  [-0.0004627   0.09999893]
# contact_angle:  -0.3698279988811886
# norm:  [-0.93238953  0.36145507]
# projection:  0.03657653696212971
# pusher_rel_vel:  [-0.03410358  0.01322077]
# projected point:  [-1.17848063e-01  4.56856045e-02 -1.75406347e-18]
# normal:  [-0.09158617  0.03699671 -0.01559543]
# slider velocity:  [-0.03390723  0.013697   -0.00577377]
# pusher velocity:  [-0.03410358  0.01322077]
# contact velocity:  [-0.09272702  0.03409375]
# new contact point:  [0.04010618 0.18845827]
# new pusher_pt:  [0.04  0.189]
# step:  778
# pusher_contact_angle:  -0.3674978184586177
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046559  0.09999892]
# contact_angle:  -0.3674978184586177
# norm:  [-0.93322925  0.35928145]
# projection:  0.0363622555966105
# pusher_rel_vel:  [-0.03393432  0.01306428]
# projected point:  [-0.11795255  0.04541024  0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03409601  0.01263084 -0.00050334]
# pusher velocity:  [-0.03393432  0.01306428]
# contact velocity:  [-0.09386415  0.03447672]
# new contact point:  [0.04010676 0.18895833]
# new pusher_pt:  [0.04   0.1895]
# step:  779
# pusher_contact_angle:  -0.3651655038682551
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046584  0.09999891]
# contact_angle:  -0.3651655038682551
# norm:  [-0.93406467  0.35710389]
# projection:  0.036145125629837134
# pusher_rel_vel:  [-0.03376188  0.01290756]
# projected point:  [-0.11805495  0.0451338   0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03389264  0.0125555  -0.00050034]
# pusher velocity:  [-0.03376188  0.01290756]
# contact velocity:  [-0.09386355  0.03447648]
# new contact point:  [0.04010736 0.18945838]
# new pusher_pt:  [0.04 0.19]
# step:  780
# pusher_contact_angle:  -0.36283108086656074
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046609  0.09999891]
# contact_angle:  -0.36283108086656074
# norm:  [-0.93489576  0.35492242]
# projection:  0.035927601304496876
# pusher_rel_vel:  [-0.03358856  0.01275151]
# projected point:  [-0.11815745  0.04485712  0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03368888  0.01248002 -0.00049733]
# pusher velocity:  [-0.03358856  0.01275151]
# contact velocity:  [-0.09386295  0.03447625]
# new contact point:  [0.04010797 0.18995844]
# new pusher_pt:  [0.04   0.1905]
# step:  781
# pusher_contact_angle:  -0.36049456023764087
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046634  0.09999891]
# contact_angle:  -0.36049456023764087
# norm:  [-0.93572249  0.35273705]
# projection:  0.03570968427288056
# pusher_rel_vel:  [-0.03341435  0.01259613]
# projected point:  [-0.11826003  0.0445802   0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03348476  0.0124044  -0.00049432]
# pusher velocity:  [-0.03341435  0.01259613]
# contact velocity:  [-0.09386234  0.03447602]
# new contact point:  [0.04010857 0.19045849]
# new pusher_pt:  [0.04  0.191]
# step:  782
# pusher_contact_angle:  -0.3581559528212495
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046659  0.09999891]
# contact_angle:  -0.3581559528212495
# norm:  [-0.93654484  0.3505478 ]
# projection:  0.035491376203120394
# pusher_rel_vel:  [-0.03323927  0.01244142]
# projected point:  [-1.18362707e-01  4.43030426e-02 -1.75390697e-18]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03328027  0.01232865 -0.0004913 ]
# pusher velocity:  [-0.03323927  0.01244142]
# contact velocity:  [-0.09386174  0.03447579]
# new contact point:  [0.04010918 0.19095855]
# new pusher_pt:  [0.04   0.1915]
# step:  783
# pusher_contact_angle:  -0.3558152695126252
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046683  0.09999891]
# contact_angle:  -0.3558152695126252
# norm:  [-0.9373628   0.34835468]
# projection:  0.03527267877916881
# pusher_rel_vel:  [-0.0330633  0.0122874]
# projected point:  [-0.11846547  0.04402564  0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03307541  0.01225276 -0.00048827]
# pusher velocity:  [-0.0330633  0.0122874]
# contact velocity:  [-0.09386113  0.03447556]
# new contact point:  [0.04010979 0.19145861]
# new pusher_pt:  [0.04  0.192]
# step:  784
# pusher_contact_angle:  -0.3534725212623242
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046708  0.09999891]
# contact_angle:  -0.3534725212623242
# norm:  [-0.93817633  0.34615773]
# projection:  0.03505359370077619
# pusher_rel_vel:  [-0.03288645  0.01213407]
# projected point:  [-0.11856832  0.043748    0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03287019  0.01217673 -0.00048524]
# pusher velocity:  [-0.03288645  0.01213407]
# contact velocity:  [-0.09386053  0.03447533]
# new contact point:  [0.0401104  0.19195868]
# new pusher_pt:  [0.04   0.1925]
# step:  785
# pusher_contact_angle:  -0.35112771907605234
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046732  0.09999891]
# contact_angle:  -0.35112771907605234
# norm:  [-0.93898542  0.34395694]
# projection:  0.03483412268346753
# pusher_rel_vel:  [-0.03270873  0.01198144]
# projected point:  [-1.18671264e-01  4.34701152e-02 -1.75390861e-18]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.0326646   0.01210057 -0.00048221]
# pusher velocity:  [-0.03270873  0.01198144]
# contact velocity:  [-0.09385992  0.0344751 ]
# new contact point:  [0.04011101 0.19245875]
# new pusher_pt:  [0.04  0.193]
# step:  786
# pusher_contact_angle:  -0.34878087401449315
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046756  0.09999891]
# contact_angle:  -0.34878087401449315
# norm:  [-0.93979005  0.34175234]
# projection:  0.03461426745851774
# pusher_rel_vel:  [-0.03253014  0.01182951]
# projected point:  [-0.1187743   0.04319198  0.        ]
# normal:  [-0.09376349  0.0347346  -0.00138417]
# slider velocity:  [-0.03245865  0.01202428 -0.00047917]
# pusher velocity:  [-0.03253014  0.01182951]
# contact velocity:  [-0.09385931  0.03447488]
# new contact point:  [0.04011162 0.19295882]
# new pusher_pt:  [0.04   0.1935]
# step:  787
# pusher_contact_angle:  -0.34643199719313145
# pusher inside the slider
# input pusher_rel_vel:  [-0.0004678   0.09999891]
# contact_angle:  -0.34643199719313145
# norm:  [-0.94059019  0.33954395]
# projection:  0.03439402977292569
# pusher_rel_vel:  [-0.03235069  0.01167828]
# projected point:  [-0.11887741  0.04291359  0.        ]
# normal:  [-0.09376485  0.03472949 -0.00141967]
# slider velocity:  [-0.03225296  0.01194615 -0.00048833]
# pusher velocity:  [-0.03235069  0.01167828]
# contact velocity:  [-0.09386251  0.03446288]
# new contact point:  [0.04011224 0.19345889]
# new pusher_pt:  [0.04  0.194]
# step:  788
# pusher_contact_angle:  -0.3440810998708527
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046804  0.0999989 ]
# contact_angle:  -0.3440810998708527
# norm:  [-0.94138582  0.33733178]
# projection:  0.03417341713561952
# pusher_rel_vel:  [-0.03217037  0.01152778]
# projected point:  [-1.18980615e-01  4.26349556e-02  1.75399681e-18]
# normal:  [-0.09376485  0.03472949 -0.00141967]
# slider velocity:  [-0.0320463  0.0118696 -0.0004852]
# pusher velocity:  [-0.03217037  0.01152778]
# contact velocity:  [-0.09386188  0.03446265]
# new contact point:  [0.04011285 0.19395896]
# new pusher_pt:  [0.04   0.1945]
# step:  789
# pusher_contact_angle:  -0.34172819323466663
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046829  0.0999989 ]
# contact_angle:  -0.34172819323466663
# norm:  [-0.94217693  0.33511586]
# projection:  0.033952425556618114
# pusher_rel_vel:  [-0.03198919  0.011378  ]
# projected point:  [-0.11907881  0.04235425  0.        ]
# normal:  [-0.09442835  0.03249581 -0.00522574]
# slider velocity:  [-0.0320978   0.01104588 -0.00177632]
# pusher velocity:  [-0.03198919  0.011378  ]
# contact velocity:  [-0.09478321  0.03151275]
# new contact point:  [0.04011347 0.19445904]
# new pusher_pt:  [0.04  0.195]
# step:  790
# pusher_contact_angle:  -0.339373297936286
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046917  0.0999989 ]
# contact_angle:  -0.339373297936286
# norm:  [-0.94296348  0.3328962 ]
# projection:  0.03373166690962357
# pusher_rel_vel:  [-0.03180773  0.01122914]
# projected point:  [-0.11917566  0.04207281  0.        ]
# normal:  [-0.09442835  0.03249581 -0.00522574]
# slider velocity:  [-0.03188988  0.01097432 -0.00176481]
# pusher velocity:  [-0.03180773  0.01122914]
# contact velocity:  [-0.0947809   0.03151192]
# new contact point:  [0.04011409 0.19495912]
# new pusher_pt:  [0.04   0.1955]
# step:  791
# pusher_contact_angle:  -0.33701642129234105
# pusher inside the slider
# input pusher_rel_vel:  [-0.00047006  0.0999989 ]
# contact_angle:  -0.33701642129234105
# norm:  [-0.94374545  0.33067283]
# projection:  0.03351053051203818
# pusher_rel_vel:  [-0.03162541  0.01108102]
# projected point:  [-1.19271211e-01  4.17906635e-02 -8.76942266e-19]
# normal:  [-0.0949386   0.03140733 -0.00049156]
# slider velocity:  [-0.0318141   0.01052465 -0.00016472]
# pusher velocity:  [-0.03162541  0.01108102]
# contact velocity:  [-0.09497155  0.0313147 ]
# new contact point:  [0.0401147 0.1954592]
# new pusher_pt:  [0.04  0.196]
# step:  792
# pusher_contact_angle:  -0.33465756312482214
# pusher inside the slider
# input pusher_rel_vel:  [-0.00047014  0.09999889]
# contact_angle:  -0.33465756312482214
# norm:  [-0.94452284  0.32844575]
# projection:  0.033288268093779085
# pusher_rel_vel:  [-0.03144153  0.01093339]
# projected point:  [-1.19364852e-01  4.15076023e-02 -8.76908436e-19]
# normal:  [-0.0949386   0.03140733 -0.00049156]
# slider velocity:  [-0.03160317  0.01045487 -0.00016363]
# pusher velocity:  [-0.03144153  0.01093339]
# contact velocity:  [-0.09497133  0.03131462]
# new contact point:  [0.04011532 0.19595929]
# new pusher_pt:  [0.04   0.1965]
# step:  793
# pusher_contact_angle:  -0.3322967397451192
# pusher inside the slider
# input pusher_rel_vel:  [-0.00047022  0.09999889]
# contact_angle:  -0.3322967397451192
# norm:  [-0.94529561  0.32621498]
# projection:  0.03306563459950619
# pusher_rel_vel:  [-0.0312568   0.01078651]
# projected point:  [-1.19458565e-01  4.12243257e-02  8.76879467e-19]
# normal:  [-0.0949386   0.03140733 -0.00049156]
# slider velocity:  [-0.03139187  0.01038497 -0.00016254]
# pusher velocity:  [-0.0312568   0.01078651]
# contact velocity:  [-0.09497111  0.03131454]
# new contact point:  [0.04011595 0.19645938]
# new pusher_pt:  [0.04  0.197]
# step:  794
# pusher_contact_angle:  -0.32993396267067354
# pusher inside the slider
# input pusher_rel_vel:  [-0.0004703   0.09999889]
# contact_angle:  -0.32993396267067354
# norm:  [-0.94606374  0.32398055]
# projection:  0.03284263189330065
# pusher_rel_vel:  [-0.03107122  0.01064037]
# projected point:  [-1.19551900e-01  4.09406777e-02  8.76852069e-19]
# normal:  [-0.09499499  0.03117913  0.00195275]
# slider velocity:  [-0.0312067   0.01024262  0.0006415 ]
# pusher velocity:  [-0.03107122  0.01064037]
# contact velocity:  [-0.09486673  0.03154802]
# new contact point:  [0.04011656 0.19695947]
# new pusher_pt:  [0.04   0.1975]
# step:  795
# pusher_contact_angle:  -0.3275692377126651
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046998  0.0999989 ]
# contact_angle:  -0.3275692377126651
# norm:  [-0.94682722  0.32174247]
# projection:  0.032618881799721576
# pusher_rel_vel:  [-0.03088445  0.01049488]
# projected point:  [-1.19645093e-01  4.06567397e-02 -8.76827992e-19]
# normal:  [-0.09499499  0.03117913  0.00195275]
# slider velocity:  [-0.03099381  0.01017275  0.00063712]
# pusher velocity:  [-0.03088445  0.01049488]
# contact velocity:  [-0.0948676   0.03154832]
# new contact point:  [0.04011719 0.19745956]
# new pusher_pt:  [0.04  0.198]
# step:  796
# pusher_contact_angle:  -0.3252025790439252
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046966  0.0999989 ]
# contact_angle:  -0.3252025790439252
# norm:  [-0.94758602  0.31950075]
# projection:  0.0323947679354289
# pusher_rel_vel:  [-0.03069683  0.01035015]
# projected point:  [-0.11973836  0.04037258  0.        ]
# normal:  [-0.09499499  0.03117913  0.00195275]
# slider velocity:  [-0.03078058  0.01010276  0.00063274]
# pusher velocity:  [-0.03069683  0.01035015]
# contact velocity:  [-0.09486847  0.03154862]
# new contact point:  [0.04011781 0.19795966]
# new pusher_pt:  [0.04   0.1985]
# step:  797
# pusher_contact_angle:  -0.3228339984054349
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046935  0.0999989 ]
# contact_angle:  -0.3228339984054349
# norm:  [-0.94834013  0.31725543]
# projection:  0.03217029223225546
# pusher_rel_vel:  [-0.03050838  0.0102062 ]
# projected point:  [-1.19831659e-01  4.00881951e-02  8.76794248e-19]
# normal:  [-0.09496049  0.03102968  0.00443437]
# slider velocity:  [-0.03058112  0.00999281  0.00142805]
# pusher velocity:  [-0.03050838  0.0102062 ]
# contact velocity:  [-0.09467518  0.03186941]
# new contact point:  [0.04011844 0.19845976]
# new pusher_pt:  [0.04  0.199]
# step:  798
# pusher_contact_angle:  -0.3204635018881761
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046863  0.0999989 ]
# contact_angle:  -0.3204635018881761
# norm:  [-0.94908951  0.3150065 ]
# projection:  0.03194507719791079
# pusher_rel_vel:  [-0.03031874  0.01006291]
# projected point:  [-0.1199247   0.03980347  0.        ]
# normal:  [-0.09496049  0.03102968  0.00443437]
# slider velocity:  [-0.03036639  0.00992265  0.00141802]
# pusher velocity:  [-0.03031874  0.01006291]
# contact velocity:  [-0.09467718  0.03187008]
# new contact point:  [0.04011906 0.19895986]
# new pusher_pt:  [0.04   0.1995]
# step:  799
# pusher_contact_angle:  -0.31809110391153644
# pusher inside the slider
# input pusher_rel_vel:  [-0.00046792  0.09999891]
# contact_angle:  -0.31809110391153644
# norm:  [-0.94983416  0.312754  ]
# projection:  0.031719506001060715
# pusher_rel_vel:  [-0.03012827  0.0099204 ]
# projected point:  [-1.20017806e-01  3.95185284e-02  8.76774970e-19]
# normal:  [-0.09496049  0.03102968  0.00443437]
# slider velocity:  [-0.03015133  0.00985237  0.00140798]
# pusher velocity:  [-0.03012827  0.0099204 ]
# contact velocity:  [-0.09467918  0.03187075]
# new contact point:  [0.04011969 0.19945997]
# new pusher_pt:  [0.04 0.2 ]
# <video width="800" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...
