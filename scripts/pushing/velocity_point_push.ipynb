# %%
"""
This implements the velocity-controlled point pusher system. We simplify the analysis by assuming that
the relative velocity is to be passed on the slider from the pusher, under the assumption that at small
velocity the acceleration acts in the direction of the realtive velocity until objects move. The effect
of the force and acceleration are to be ignored, hence a quasi-static system is assumed.

Different modes are to be considered:
1) simple model: ignore friction between pusher and slider. Only pass the normal velocity to the slider.
This creates a translating velocity and a rotation velocity
2) friction model: assume the friction cone to be certain shapes, and consider the sticking and sliding modes.

Object models to be considered:
1) cylinders
2) blocks
"""
import numpy as np
class Slider:
    def __init__(self, transform, shape):
        # transform: x,y,theta
        # shape: cylinder is radius, block is (height, width)
        self.transform = transform
        x,y,theta = transform
        tf_mat = [[np.cos(theta), -np.sin(theta),x], [np.sin(theta), np.cos(theta),y],[0,0,1]]
        tf_mat = np.array(tf_mat)
        self.tf_mat = tf_mat
        self.shape = shape
        self.tran_vel = np.zeros((2))
        self.rot_vel = 0
        self.type = 'none'
    def get_tf_mat(self, transform):
        x,y,theta = transform
        tf_mat = [[np.cos(theta), -np.sin(theta),x], [np.sin(theta), np.cos(theta),y],[0,0,1]]
        tf_mat = np.array(tf_mat)
        return tf_mat
    def update_transform(self, new_transform):
        self.transform = new_transform
        self.tf_mat = self.get_tf_mat(new_transform)
    def update_vel(self, tran_vel, rot_vel):
        self.tran_vel = tran_vel
        self.rot_vel = rot_vel
    def get_contact_pt(self, contact_angle):
        pass
    def get_normal_local(self, contact_angle):
        # any convex object can map 1-to-1 to a unit circle
        # this is in the local frame
        pass
    def get_tran_vel(self, contact_angle, vel):
        # get the vector from contact point to COM
        pt = self.get_contact_pt(contact_angle)
        pt = pt/np.linalg.norm(pt)
        return vel.dot(pt)*pt
    def get_rot_vel(self, contact_angle, vel):
        # get the vector from contact point to COM
        pt = self.get_contact_pt(contact_angle)
        norm = np.linalg.norm(pt)
        pt = pt/np.linalg.norm(pt)
        # linear_v = vel - vel.dot(norm)*norm
        linear_v = np.cross(vel, pt)  # |a||b|sin(theta)
        ang_v = linear_v / norm
        return ang_v
    def get_vel_at_contact(self, contact_angle, tran_vel, rot_vel):
        # get the contact poitn velocity, assuming the object is undergoing velocity
        pass
    def get_cur_vel_at_contact(self, contact_angle):
        # get the contact point velocity based on the object current velocity
        pass


# TODO: implement cylinder and block sliders. Write an animation for these
class CylinderSlider(Slider):
    def __init__(self, transform, shape):
        super().__init__(transform, shape)
        self.radius = shape  # shape is a float
        self.type = 'cylinder'
    def get_contact_pt(self, contact_angle):
        return self.radius*np.array([np.cos(contact_angle),np.sin(contact_angle)])
    def get_contact_pt_in_world(self, contact_angle):
        contact_pt = self.get_contact_pt(contact_angle)
        return self.tf_mat[:2,:2].dot(contact_pt) + self.tf_mat[:2,2]
    def get_normal_local(self, contact_angle):
        return -np.array([np.cos(contact_angle),np.sin(contact_angle)])
    def get_vel_at_contact(self, contact_angle, tran_vel, rot_vel):
        linear_v = rot_vel * self.radius
        linear_v = np.array([0,0,linear_v])
        # get the vector pointing from the COM to the contact point. This is useful to get the
        # linear velocity at the contact point
        contact_pt = self.get_contact_pt(contact_angle)
        contact_pt_vec = self.tf_mat[:2,:2].dot(contact_pt)
        contact_pt_vec = contact_pt_vec / np.linalg.norm(contact_pt_vec)
        contact_pt_vec = np.array([contact_pt_vec[0], contact_pt_vec[1], 0])
        linear_v = np.cross(linear_v,contact_pt_vec)[:2]
        return tran_vel + linear_v
    def get_cur_vel_at_contact(self, contact_angle):
        # get the contact point velocity based on the object current velocity
        return self.get_vel_at_contact(contact_angle, self.tran_vel, self.rot_vel)

    
class BlockSlider(Slider):
    def __init__(self, transform, shape):
        super().__init__(transform, shape)
        self.width = shape[0]
        self.height = shape[1]
        self.shape = np.array(shape[:2])
        self.type = 'block'
    def get_contact_pt(self, contact_angle):
        pt = np.array([np.cos(contact_angle),np.sin(contact_angle)])
        # map to rectangular
        ratio = np.array([self.width,self.height])/2/np.abs(pt)
        ratio = np.min(ratio)
        pt = pt * ratio
        return pt
    def get_contact_pt_in_world(self, contact_angle):
        contact_pt = self.get_contact_pt(contact_angle)
        return self.tf_mat[:2,:2].dot(contact_pt) + self.tf_mat[:2,2]
    def get_normal_local(self, contact_angle):
        # this is useful to project the velocity to ignore friction
        pt = self.get_contact_pt(contact_angle)
        if (pt[0] > -self.width/2) and (pt[0] < self.width/2):
            norm = -np.array([0,np.sign(pt[1])])
        if (pt[1] > -self.height/2) and (pt[1] < self.height/2):
            norm = -np.array([np.sign(pt[0]),0])
        return norm
    def get_vel_at_contact(self, contact_angle, tran_vel, rot_vel):
        pt = self.get_contact_pt(contact_angle)
        linear_v = rot_vel * np.linalg.norm(pt)
        linear_v = np.array([0,0,linear_v])
        # get the vector pointing from the COM to the contact point. This is useful to get the
        # linear velocity at the contact point
        contact_pt = self.get_contact_pt(contact_angle)
        contact_pt_vec = self.tf_mat[:2,:2].dot(contact_pt)
        contact_pt_vec = contact_pt_vec / np.linalg.norm(contact_pt_vec)
        contact_pt_vec = np.array([contact_pt_vec[0], contact_pt_vec[1], 0])
        linear_v = np.cross(linear_v,contact_pt_vec)[:2]
        return tran_vel + linear_v
    def get_cur_vel_at_contact(self, contact_angle):
        # get the contact point velocity based on the object current velocity
        return self.get_vel_at_contact(contact_angle, self.tran_vel, self.rot_vel)

    
    

# TODO: what about robot models? How to infer that?
# maybe we can randomly select a point on the robot arm geometry, and assuming convex shape. Then
# iteratively refine until the robot geometry roughly covers the point and is normal to that.
# This pushing motion will be noisy, so we need a controller to decide the velocity after a certain
# period for feedback control

class System:
    def __init__(self, slider: Slider, dt):
        self.slider = slider
        self.dt = dt
    def get_contact_point(self, pusher_pt):
        """
        at current slider transform, get the current contact point given the pusher point in the world frame
        """
        pass
    def update_slider_transform(self, s0, v0, v1):
        """
        v0: velocity before updating the velocity of the slider. (e.g. default is static)
        v1: velocity after update
        both v0 and v1 are of form [vx, vy, omega]
        """
        # we use a simple euler integration
        s1 = s0 + self.dt * v1
        return s1

    def update_slider_rel(self, contact_angle, pusher_rel_vel):
        """
        given the contact angle, update the slider velocity and transform.
        The pusher_rel_velocity is in the frame of the slider
        NOTE: in quasi-static assumption, we basically assume that the contact velocity is equivalent
        to the pusher velocity in the slider after the pusher-slider friction effect
        """
        # frictionless: we ignore the tangent velocity to the boundary, and only take the normal velocity
        norm = self.slider.get_normal_local(contact_angle)
#         print('norm: ', norm)
        pusher_rel_vel = pusher_rel_vel.dot(norm) * norm

#         print("pusher_rel_vel after projecting: ", pusher_rel_vel)
        rel_tran_vel = self.slider.get_tran_vel(contact_angle, pusher_rel_vel)
        rel_rot_vel = self.slider.get_rot_vel(contact_angle, pusher_rel_vel)
        # TODO: map the relative velocity to world frame, and update
        tran_vel = self.slider.tran_vel + self.slider.tf_mat[:2,:2].dot(rel_tran_vel)
        rot_vel = self.slider.rot_vel + rel_rot_vel
        v0 = np.array([self.slider.tran_vel[0],self.slider.tran_vel[1],self.slider.rot_vel])
        v1 = np.array([tran_vel[0],tran_vel[1],rot_vel])
        transform = self.update_slider_transform(self.slider.transform, v0, v1)
        self.slider.update_transform(transform)
        self.slider.update_vel(tran_vel, rot_vel)

    def update_slider(self, contact_angle, pusher_vel_in_slider):
        """
        given the contact angle, update the slider velocity and transform.
        The pusher_vel_in_slider is in the frame of the slider
        NOTE: in quasi-static assumption, we basically assume that the contact velocity is equivalent
        to the pusher velocity in the slider after the pusher-slider friction effect
        """
        # compute the relative velocity of the pusher w.r.t. the slider
        contact_vel = self.slider.get_cur_vel_at_contact(contact_angle) # in world frame
        contact_vel_in_slider = self.slider.tf_mat[:2,:2].dot(contact_vel)
#         print('contact_vel_in_slider: ', contact_vel_in_slider)
        pusher_rel_vel = pusher_vel_in_slider - contact_vel_in_slider
#         print('pusher_rel_vel: ', pusher_rel_vel)
        self.update_slider_rel(contact_angle, pusher_rel_vel)
        
        print('slider translation velocity: ', self.slider.tran_vel)
        print('slider rotation velocity: ', self.slider.rot_vel)

# %%
class PointPusher:
    def __init__(self, start_position, waypoints, velocity):
        self.start_position = start_position
        self.waypoints = waypoints
        self.next_waypoint_i = 1
        self.velocity = velocity

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import matplotlib as mpl
from IPython import display
"""
implement the animation for the pusher-slider system
"""
class SystemAnimationRelativePusher:
    def __init__(self, slider: Slider, pusher_contact_angle, pusher_rel_vel, dt):
        self.system = System(slider, dt)
        self.pusher_contact_angle = pusher_contact_angle
        self.pusher_rel_vel = pusher_rel_vel
        self.fig, self.ax = plt.subplots(figsize=(8, 8))
    
    def get_ori(self):
        # get the orientation x0, x1, y0, y1 for the slider
        vec = self.system.slider.tf_mat[:2,:2].dot([1,0]) * 0.1
        start_pos = self.system.slider.transform[:2]
        end_pos = start_pos + vec
        return start_pos, end_pos

    def init_anim(self):
        # plot the slider at the start position
        if self.system.slider.type == 'cylinder':
            self.slider_anim = plt.Circle((self.system.slider.transform[0],self.system.slider.transform[1]),
                                self.system.slider.radius, color='b')
            start_ori, end_ori = self.get_ori()
            self.slider_ori_anim, = self.ax.plot([start_ori[0], end_ori[0]],
                                           [start_ori[1], end_ori[1]],
                                           color='r')
        else:
            self.slider_anim = plt.Rectangle(self.system.slider.transform[:2]-self.system.slider.shape/2,
                                             self.system.slider.width,
                                             self.system.slider.height,
                                             color='b')
            transform = self.system.slider.transform
            t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                            transform[2]/np.pi * 180) + self.ax.transData
            self.slider_anim.set_transform(t)
            start_ori, end_ori = self.get_ori()
            self.slider_ori_anim, = self.ax.plot([start_ori[0], end_ori[0]],
                                           [start_ori[1], end_ori[1]],
                                           color='r')
            
        # plot the pusher
        # get the transform of the pusher in the world frame
        pusher_pt = self.system.slider.get_contact_pt_in_world(self.pusher_contact_angle)
        self.pusher_anim = plt.Circle((pusher_pt[0], pusher_pt[1]), 0.01, color='green')
        self.ax.set_xlim(-2, 2)
        self.ax.set_ylim(-2, 2)

        self.ax.add_patch(self.slider_anim)
        self.ax.add_patch(self.pusher_anim)
        return self.slider_anim, self.pusher_anim, self.slider_ori_anim, 
    def step(self, i):
        print('step: ', i)
        # update the slider based on the pusher
        self.system.update_slider(self.pusher_contact_angle, self.pusher_rel_vel)
        if self.system.slider.type == 'cylinder':
            self.slider_anim.center = self.system.slider.transform[0],self.system.slider.transform[1]
        else:
            transform = self.system.slider.transform
            self.slider_anim.set_xy([transform[0]-self.system.slider.width/2, 
                                     transform[1]-self.system.slider.height/2])
            t = mpl.transforms.Affine2D().rotate_deg_around(transform[0], transform[1], \
                                                            transform[2]/np.pi * 180) + self.ax.transData
            self.slider_anim.set_transform(t)      
        start_ori, end_ori = self.get_ori()
#         print('start ori: ', start_ori)
#         print('start ori: ', start_ori)

        self.slider_ori_anim.set_xdata([start_ori[0], end_ori[0]])
        self.slider_ori_anim.set_ydata([start_ori[1], end_ori[1]])

        # get the relative position again
        pusher_pt = self.system.slider.get_contact_pt_in_world(self.pusher_contact_angle)
        self.pusher_anim.center = pusher_pt[0],pusher_pt[1]
        
        return self.slider_anim, self.pusher_anim,
    def anim(self):
        ani = FuncAnimation(self.fig, self.step, frames=np.arange(0,400,1),
                            init_func=self.init_anim, interval=int(1000*dt), blit=False)
        video = ani.to_html5_video()
        html = display.HTML(video)
        display.display(html)
        plt.close()

# %%
# slider = CylinderSlider([0,0,0], 0.2)
slider = BlockSlider([0,0,0], [0.2,0.2])

pusher_contact_angle = 3/2*np.pi + 30*np.pi/180
pusher_rel_vel = [0,0.1]
dt = 0.01
anim = SystemAnimationRelativePusher(slider, pusher_contact_angle, pusher_rel_vel, dt)
anim.anim()
# Out:
# step:  0
# slider translation velocity:  [-0.04330127  0.075     ]
# slider rotation velocity:  -0.43301270189221935
# step:  1
# slider translation velocity:  [-0.06454748  0.1121703 ]
# slider rotation velocity:  -0.6470823643718557
# step:  2
# slider translation velocity:  [-0.07435896  0.12959627]
# slider rotation velocity:  -0.7470735327044274
# step:  3
# slider translation velocity:  [-0.07831691  0.13675041]
# slider rotation velocity:  -0.7879535744985041
# step:  4
# slider translation velocity:  [-0.07937464  0.13869836]
# slider rotation velocity:  -0.79903654937354
# step:  5
# slider translation velocity:  [-0.07906767  0.1381221 ]
# slider rotation velocity:  -0.7957719631436937
# step:  6
# slider translation velocity:  [-0.07816983  0.1364038 ]
# slider rotation velocity:  -0.7860783254181696
# step:  7
# slider translation velocity:  [-0.07705552  0.13422976]
# slider rotation velocity:  -0.7738634024292207
# step:  8
# slider translation velocity:  [-0.07589678  0.13192528]
# slider rotation velocity:  -0.7609664144911829
# step:  9
# slider translation velocity:  [-0.07476716  0.12963545]
# slider rotation velocity:  -0.7481999246491458
# step:  10
# slider translation velocity:  [-0.07369435  0.12741915]
# slider rotation velocity:  -0.7358884116353789
# step:  11
# slider translation velocity:  [-0.07268582  0.12529592]
# slider rotation velocity:  -0.7241355283897501
# step:  12
# slider translation velocity:  [-0.07174073  0.12326851]
# slider rotation velocity:  -0.7129511433726593
# step:  13
# slider translation velocity:  [-0.07085523  0.12133303]
# slider rotation velocity:  -0.7023090186040313
# step:  14
# slider translation velocity:  [-0.07002471  0.11948347]
# slider rotation velocity:  -0.6921716604261926
# step:  15
# slider translation velocity:  [-0.06924459  0.11771349]
# slider rotation velocity:  -0.6825003229861293
# step:  16
# slider translation velocity:  [-0.06851069  0.1160171 ]
# slider rotation velocity:  -0.6732586150880946
# step:  17
# slider translation velocity:  [-0.06781924  0.11438881]
# slider rotation velocity:  -0.664413504079714
# step:  18
# slider translation velocity:  [-0.06716685  0.1128237 ]
# slider rotation velocity:  -0.6559353408789858
# step:  19
# slider translation velocity:  [-0.06655052  0.11131735]
# slider rotation velocity:  -0.647797565850461
# step:  20
# slider translation velocity:  [-0.06596756  0.1098658 ]
# slider rotation velocity:  -0.6399763464162049
# step:  21
# slider translation velocity:  [-0.06541555  0.10846545]
# slider rotation velocity:  -0.6324502325415089
# step:  22
# slider translation velocity:  [-0.0648923   0.10711307]
# slider rotation velocity:  -0.6251998536950942
# step:  23
# slider translation velocity:  [-0.06439585  0.10580572]
# slider rotation velocity:  -0.618207659052526
# step:  24
# slider translation velocity:  [-0.0639244   0.10454072]
# slider rotation velocity:  -0.6114576962021446
# step:  25
# slider translation velocity:  [-0.06347635  0.10331563]
# slider rotation velocity:  -0.604935422455985
# step:  26
# slider translation velocity:  [-0.06305019  0.10212821]
# slider rotation velocity:  -0.5986275433596011
# step:  27
# slider translation velocity:  [-0.06264459  0.1009764 ]
# slider rotation velocity:  -0.5925218738503641
# step:  28
# slider translation velocity:  [-0.06225829  0.09985832]
# slider rotation velocity:  -0.5866072183347726
# step:  29
# slider translation velocity:  [-0.06189016  0.09877223]
# slider rotation velocity:  -0.5808732666455947
# step:  30
# slider translation velocity:  [-0.06153915  0.0977165 ]
# slider rotation velocity:  -0.5753105033969151
# step:  31
# slider translation velocity:  [-0.06120428  0.09668965]
# slider rotation velocity:  -0.5699101287003733
# step:  32
# slider translation velocity:  [-0.06088467  0.09569028]
# slider rotation velocity:  -0.5646639885618508
# step:  33
# slider translation velocity:  [-0.06057949  0.09471712]
# slider rotation velocity:  -0.5595645135638545
# step:  34
# slider translation velocity:  [-0.06028796  0.09376895]
# slider rotation velocity:  -0.5546046646699517
# step:  35
# slider translation velocity:  [-0.06000938  0.09284467]
# slider rotation velocity:  -0.5497778851755312
# step:  36
# slider translation velocity:  [-0.05974307  0.09194322]
# slider rotation velocity:  -0.5450780579828378
# step:  37
# slider translation velocity:  [-0.05948843  0.09106362]
# slider rotation velocity:  -0.5404994675046065
# step:  38
# slider translation velocity:  [-0.05924486  0.09020495]
# slider rotation velocity:  -0.5360367656050851
# step:  39
# slider translation velocity:  [-0.05901185  0.08936636]
# slider rotation velocity:  -0.5316849410740138
# step:  40
# slider translation velocity:  [-0.05878886  0.08854703]
# slider rotation velocity:  -0.5274392922015447
# step:  41
# slider translation velocity:  [-0.05857545  0.0877462 ]
# slider rotation velocity:  -0.5232954020827804
# step:  42
# slider translation velocity:  [-0.05837115  0.08696315]
# slider rotation velocity:  -0.5192491163316938
# step:  43
# slider translation velocity:  [-0.05817557  0.08619721]
# slider rotation velocity:  -0.5152965229273576
# step:  44
# slider translation velocity:  [-0.05798829  0.08544774]
# slider rotation velocity:  -0.5114339339520101
# step:  45
# slider translation velocity:  [-0.05780896  0.08471413]
# slider rotation velocity:  -0.5076578690116433
# step:  46
# slider translation velocity:  [-0.05763723  0.0839958 ]
# slider rotation velocity:  -0.5039650401564029
# step:  47
# slider translation velocity:  [-0.05747276  0.08329223]
# slider rotation velocity:  -0.5003523381408811
# step:  48
# slider translation velocity:  [-0.05731526  0.08260289]
# slider rotation velocity:  -0.4968168198839781
# step:  49
# slider translation velocity:  [-0.05716442  0.0819273 ]
# slider rotation velocity:  -0.4933556970048816
# step:  50
# slider translation velocity:  [-0.05701998  0.08126499]
# slider rotation velocity:  -0.4899663253263218
# step:  51
# slider translation velocity:  [-0.05688167  0.08061553]
# slider rotation velocity:  -0.4866461952488949
# step:  52
# slider translation velocity:  [-0.05674925  0.0799785 ]
# slider rotation velocity:  -0.4833929229112523
# step:  53
# slider translation velocity:  [-0.05662247  0.07935349]
# slider rotation velocity:  -0.4802042420605225
# step:  54
# slider translation velocity:  [-0.05650112  0.07874013]
# slider rotation velocity:  -0.4770779965656968
# step:  55
# slider translation velocity:  [-0.05638498  0.07813805]
# slider rotation velocity:  -0.474012133514036
# step:  56
# slider translation velocity:  [-0.05627386  0.07754692]
# slider rotation velocity:  -0.4710046968369678
# step:  57
# slider translation velocity:  [-0.05616756  0.0769664 ]
# slider rotation velocity:  -0.4680538214176036
# step:  58
# slider translation velocity:  [-0.0560659   0.07639617]
# slider rotation velocity:  -0.4651577276369682
# step:  59
# slider translation velocity:  [-0.05596871  0.07583593]
# slider rotation velocity:  -0.46231471632043425
# step:  60
# slider translation velocity:  [-0.05587583  0.07528541]
# slider rotation velocity:  -0.45952316404973503
# step:  61
# slider translation velocity:  [-0.05578709  0.0747443 ]
# slider rotation velocity:  -0.4567815188093769
# step:  62
# slider translation velocity:  [-0.05570234  0.07421237]
# slider rotation velocity:  -0.45408829593932315
# step:  63
# slider translation velocity:  [-0.05562145  0.07368934]
# slider rotation velocity:  -0.4514420743685467
# step:  64
# slider translation velocity:  [-0.05554428  0.07317498]
# slider rotation velocity:  -0.4488414931064678
# step:  65
# slider translation velocity:  [-0.05547069  0.07266906]
# slider rotation velocity:  -0.44628524797145613
# step:  66
# slider translation velocity:  [-0.05540056  0.07217134]
# slider rotation velocity:  -0.4437720885375088
# step:  67
# slider translation velocity:  [-0.05533377  0.07168162]
# slider rotation velocity:  -0.44130081528194787
# step:  68
# slider translation velocity:  [-0.05527021  0.07119969]
# slider rotation velocity:  -0.4388702769185296
# step:  69
# slider translation velocity:  [-0.05520977  0.07072534]
# slider rotation velocity:  -0.43647936790175396
# step:  70
# slider translation velocity:  [-0.05515234  0.07025839]
# slider rotation velocity:  -0.4341270260894133
# step:  71
# slider translation velocity:  [-0.05509782  0.06979865]
# slider rotation velocity:  -0.4318122305515485
# step:  72
# slider translation velocity:  [-0.05504612  0.06934595]
# slider rotation velocity:  -0.42953399951499993
# step:  73
# slider translation velocity:  [-0.05499714  0.06890011]
# slider rotation velocity:  -0.4272913884336559
# step:  74
# slider translation velocity:  [-0.0549508   0.06846097]
# slider rotation velocity:  -0.4250834881753349
# step:  75
# slider translation velocity:  [-0.054907    0.06802837]
# slider rotation velocity:  -0.422909423316989
# step:  76
# slider translation velocity:  [-0.05486567  0.06760215]
# slider rotation velocity:  -0.4207683505405967
# step:  77
# slider translation velocity:  [-0.05482673  0.06718217]
# slider rotation velocity:  -0.4186594571227337
# step:  78
# slider translation velocity:  [-0.0547901   0.06676829]
# slider rotation velocity:  -0.4165819595113696
# step:  79
# slider translation velocity:  [-0.05475571  0.06636037]
# slider rotation velocity:  -0.41453510198395244
# step:  80
# slider translation velocity:  [-0.05472349  0.06595827]
# slider rotation velocity:  -0.41251815538130654
# step:  81
# slider translation velocity:  [-0.05469337  0.06556186]
# slider rotation velocity:  -0.4105304159122935
# step:  82
# slider translation velocity:  [-0.05466529  0.06517103]
# slider rotation velocity:  -0.4085712040245743
# step:  83
# slider translation velocity:  [-0.05463918  0.06478564]
# slider rotation velocity:  -0.40663986333716334
# step:  84
# slider translation velocity:  [-0.05461498  0.06440559]
# slider rotation velocity:  -0.4047357596307894
# step:  85
# slider translation velocity:  [-0.05459264  0.06403076]
# slider rotation velocity:  -0.40285827989237216
# step:  86
# slider translation velocity:  [-0.0545721   0.06366104]
# slider rotation velocity:  -0.4010068314101986
# step:  87
# slider translation velocity:  [-0.0545533   0.06329633]
# slider rotation velocity:  -0.39918084091662664
# step:  88
# slider translation velocity:  [-0.0545362   0.06293652]
# slider rotation velocity:  -0.397379753775377
# step:  89
# slider translation velocity:  [-0.05452074  0.06258151]
# slider rotation velocity:  -0.39560303321067936
# step:  90
# slider translation velocity:  [-0.05450687  0.06223121]
# slider rotation velocity:  -0.3938501595757358
# step:  91
# slider translation velocity:  [-0.05449454  0.06188552]
# slider rotation velocity:  -0.39212062965813815
# step:  92
# slider translation velocity:  [-0.05448372  0.06154436]
# slider rotation velocity:  -0.3904139560200422
# step:  93
# slider translation velocity:  [-0.05447436  0.06120763]
# slider rotation velocity:  -0.38872966637105144
# step:  94
# slider translation velocity:  [-0.0544664   0.06087525]
# slider rotation velocity:  -0.3870673029719014
# step:  95
# slider translation velocity:  [-0.05445982  0.06054714]
# slider rotation velocity:  -0.38542642206716493
# step:  96
# slider translation velocity:  [-0.05445458  0.06022322]
# slider rotation velocity:  -0.3838065933453169
# step:  97
# slider translation velocity:  [-0.05445063  0.0599034 ]
# slider rotation velocity:  -0.3822073994246071
# step:  98
# slider translation velocity:  [-0.05444793  0.05958762]
# slider rotation velocity:  -0.3806284353632895
# step:  99
# slider translation velocity:  [-0.05444646  0.0592758 ]
# slider rotation velocity:  -0.37906930819285456
# step:  100
# slider translation velocity:  [-0.05444617  0.05896787]
# slider rotation velocity:  -0.37752963647299265
# step:  101
# slider translation velocity:  [-0.05444703  0.05866375]
# slider rotation velocity:  -0.3760090498671022
# step:  102
# slider translation velocity:  [-0.05444901  0.05836339]
# slider rotation velocity:  -0.37450718873722905
# step:  103
# slider translation velocity:  [-0.05445208  0.0580667 ]
# slider rotation velocity:  -0.3730237037573929
# step:  104
# slider translation velocity:  [-0.05445621  0.05777364]
# slider rotation velocity:  -0.3715582555443231
# step:  105
# slider translation velocity:  [-0.05446136  0.05748414]
# slider rotation velocity:  -0.37011051430468367
# step:  106
# slider translation velocity:  [-0.0544675   0.05719814]
# slider rotation velocity:  -0.3686801594979273
# step:  107
# slider translation velocity:  [-0.05447462  0.05691557]
# slider rotation velocity:  -0.3672668795139662
# step:  108
# slider translation velocity:  [-0.05448268  0.05663638]
# slider rotation velocity:  -0.36587037136489803
# step:  109
# slider translation velocity:  [-0.05449165  0.05636052]
# slider rotation velocity:  -0.3644903403900723
# step:  110
# slider translation velocity:  [-0.05450151  0.05608793]
# slider rotation velocity:  -0.3631264999738212
# step:  111
# slider translation velocity:  [-0.05451223  0.05581856]
# slider rotation velocity:  -0.3617785712752215
# step:  112
# slider translation velocity:  [-0.05452379  0.05555235]
# slider rotation velocity:  -0.3604462829692896
# step:  113
# slider translation velocity:  [-0.05453617  0.05528926]
# slider rotation velocity:  -0.3591293709990451
# step:  114
# slider translation velocity:  [-0.05454933  0.05502924]
# slider rotation velocity:  -0.35782757833791523
# step:  115
# slider translation velocity:  [-0.05456327  0.05477223]
# slider rotation velocity:  -0.3565406547619743
# step:  116
# slider translation velocity:  [-0.05457795  0.0545182 ]
# slider rotation velocity:  -0.3552683566315503
# step:  117
# slider translation velocity:  [-0.05459337  0.05426709]
# slider rotation velocity:  -0.3540104466817498
# step:  118
# slider translation velocity:  [-0.05460948  0.05401886]
# slider rotation velocity:  -0.3527666938214795
# step:  119
# slider translation velocity:  [-0.05462628  0.05377347]
# slider rotation velocity:  -0.35153687294056796
# step:  120
# slider translation velocity:  [-0.05464375  0.05353087]
# slider rotation velocity:  -0.35032076472460916
# step:  121
# slider translation velocity:  [-0.05466186  0.05329104]
# slider rotation velocity:  -0.34911815547717323
# step:  122
# slider translation velocity:  [-0.05468061  0.05305391]
# slider rotation velocity:  -0.34792883694904714
# step:  123
# slider translation velocity:  [-0.05469996  0.05281946]
# slider rotation velocity:  -0.34675260617418574
# step:  124
# slider translation velocity:  [-0.0547199   0.05258765]
# slider rotation velocity:  -0.34558926531207357
# step:  125
# slider translation velocity:  [-0.05474042  0.05235844]
# slider rotation velocity:  -0.3444386214962087
# step:  126
# slider translation velocity:  [-0.05476149  0.05213179]
# slider rotation velocity:  -0.3433004866884401
# step:  127
# slider translation velocity:  [-0.05478311  0.05190767]
# slider rotation velocity:  -0.342174677538901
# step:  128
# slider translation velocity:  [-0.05480525  0.05168604]
# slider rotation velocity:  -0.34106101525129495
# step:  129
# slider translation velocity:  [-0.0548279   0.05146687]
# slider rotation velocity:  -0.33995932545330293
# step:  130
# slider translation velocity:  [-0.05485105  0.05125012]
# slider rotation velocity:  -0.3388694380718945
# step:  131
# slider translation velocity:  [-0.05487467  0.05103577]
# slider rotation velocity:  -0.33779118721333284
# step:  132
# slider translation velocity:  [-0.05489876  0.05082378]
# slider rotation velocity:  -0.33672441104767764
# step:  133
# slider translation velocity:  [-0.0549233   0.05061412]
# slider rotation velocity:  -0.33566895169759886
# step:  134
# slider translation velocity:  [-0.05494828  0.05040676]
# slider rotation velocity:  -0.33462465513132156
# step:  135
# slider translation velocity:  [-0.05497368  0.05020167]
# slider rotation velocity:  -0.3335913710595347
# step:  136
# slider translation velocity:  [-0.05499949  0.04999882]
# slider rotation velocity:  -0.33256895283610177
# step:  137
# slider translation velocity:  [-0.05502569  0.04979819]
# slider rotation velocity:  -0.3315572573624205
# step:  138
# slider translation velocity:  [-0.05505228  0.04959974]
# slider rotation velocity:  -0.3305561449952876
# step:  139
# slider translation velocity:  [-0.05507925  0.04940345]
# slider rotation velocity:  -0.3295654794581286
# step:  140
# slider translation velocity:  [-0.05510657  0.04920929]
# slider rotation velocity:  -0.3285851277554619
# step:  141
# slider translation velocity:  [-0.05513424  0.04901724]
# slider rotation velocity:  -0.3276149600904724
# step:  142
# slider translation velocity:  [-0.05516224  0.04882727]
# slider rotation velocity:  -0.32665484978557563
# step:  143
# slider translation velocity:  [-0.05519057  0.04863936]
# slider rotation velocity:  -0.3257046732058574
# step:  144
# slider translation velocity:  [-0.05521921  0.04845348]
# slider rotation velocity:  -0.32476430968528325
# step:  145
# slider translation velocity:  [-0.05524815  0.04826961]
# slider rotation velocity:  -0.32383364145557386
# step:  146
# slider translation velocity:  [-0.05527739  0.04808773]
# slider rotation velocity:  -0.3229125535776481
# step:  147
# slider translation velocity:  [-0.0553069   0.04790781]
# slider rotation velocity:  -0.3220009338755417
# step:  148
# slider translation velocity:  [-0.05533669  0.04772983]
# slider rotation velocity:  -0.32109867287271165
# step:  149
# slider translation velocity:  [-0.05536673  0.04755377]
# slider rotation velocity:  -0.32020566373064285
# step:  150
# slider translation velocity:  [-0.05539703  0.04737962]
# slider rotation velocity:  -0.3193218021896752
# step:  151
# slider translation velocity:  [-0.05542757  0.04720734]
# slider rotation velocity:  -0.31844698651197556
# step:  152
# slider translation velocity:  [-0.05545833  0.04703692]
# slider rotation velocity:  -0.31758111742658135
# step:  153
# slider translation velocity:  [-0.05548932  0.04686834]
# slider rotation velocity:  -0.3167240980764454
# step:  154
# slider translation velocity:  [-0.05552052  0.04670158]
# slider rotation velocity:  -0.3158758339674166
# step:  155
# slider translation velocity:  [-0.05555192  0.04653662]
# slider rotation velocity:  -0.31503623291909255
# step:  156
# slider translation velocity:  [-0.05558352  0.04637345]
# slider rotation velocity:  -0.3142052050174852
# step:  157
# slider translation velocity:  [-0.0556153   0.04621204]
# slider rotation velocity:  -0.31338266256944136
# step:  158
# slider translation velocity:  [-0.05564725  0.04605238]
# slider rotation velocity:  -0.31256852005876284
# step:  159
# slider translation velocity:  [-0.05567938  0.04589444]
# slider rotation velocity:  -0.3117626941039773
# step:  160
# slider translation velocity:  [-0.05571166  0.04573823]
# slider rotation velocity:  -0.31096510341770706
# step:  161
# slider translation velocity:  [-0.05574409  0.04558371]
# slider rotation velocity:  -0.31017566876759156
# step:  162
# slider translation velocity:  [-0.05577667  0.04543087]
# slider rotation velocity:  -0.3093943129387179
# step:  163
# slider translation velocity:  [-0.05580938  0.0452797 ]
# slider rotation velocity:  -0.3086209606975171
# step:  164
# slider translation velocity:  [-0.05584221  0.04513018]
# slider rotation velocity:  -0.30785553875708704
# step:  165
# slider translation velocity:  [-0.05587516  0.04498229]
# slider rotation velocity:  -0.307097975743902
# step:  166
# slider translation velocity:  [-0.05590823  0.04483603]
# slider rotation velocity:  -0.306348202165876
# step:  167
# slider translation velocity:  [-0.0559414   0.04469137]
# slider rotation velocity:  -0.30560615038174166
# step:  168
# slider translation velocity:  [-0.05597466  0.04454831]
# slider rotation velocity:  -0.30487175457171656
# step:  169
# slider translation velocity:  [-0.05600801  0.04440682]
# slider rotation velocity:  -0.30414495070942316
# step:  170
# slider translation velocity:  [-0.05604144  0.04426691]
# slider rotation velocity:  -0.3034256765350363
# step:  171
# slider translation velocity:  [-0.05607494  0.04412854]
# slider rotation velocity:  -0.3027138715296296
# step:  172
# slider translation velocity:  [-0.05610851  0.04399172]
# slider rotation velocity:  -0.302009476890695
# step:  173
# slider translation velocity:  [-0.05614214  0.04385643]
# slider rotation velocity:  -0.301312435508814
# step:  174
# slider translation velocity:  [-0.05617582  0.04372266]
# slider rotation velocity:  -0.3006226919454556
# step:  175
# slider translation velocity:  [-0.05620954  0.04359039]
# slider rotation velocity:  -0.2999401924118821
# step:  176
# slider translation velocity:  [-0.0562433   0.04345961]
# slider rotation velocity:  -0.2992648847491423
# step:  177
# slider translation velocity:  [-0.05627709  0.04333032]
# slider rotation velocity:  -0.2985967184091352
# step:  178
# slider translation velocity:  [-0.0563109  0.0432025]
# slider rotation velocity:  -0.29793564443672726
# step:  179
# slider translation velocity:  [-0.05634473  0.04307615]
# slider rotation velocity:  -0.29728161545290777
# step:  180
# slider translation velocity:  [-0.05637856  0.04295124]
# slider rotation velocity:  -0.29663458563896977
# step:  181
# slider translation velocity:  [-0.05641241  0.04282778]
# slider rotation velocity:  -0.2959945107217036
# step:  182
# slider translation velocity:  [-0.05644624  0.04270576]
# slider rotation velocity:  -0.29536134795959107
# step:  183
# slider translation velocity:  [-0.05648007  0.04258515]
# slider rotation velocity:  -0.29473505612999246
# step:  184
# slider translation velocity:  [-0.05651388  0.04246596]
# slider rotation velocity:  -0.2941155955173169
# step:  185
# slider translation velocity:  [-0.05654766  0.04234818]
# slider rotation velocity:  -0.29350292790216825
# step:  186
# slider translation velocity:  [-0.05658141  0.04223179]
# slider rotation velocity:  -0.29289701655146216
# step:  187
# slider translation velocity:  [-0.05661513  0.04211679]
# slider rotation velocity:  -0.29229782620950884
# step:  188
# slider translation velocity:  [-0.0566488   0.04200318]
# slider rotation velocity:  -0.29170532309005825
# step:  189
# slider translation velocity:  [-0.05668242  0.04189093]
# slider rotation velocity:  -0.29111947486930606
# step:  190
# slider translation velocity:  [-0.05671599  0.04178006]
# slider rotation velocity:  -0.29054025067985945
# step:  191
# slider translation velocity:  [-0.05674949  0.04167054]
# slider rotation velocity:  -0.2899676211056632
# step:  192
# slider translation velocity:  [-0.05678292  0.04156238]
# slider rotation velocity:  -0.2894015581778886
# step:  193
# slider translation velocity:  [-0.05681627  0.04145556]
# slider rotation velocity:  -0.28884203537178665
# step:  194
# slider translation velocity:  [-0.05684954  0.04135008]
# slider rotation velocity:  -0.28828902760451325
# step:  195
# slider translation velocity:  [-0.05688272  0.04124593]
# slider rotation velocity:  -0.28774251123392824
# step:  196
# slider translation velocity:  [-0.0569158   0.04114311]
# slider rotation velocity:  -0.2872024640583795
# step:  197
# slider translation velocity:  [-0.05694878  0.04104162]
# slider rotation velocity:  -0.28666886531747765
# step:  198
# slider translation velocity:  [-0.05698165  0.04094144]
# slider rotation velocity:  -0.2861416956938736
# step:  199
# slider translation velocity:  [-0.0570144   0.04084257]
# slider rotation velocity:  -0.2856209373160495
# step:  200
# slider translation velocity:  [-0.05704703  0.04074501]
# slider rotation velocity:  -0.2851065737621364
# step:  201
# slider translation velocity:  [-0.05707953  0.04064875]
# slider rotation velocity:  -0.2845985900647739
# step:  202
# slider translation velocity:  [-0.05711189  0.04055379]
# slider rotation velocity:  -0.2840969727170268
# step:  203
# slider translation velocity:  [-0.05714411  0.04046012]
# slider rotation velocity:  -0.28360170967937837
# step:  204
# slider translation velocity:  [-0.05717618  0.04036775]
# slider rotation velocity:  -0.2831127903878184
# step:  205
# slider translation velocity:  [-0.05720809  0.04027666]
# slider rotation velocity:  -0.282630205763048
# step:  206
# slider translation velocity:  [-0.05723983  0.04018685]
# slider rotation velocity:  -0.2821539482208254
# step:  207
# slider translation velocity:  [-0.05727141  0.04009833]
# slider rotation velocity:  -0.28168401168347573
# step:  208
# slider translation velocity:  [-0.0573028   0.04001108]
# slider rotation velocity:  -0.2812203915925942
# step:  209
# slider translation velocity:  [-0.05733401  0.03992511]
# slider rotation velocity:  -0.28076308492297036
# step:  210
# slider translation velocity:  [-0.05736503  0.03984041]
# slider rotation velocity:  -0.28031209019776576
# step:  211
# slider translation velocity:  [-0.05739585  0.03975698]
# slider rotation velocity:  -0.27986740750497785
# step:  212
# slider translation velocity:  [-0.05742645  0.03967483]
# slider rotation velocity:  -0.2794290385152265
# step:  213
# slider translation velocity:  [-0.05745685  0.03959394]
# slider rotation velocity:  -0.27899698650090166
# step:  214
# slider translation velocity:  [-0.05748702  0.03951432]
# slider rotation velocity:  -0.2785712563567133
# step:  215
# slider translation velocity:  [-0.05751696  0.03943596]
# slider rotation velocity:  -0.27815185462168635
# step:  216
# slider translation velocity:  [-0.05754667  0.03935888]
# slider rotation velocity:  -0.27773878950264796
# step:  217
# slider translation velocity:  [-0.05757613  0.03928305]
# slider rotation velocity:  -0.2773320708992575
# step:  218
# slider translation velocity:  [-0.05760533  0.0392085 ]
# slider rotation velocity:  -0.27693171043062936
# step:  219
# slider translation velocity:  [-0.05763427  0.03913521]
# slider rotation velocity:  -0.2765377214636074
# step:  220
# slider translation velocity:  [-0.05766295  0.03906319]
# slider rotation velocity:  -0.2761501191427485
# step:  221
# slider translation velocity:  [-0.05769134  0.03899243]
# slider rotation velocity:  -0.2757689204220789
# step:  222
# slider translation velocity:  [-0.05771945  0.03892295]
# slider rotation velocity:  -0.27539414409869073
# step:  223
# slider translation velocity:  [-0.05774726  0.03885473]
# slider rotation velocity:  -0.2750258108482488
# step:  224
# slider translation velocity:  [-0.05777477  0.03878779]
# slider rotation velocity:  -0.27466394326248444
# step:  225
# slider translation velocity:  [-0.05780197  0.03872212]
# slider rotation velocity:  -0.2743085658887546
# step:  226
# slider translation velocity:  [-0.05782884  0.03865773]
# slider rotation velocity:  -0.2739597052717522
# step:  227
# slider translation velocity:  [-0.05785539  0.03859463]
# slider rotation velocity:  -0.27361738999745794
# step:  228
# slider translation velocity:  [-0.05788159  0.0385328 ]
# slider rotation velocity:  -0.2732816507394272
# step:  229
# slider translation velocity:  [-0.05790744  0.03847226]
# slider rotation velocity:  -0.27295252030751466
# step:  230
# slider translation velocity:  [-0.05793293  0.03841302]
# slider rotation velocity:  -0.27263003369914396
# step:  231
# slider translation velocity:  [-0.05795805  0.03835507]
# slider rotation velocity:  -0.27231422815323447
# step:  232
# slider translation velocity:  [-0.0579828   0.03829842]
# slider rotation velocity:  -0.2720051432069082
# step:  233
# slider translation velocity:  [-0.05800715  0.03824307]
# slider rotation velocity:  -0.271702820755102
# step:  234
# slider translation velocity:  [-0.0580311   0.03818904]
# slider rotation velocity:  -0.27140730511322364
# step:  235
# slider translation velocity:  [-0.05805463  0.03813632]
# slider rotation velocity:  -0.27111864308299366
# step:  236
# slider translation velocity:  [-0.05807775  0.03808493]
# slider rotation velocity:  -0.270836884021627
# step:  237
# slider translation velocity:  [-0.05810043  0.03803487]
# slider rotation velocity:  -0.2705620799145171
# step:  238
# slider translation velocity:  [-0.05812266  0.03798614]
# slider rotation velocity:  -0.27029428545159345
# step:  239
# slider translation velocity:  [-0.05814443  0.03793876]
# slider rotation velocity:  -0.27003355810753754
# step:  240
# slider translation velocity:  [-0.05816574  0.03789273]
# slider rotation velocity:  -0.2697799582260509
# step:  241
# slider translation velocity:  [-0.05818656  0.03784806]
# slider rotation velocity:  -0.269533549108382
# step:  242
# slider translation velocity:  [-0.05820688  0.03780476]
# slider rotation velocity:  -0.26929439710633285
# step:  243
# slider translation velocity:  [-0.05822669  0.03776285]
# slider rotation velocity:  -0.2690625717199786
# step:  244
# slider translation velocity:  [-0.05824598  0.03772232]
# slider rotation velocity:  -0.2688381457003498
# step:  245
# slider translation velocity:  [-0.05826474  0.03768319]
# slider rotation velocity:  -0.2686211951573412
# step:  246
# slider translation velocity:  [-0.05828294  0.03764547]
# slider rotation velocity:  -0.2684117996731314
# step:  247
# slider translation velocity:  [-0.05830057  0.03760918]
# slider rotation velocity:  -0.26821004242141244
# step:  248
# slider translation velocity:  [-0.05831763  0.03757432]
# slider rotation velocity:  -0.26801601029274996
# step:  249
# slider translation velocity:  [-0.05833408  0.03754091]
# slider rotation velocity:  -0.2678297940264171
# step:  250
# slider translation velocity:  [-0.05834992  0.03750896]
# slider rotation velocity:  -0.2676514883490648
# step:  251
# slider translation velocity:  [-0.05836514  0.03747849]
# slider rotation velocity:  -0.26748119212061916
# step:  252
# slider translation velocity:  [-0.0583797  0.0374495]
# slider rotation velocity:  -0.26731900848782025
# step:  253
# slider translation velocity:  [-0.0583936   0.03742203]
# slider rotation velocity:  -0.267165045045847
# step:  254
# slider translation velocity:  [-0.05840682  0.03739607]
# slider rotation velocity:  -0.267019414008502
# step:  255
# slider translation velocity:  [-0.05841934  0.03737166]
# slider rotation velocity:  -0.266882232387463
# step:  256
# slider translation velocity:  [-0.05843113  0.0373488 ]
# slider rotation velocity:  -0.26675362218114557
# step:  257
# slider translation velocity:  [-0.05844219  0.03732752]
# slider rotation velocity:  -0.26663371057375473
# step:  258
# slider translation velocity:  [-0.05845248  0.03730783]
# slider rotation velocity:  -0.26652263014515143
# step:  259
# slider translation velocity:  [-0.05846199  0.03728976]
# slider rotation velocity:  -0.26642051909219777
# step:  260
# slider translation velocity:  [-0.05847069  0.03727332]
# slider rotation velocity:  -0.26632752146229727
# step:  261
# slider translation velocity:  [-0.05847857  0.03725854]
# slider rotation velocity:  -0.26624378739989685
# step:  262
# slider translation velocity:  [-0.05848559  0.03724544]
# slider rotation velocity:  -0.26616947340677455
# step:  263
# slider translation velocity:  [-0.05849174  0.03723405]
# slider rotation velocity:  -0.2661047426169972
# step:  264
# slider translation velocity:  [-0.05849699  0.03722439]
# slider rotation velocity:  -0.2660497650874981
# step:  265
# slider translation velocity:  [-0.05850132  0.03721648]
# slider rotation velocity:  -0.2660047181052994
# step:  266
# slider translation velocity:  [-0.05850468  0.03721036]
# slider rotation velocity:  -0.26596978651247805
# step:  267
# slider translation velocity:  [-0.05850707  0.03720605]
# slider rotation velocity:  -0.2659451630500607
# step:  268
# slider translation velocity:  [-0.05850844  0.03720359]
# slider rotation velocity:  -0.26593104872212675
# step:  269
# slider translation velocity:  [-0.05850878  0.037203  ]
# slider rotation velocity:  -0.2659276531814943
# step:  270
# slider translation velocity:  [-0.05850803  0.03720431]
# slider rotation velocity:  -0.26593519513847846
# step:  271
# slider translation velocity:  [-0.05850619  0.03720756]
# slider rotation velocity:  -0.2659539027943253
# step:  272
# slider translation velocity:  [-0.0585032   0.03721279]
# slider rotation velocity:  -0.2659840143010575
# step:  273
# slider translation velocity:  [-0.05849904  0.03722004]
# slider rotation velocity:  -0.2660257782496089
# step:  274
# slider translation velocity:  [-0.05849366  0.03722933]
# slider rotation velocity:  -0.2660794541882766
# step:  275
# slider translation velocity:  [-0.05848704  0.03724071]
# slider rotation velocity:  -0.26614531317369383
# step:  276
# slider translation velocity:  [-0.05847913  0.03725423]
# slider rotation velocity:  -0.26622363835670526
# step:  277
# slider translation velocity:  [-0.05846988  0.03726993]
# slider rotation velocity:  -0.266314725605734
# step:  278
# slider translation velocity:  [-0.05845926  0.03728785]
# slider rotation velocity:  -0.26641888417044884
# step:  279
# slider translation velocity:  [-0.05844722  0.03730805]
# slider rotation velocity:  -0.26653643738878474
# step:  280
# slider translation velocity:  [-0.05843372  0.03733056]
# slider rotation velocity:  -0.2666677234406356
# step:  281
# slider translation velocity:  [-0.0584187   0.03735546]
# slider rotation velocity:  -0.26681309615183524
# step:  282
# slider translation velocity:  [-0.05840211  0.03738278]
# slider rotation velocity:  -0.26697292585236254
# step:  283
# slider translation velocity:  [-0.0583839  0.0374126]
# slider rotation velocity:  -0.26714760029306595
# step:  284
# slider translation velocity:  [-0.05836402  0.03744496]
# slider rotation velocity:  -0.2673375256255939
# step:  285
# slider translation velocity:  [-0.0583424   0.03747994]
# slider rotation velocity:  -0.2675431274506509
# step:  286
# slider translation velocity:  [-0.05831898  0.0375176 ]
# slider rotation velocity:  -0.2677648519401809
# step:  287
# slider translation velocity:  [-0.0582937   0.03755801]
# slider rotation velocity:  -0.2680031670396053
# step:  288
# slider translation velocity:  [-0.0582665   0.03760124]
# slider rotation velocity:  -0.2682585637568344
# step:  289
# slider translation velocity:  [-0.0582373   0.03764737]
# slider rotation velocity:  -0.26853155754541735
# step:  290
# slider translation velocity:  [-0.05820602  0.03769649]
# slider rotation velocity:  -0.2688226897899222
# step:  291
# slider translation velocity:  [-0.0581726   0.03774867]
# slider rotation velocity:  -0.2691325294024341
# step:  292
# slider translation velocity:  [-0.05813695  0.03780401]
# slider rotation velocity:  -0.2694616745399589
# step:  293
# slider translation velocity:  [-0.05809897  0.03786259]
# slider rotation velocity:  -0.2698107544535073
# step:  294
# slider translation velocity:  [-0.05805859  0.03792453]
# slider rotation velocity:  -0.27018043148074633
# step:  295
# slider translation velocity:  [-0.05801571  0.03798991]
# slider rotation velocity:  -0.2705714031953429
# step:  296
# slider translation velocity:  [-0.05797022  0.03805886]
# slider rotation velocity:  -0.2709844047275053
# step:  297
# slider translation velocity:  [-0.05792202  0.03813148]
# slider rotation velocity:  -0.27142021127178
# step:  298
# slider translation velocity:  [-0.05787101  0.03820791]
# slider rotation velocity:  -0.27187964079989774
# step:  299
# slider translation velocity:  [-0.05781706  0.03828826]
# slider rotation velocity:  -0.27236355699840964
# step:  300
# slider translation velocity:  [-0.05776004  0.03837267]
# slider rotation velocity:  -0.27287287245305
# step:  301
# slider translation velocity:  [-0.05769983  0.03846128]
# slider rotation velocity:  -0.2734085521042257
# step:  302
# slider translation velocity:  [-0.05763629  0.03855426]
# slider rotation velocity:  -0.2739716170008169
# step:  303
# slider translation velocity:  [-0.05756927  0.03865175]
# slider rotation velocity:  -0.27456314838261403
# step:  304
# slider translation velocity:  [-0.05749861  0.03875393]
# slider rotation velocity:  -0.27518429212526896
# step:  305
# slider translation velocity:  [-0.05742415  0.03886097]
# slider rotation velocity:  -0.2758362635856635
# step:  306
# slider translation velocity:  [-0.05734572  0.03897308]
# slider rotation velocity:  -0.27652035289016397
# step:  307
# slider translation velocity:  [-0.05726312  0.03909044]
# slider rotation velocity:  -0.27723793071342157
# step:  308
# slider translation velocity:  [-0.05717615  0.03921327]
# slider rotation velocity:  -0.277990454601286
# step:  309
# slider translation velocity:  [-0.05708461  0.03934182]
# slider rotation velocity:  -0.27877947589814017
# step:  310
# slider translation velocity:  [-0.05698827  0.0394763 ]
# slider rotation velocity:  -0.2796066473466603
# step:  311
# slider translation velocity:  [-0.05688689  0.039617  ]
# slider rotation velocity:  -0.28047373143682375
# step:  312
# slider translation velocity:  [-0.05678021  0.03976417]
# slider rotation velocity:  -0.2813826095910896
# step:  313
# slider translation velocity:  [-0.05666795  0.03991813]
# slider rotation velocity:  -0.2823352922842952
# step:  314
# slider translation velocity:  [-0.05654982  0.04007918]
# slider rotation velocity:  -0.283333930210183
# step:  315
# slider translation velocity:  [-0.0564255   0.04024766]
# slider rotation velocity:  -0.2843808266219011
# step:  316
# slider translation velocity:  [-0.05629466  0.04042393]
# slider rotation velocity:  -0.2854784509916621
# step:  317
# slider translation velocity:  [-0.05615693  0.04060838]
# slider rotation velocity:  -0.2866294541554128
# step:  318
# slider translation velocity:  [-0.05601192  0.04080143]
# slider rotation velocity:  -0.287836685132376
# step:  319
# slider translation velocity:  [-0.0558592   0.04100352]
# slider rotation velocity:  -0.2891032098372657
# step:  320
# slider translation velocity:  [-0.05569832  0.04121514]
# slider rotation velocity:  -0.29043233193558043
# step:  321
# slider translation velocity:  [-0.05552879  0.04143679]
# slider rotation velocity:  -0.2918276161305102
# step:  322
# slider translation velocity:  [-0.05535008  0.04166905]
# slider rotation velocity:  -0.29329291421470316
# step:  323
# slider translation velocity:  [-0.0551616   0.04191252]
# slider rotation velocity:  -0.29483239427270147
# step:  324
# slider translation velocity:  [-0.05496273  0.04216784]
# slider rotation velocity:  -0.29645057348180937
# step:  325
# slider translation velocity:  [-0.05475279  0.04243574]
# slider rotation velocity:  -0.29815235503238807
# step:  326
# slider translation velocity:  [-0.05453104  0.04271698]
# slider rotation velocity:  -0.29994306977537655
# step:  327
# slider translation velocity:  [-0.05429668  0.04301239]
# slider rotation velocity:  -0.3018285233080285
# step:  328
# slider translation velocity:  [-0.05404881  0.0433229 ]
# slider rotation velocity:  -0.3038150493319119
# step:  329
# slider translation velocity:  [-0.05378647  0.04364948]
# slider rotation velocity:  -0.30590957026440563
# step:  330
# slider translation velocity:  [-0.05350861  0.04399325]
# slider rotation velocity:  -0.3081196662615719
# step:  331
# slider translation velocity:  [-0.05321405  0.04435537]
# slider rotation velocity:  -0.3104536540229704
# step:  332
# slider translation velocity:  [-0.05290151  0.04473717]
# slider rotation velocity:  -0.31292067700597487
# step:  333
# slider translation velocity:  [-0.05256958  0.04514008]
# slider rotation velocity:  -0.3155308089887869
# step:  334
# slider translation velocity:  [-0.0522167   0.04556568]
# slider rotation velocity:  -0.3182951733006637
# step:  335
# slider translation velocity:  [-0.05184112  0.04601574]
# slider rotation velocity:  -0.32122608050136087
# step:  336
# slider translation velocity:  [-0.05144091  0.04649218]
# slider rotation velocity:  -0.3243371878604116
# step:  337
# slider translation velocity:  [-0.05101393  0.04699716]
# slider rotation velocity:  -0.3276436846873793
# step:  338
# slider translation velocity:  [-0.05055778  0.04753307]
# slider rotation velocity:  -0.3311625084309877
# step:  339
# slider translation velocity:  [-0.05006975  0.0481026 ]
# slider rotation velocity:  -0.3349125975423775
# step:  340
# slider translation velocity:  [-0.04954683  0.04870872]
# slider rotation velocity:  -0.33891518844314117
# step:  341
# slider translation velocity:  [-0.04898562  0.0493548 ]
# slider rotation velocity:  -0.34319416562723304
# step:  342
# slider translation velocity:  [-0.04838224  0.05004462]
# slider rotation velocity:  -0.34777647605570816
# step:  343
# slider translation velocity:  [-0.04773234  0.05078243]
# slider rotation velocity:  -0.3526926217043551
# step:  344
# slider translation velocity:  [-0.04703093  0.05157307]
# slider rotation velocity:  -0.35797724756915916
# step:  345
# slider translation velocity:  [-0.04627234  0.05242205]
# slider rotation velocity:  -0.36366984685383175
# step:  346
# slider translation velocity:  [-0.04545002  0.05333562]
# slider rotation velocity:  -0.3698156107680479
# step:  347
# slider translation velocity:  [-0.04455647  0.05432097]
# slider rotation velocity:  -0.37646645777601234
# step:  348
# slider translation velocity:  [-0.043583    0.05538638]
# slider rotation velocity:  -0.38368228682875105
# step:  349
# slider translation velocity:  [-0.04251951  0.05654138]
# slider rotation velocity:  -0.39153251188431704
# step:  350
# slider translation velocity:  [-0.04135419  0.05779705]
# slider rotation velocity:  -0.4000979519719853
# step:  351
# slider translation velocity:  [-0.04007322  0.05916632]
# slider rotation velocity:  -0.40947317373826
# step:  352
# slider translation velocity:  [-0.03866027  0.06066434]
# slider rotation velocity:  -0.4197694140174338
# step:  353
# slider translation velocity:  [-0.03709594  0.06230894]
# slider rotation velocity:  -0.4311182516351861
# step:  354
# slider translation velocity:  [-0.03535712  0.0641213 ]
# slider rotation velocity:  -0.44367625491704127
# step:  355
# slider translation velocity:  [-0.03341599  0.06612662]
# slider rotation velocity:  -0.45763091086915086
# step:  356
# slider translation velocity:  [-0.03123892  0.06835519]
# slider rotation velocity:  -0.47320825354748597
# step:  357
# slider translation velocity:  [-0.02878491  0.07084359]
# slider rotation velocity:  -0.49068276745807987
# step:  358
# slider translation velocity:  [-0.02600355  0.07363638]
# slider rotation velocity:  -0.5103903693194689
# step:  359
# slider translation velocity:  [-0.0228324   0.07678822]
# slider rotation velocity:  -0.5327456027007069
# step:  360
# slider translation velocity:  [-0.01919334  0.08036678]
# slider rotation velocity:  -0.558264669044735
# step:  361
# slider translation velocity:  [-0.01498766  0.08445663]
# slider rotation velocity:  -0.5875966516731691
# step:  362
# slider translation velocity:  [-0.01008925  0.08916443]
# slider rotation velocity:  -0.6215664066262712
# step:  363
# slider translation velocity:  [-0.00433511  0.09462626]
# slider rotation velocity:  -0.6612343276229666
# step:  364
# slider translation velocity:  [0.00248826 0.10101778]
# slider rotation velocity:  -0.707980934635322
# step:  365
# slider translation velocity:  [0.01066454 0.10856862]
# slider rotation velocity:  -0.7636286667109156
# step:  366
# slider translation velocity:  [0.02057674 0.11758332]
# slider rotation velocity:  -0.8306205886324804
# step:  367
# slider translation velocity:  [0.03275124 0.1284721 ]
# slider rotation velocity:  -0.9122881577062467
# step:  368
# slider translation velocity:  [0.04792597 0.14179709]
# slider rotation velocity:  -1.0132619084306977
# step:  369
# slider translation velocity:  [0.06715905 0.15834362]
# slider rotation velocity:  -1.140118030319112
# step:  370
# slider translation velocity:  [0.09200699 0.1792325 ]
# slider rotation velocity:  -1.3024268213290375
# step:  371
# slider translation velocity:  [0.12482778 0.20610219]
# slider rotation velocity:  -1.5145107658861245
# step:  372
# slider translation velocity:  [0.16931726 0.2414131 ]
# slider rotation velocity:  -1.7985078933497196
# step:  373
# slider translation velocity:  [0.2315041  0.28897272]
# slider rotation velocity:  -2.189951377888991
# step:  374
# slider translation velocity:  [0.32169816 0.35487245]
# slider rotation velocity:  -2.7484704687134887
# step:  375
# slider translation velocity:  [0.45855913 0.44921158]
# slider rotation velocity:  -3.579596182255957
# step:  376
# slider translation velocity:  [0.67826285 0.58932812]
# slider rotation velocity:  -4.8825003222352965
# step:  377
# slider translation velocity:  [1.05709529 0.80567608]
# slider rotation velocity:  -7.0637869721028235
# step:  378
# slider translation velocity:  [1.77323371 1.15006958]
# slider rotation velocity:  -11.037013321550496
# step:  379
# slider translation velocity:  [3.29453014 1.68458895]
# slider rotation velocity:  -19.099354471398435
# step:  380
# slider translation velocity:  [6.96600587 2.22780602]
# slider rotation velocity:  -37.65657598372651
# step:  381
# slider translation velocity:  [15.67170216  0.19240581]
# slider rotation velocity:  -82.35892545412574
# step:  382
# slider translation velocity:  [17.75057728 -3.45929875]
# slider rotation velocity:  -103.36884453294282
# step:  383
# slider translation velocity:  [30.09981166 18.30262336]
# slider rotation velocity:  21.73959277131503
# step:  384
# slider translation velocity:  [31.94535632 24.29505976]
# slider rotation velocity:  53.09056132076797
# step:  385
# slider translation velocity:  [34.84522909 12.02861143]
# slider rotation velocity:  -9.932255355086156
# step:  386
# slider translation velocity:  [34.57645075 14.04029191]
# slider rotation velocity:  0.21552785060972823
# step:  387
# slider translation velocity:  [34.57623215 14.04190161]
# slider rotation velocity:  0.22365020903263289
# step:  388
# slider translation velocity:  [34.58609777 13.97045385]
# slider rotation velocity:  -0.13697815071733427
# step:  389
# slider translation velocity:  [34.58046588 14.01165695]
# slider rotation velocity:  0.07095293163522556
# step:  390
# slider translation velocity:  [34.5833779  13.99046461]
# slider rotation velocity:  -0.03600441056609789
# step:  391
# slider translation velocity:  [34.58190586 14.00120616]
# slider rotation velocity:  0.018205334712866096
# step:  392
# slider translation velocity:  [34.58265113 13.99577525]
# slider rotation velocity:  -0.009203719123141413
# step:  393
# slider translation velocity:  [34.58227463 13.99852071]
# slider rotation velocity:  0.004652041715996034
# step:  394
# slider translation velocity:  [34.582465   13.99713299]
# slider rotation velocity:  -0.0023515200316847574
# step:  395
# slider translation velocity:  [34.58236879 13.99783445]
# slider rotation velocity:  0.0011886079749498938
# step:  396
# slider translation velocity:  [34.58241742 13.99747989]
# slider rotation velocity:  -0.0006008082310097927
# step:  397
# slider translation velocity:  [34.58239284 13.99765911]
# slider rotation velocity:  0.0003036892206669837
# step:  398
# slider translation velocity:  [34.58240527 13.99756852]
# slider rotation velocity:  -0.00015350578916661223
# step:  399
# slider translation velocity:  [34.58239899 13.99761431]
# slider rotation velocity:  7.759240079948602e-05
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
